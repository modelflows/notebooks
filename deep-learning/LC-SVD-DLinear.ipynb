# %% [markdown]
# ## LC-SVD-DLinear
# Official implementation of the hybrid LC-SVD-DLinear model.
#
# [Hetherington, Ashton, Javier López Leonés, and Soledad Le Clainche. "LC-SVD-DLinear: A low-cost physics-based hybrid machine learning model for data forecasting using sparse measurements." arXiv preprint arXiv:2411.17433 (2024)](https://arxiv.org/abs/2411.17433)
#
# **Description**
#
# LC-SVD-DLinear and LC-HOSVD-DLinear are hybrid physics-informed neural networks designed for forecasting experimental data before reconstructing high-resolution snapshots. These models integrate modal decomposition techniques, such as low-cost singular value decomposition (LC-SVD) and low-cost high-order singular value decomposition (LC-HOSVD), which extract and reconstruct proper orthogonal decomposition (POD) modes, singular values, and temporal coefficients while preserving the underlying physical dynamics. A shallow neural network is then employed to analyze the temporal coefficients, breaking down the input sequence into its trend and seasonality components, and identify patterns for forecasting future states. This approach ensures computational efficiency, as the predictive model operates exclusively on the reconstructed temporal coefficients rather than the full high-dimensional dataset. For more information about LC-SVD, please see:
#
# [Hetherington, Ashton, and Soledad Le Clainche. "Low-cost singular value decomposition with optimal sensor placement." *arXiv preprint* arXiv:2311.09791 (2023)](https://arxiv.org/abs/2311.09791)

# %%
# Install libraries
# !pip install -q python-sensors optuna torch termcolor
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
### Imports
import pysensors as ps
import numpy as np
import pickle
from termcolor import colored

from scipy.io import loadmat
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy.stats import pearsonr 
from scipy.fftpack import fft

import optuna
from optuna.trial import TrialState
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt

# %matplotlib inline

# Configure the plot appearance
plt.rc('axes', labelsize = 18)
plt.rc('axes', titlesize = 18)
plt.rc('legend', fontsize = 22)
plt.rc('figure', titlesize = 24)
plt.rc('xtick', labelsize = 16)
plt.rc('ytick', labelsize = 16)

# %% [markdown]
# ### Use cases
# You can run this notebook two different ways:
# 1. Train the model from scratch. In this case, run the entire notebook.
# 2. Use the pretrained model for the test case to generate predictions. Load the data from cells `[10]` to `[12]` and then skip to the **Using a pretrained model** section, or cell `[57]`.

# %% [markdown]
# ### Callbacks

# %%
### Early stopping callback
class EarlyStopping():
  '''
  Callback used to avoid model overfitting during training. If the validation
  loss does not improve during a number of epochs, the model will stop training.
  Args:
      - patience: number of epochs evaluated after validation loss plateau, before stopping training
      - model_save_path: name of the file where the model parameters are saved
      - min_delta: minumum variation of validation loss between iterations
          val_loss[n] - val_loss[n - 1] <= min_delta
  '''
  def __init__(self, patience, model_save_path, min_delta = 0):
      self.patience = patience
      self.min_delta = min_delta
      self.model_save_path = model_save_path
      self.counter = 0
      self.min_validation_loss = np.inf
      self.best_epoch = 0
      self.early_stop = False

  def __call__(self, epoch, model, validation_loss):
      delta_loss = self.min_validation_loss - validation_loss
      if delta_loss > self.min_delta:
          self.min_validation_loss = validation_loss
          self.counter = 0
          self.best_epoch = epoch
          torch.save(model.state_dict(), self.model_save_path)
      else:
          self.counter += 1
          if self.counter >= self.patience:
              print('Early stopping')
              print(f'Saved best model at epoch {self.best_epoch}')
              self.early_stop = True

# Reduce LR on plateau
class LRScheduler():
  '''
  Reduce optimizer learning rate when the model validation loss does not improve
  Args:
      - optimizer: optimizer used during training (SGD, Adam, Adam, etc.)
      - patience: number of epochs evaluated after a possible learning rate plateau before applying a decrease
      - min_lr: minimum learning rate value. Default is 1e-06
      - factor: value by which the learning rate is reduced. Default is 0.5
  '''
  def __init__(self, lr, optimizer, patience, min_lr = 1e-6, factor = 0.5):
      self.optimizer = optimizer
      self.patience = patience
      self.min_lr = min_lr
      self.prev_lr = lr
      self.factor = factor
      self.lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer,
                                                                      mode = 'min',
                                                                      patience = self.patience,
                                                                      factor = self.factor,
                                                                      min_lr = self.min_lr)
  def __call__(self, val_loss):
      self.lr_scheduler.step(val_loss)
      curr_lr = self.optimizer.param_groups[0]['lr']
      if curr_lr < self.prev_lr:
          print(f'Learning rate dropped to: {curr_lr}')
      self.prev_lr = curr_lr

# %% [markdown]
# ### Hyperparameter tuner

# %%
def hyperFinder(train_dataset, val_dataset, model, device):
    '''
    Function used to find optimal hyperparameter values
    Args:
        - train_dataset: dataset containing training data
        - val_dataset: dataset containing validation data
        - model: forecast model class which requires tuning
        - device: device used for training: cuda:0 or cpu
    Returns:
        - train_loader: train dataloader with the optimal batch size
        - val_loader: validation dataloader with the optimal batch_size
        - learning_rate: optimal learning rate
        - weight_decay: optimal weight decay
    '''
    def objective(trial):
        epochs = 50

        weight_decay = trial.suggest_float('weight_decay', 1e-15, 1e-02, log = True)
        lr = trial.suggest_float("lr", 1e-04, 1e-02, log = True)

        optimizer = torch.optim.Adam(model.parameters(), lr = lr, weight_decay = weight_decay)

        batch_size = trial.suggest_categorical("batch_size", [4, 8, 16, 32])
        
        train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True, drop_last = True)
        val_loader = DataLoader(val_dataset, batch_size = batch_size, shuffle = False)

        loss_fn = nn.MSELoss()

        train_loss = 0.0
        num_train_batches = len(train_loader)
        num_val_batches = len(val_loader)
        val_loss = 0.0

        for epoch in range(epochs):
            model.train()

            for X, y in train_loader:
                X, y = X.to(device), y.to(device)
                optimizer.zero_grad()
                output = model(X)
                loss = loss_fn(output, y)
                loss.backward()
                optimizer.step()

                train_loss += loss.item()

            # train_avg_loss = train_loss / num_train_batches

            model.eval()
            with torch.no_grad():
                for X, y in val_loader:
                    X, y = X.to(device), y.to(device)
                    output = model(X)
                    val_loss += loss_fn(output, y)

            val_avg_loss = val_loss / num_val_batches

            trial.report(val_avg_loss, epoch)

            if trial.should_prune():
                raise optuna.exceptions.TrialPruned()

        return val_avg_loss

    study = optuna.create_study(direction = "minimize")
    study.optimize(objective, n_trials = 50)
    pruned_trials = study.get_trials(deepcopy = False, states = [TrialState.PRUNED])
    completed_trials = study.get_trials(deepcopy=False, states = [TrialState.COMPLETE])

    print('Study statistics: ')
    print('     Number of finished trials: ', len(study.trials))
    print('     Number of pruned trials: ', len(pruned_trials))
    print('     Number of completed trials: ', len(completed_trials))

    print('Best trial: ')
    trial = study.best_trial
    print('     Value: ', trial.value)

    print('     Params: ')
    for key, value in trial.params.items():
        print('    {}: {}'.format(key, value))

    optimal_params = trial.params

    train_loader = DataLoader(train_dataset, batch_size = optimal_params['batch_size'], shuffle = True, drop_last = True)
    val_loader = DataLoader(val_dataset, batch_size = optimal_params['batch_size'], shuffle = False)

    return train_loader, val_loader, optimal_params['lr'], optimal_params['weight_decay']

# %% [markdown]
# ### The DLinear architecture

# %%
class moving_avg(nn.Module):
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size = kernel_size, stride = stride, padding = 0)

    def forward(self, x):
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size -1) // 2, 1)
        x = torch.cat([front, x, end], dim = 1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x

class series_descomp(nn.Module):
    '''
    Applies a moving average to the input sequence, and decomposes the sequence into trend and seasonality
    '''
    def __init__(self, kernel_size):
        super(series_descomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride = 1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class DLinear(nn.Module):
    def __init__(self, input_size, kernel_size, sequence, horizon, individual):
        '''
        Decomposes an input sequence into trend and seasonality, and predicts the next value(s)
        Args:
            - input_size: number of modes
            - kernel_size: size of the kernel used to extract the trend
            - sequence: length of the input sequence
            - horizon: length of the forecast sequence
            - individual (bool): set to true if only a singular mode is being predicted 
        '''
        super(DLinear, self).__init__()
        self.Lag = sequence
        self.Horizon = horizon

        kernel_size = kernel_size
        self.decomposition = series_descomp(kernel_size)
        self.individual = individual
        self.channels = input_size

        self.Linear_Seasonal = nn.ModuleList()
        self.Linear_Trend = nn.ModuleList()

        for i in range(self.channels):
            self.Linear_Seasonal.append(nn.Linear(self.Lag, self.Horizon))
            self.Linear_Seasonal[i].weight = nn.Parameter((1 / self.Lag) * torch.zeros([self.Horizon, self.Lag])) # changed from ones to zeros
            self.Linear_Trend.append(nn.Linear(self.Lag, self.Horizon))
            self.Linear_Trend[i].weight = nn.Parameter((1 / self.Lag) * torch.zeros([self.Horizon, self.Lag])) # changed from ones to zeros

    def forward(self, x): # x: [Batch_size, Input_length, Channels]
        seasonal_init, trend_init = self.decomposition(x)
        seasonal_init, trend_init = seasonal_init.permute(0, 2, 1), trend_init.permute(0, 2, 1)

        seasonal_output = torch.zeros([seasonal_init.size(0), seasonal_init.size(1), self.Horizon], dtype = seasonal_init.dtype).to(seasonal_init.device)
        trend_output = torch.zeros([trend_init.size(0), trend_init.size(1), self.Horizon], dtype = trend_init.dtype).to(trend_init.device)
        
        for i in range(self.channels):
            seasonal_output[:, i, :] = self.Linear_Seasonal[i](seasonal_init[:, i, :])
            trend_output[:, i, :] = self.Linear_Trend[i](trend_init[:, i, :])

        x = seasonal_output + trend_output # x -> [batch, channels, horizon]
        return x.reshape(-1, self.channels) if self.Horizon == 1 else x.reshape(-1, self.Horizon, self.channels) # [Batch_size, Output_length, Channel]

# %% [markdown]
# ### Sequence generator and tensor dataset

# %%
def seqGenerator(Tensor, seq_len, horizon):
    '''
    Creates the sequences for the forecasting model
    Args:
      - Tensor: input tensor, which is the product of singular values and temporal coefficients
      - seq_len: length of the sequence of snapshots used to predict
      - horizon: number of snapshots predicted
    Returns:
      - an array containing the input sequences
      - an array containing the output horizons
    '''
    X = []
    y = []

    max_index = Tensor.shape[-1] - seq_len - horizon + 1

    for i in range(max_index):
        X.append(Tensor[:, i: i + seq_len]) # Take the last seq_len snapshots
        y.append(Tensor[:, i + seq_len: i + seq_len + horizon]) # Predict the horizon

    return np.array(X), np.array(y)

class TimeSeriesDataset(Dataset):
  '''
  Create a dataset by pairing sequences with their horizons
  Args:
      - X: sequence of the features
      - y: target value horizon
  '''
  def __init__(self, X, y):
      self.X = torch.tensor(X, dtype=torch.float32)
      self.y = torch.tensor(y, dtype=torch.float32)

  def __getitem__(self, idx):
      features = self.X[idx]
      targets = self.y[idx]
      return features, targets

  def __len__(self):
      return len(self.X)

# %% [markdown]
# ### Train and validation functions

# %%
def train_model(data_loader, model, loss_function, optimizer, device):
    '''
    Forecast model training function
    Args:
        - data_loader: torch dataloader object
        - model: forecasting model
        - loss_function: loss function used for training
        - optimizer: optimizer used for training
        - device: device used for training: cuda:0 or cpu
    Returns:
        - train_avg_loss: average train loss for one epoch
    '''
    num_batches = len(data_loader)
    total_loss = 0

    model.train()

    for X, y in data_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        output = model(X)
        loss = loss_function(output, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    train_avg_loss = total_loss / num_batches

    return train_avg_loss

def val_model(data_loader, model, loss_function, device):
    '''
    Forecast model validation function
    Args:
        - data_loader: torch dataloader object
        - model: forecasting model
        - loss_function: loss function used for validation (same as training)
        - device: device used for training: cuda:0 or cpu
    Returns:
        - val_avg_loss: average validation loss for one epoch
    '''
    num_batches = len(data_loader)
    total_loss = 0
    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X, y = X.to(device), y.to(device)
            output = model(X)
            total_loss += loss_function(output, y)

    val_avg_loss = total_loss / num_batches

    return val_avg_loss

# %% [markdown]
# ### Data Scaling

# %%
def scaler(sV: np.ndarray, split: float = 0.7, type: str = 'minmax', scaler_name = 'LC-SVD-DLinear_scaler'):
    '''
    Scales the input data using max-per-mode scaling and splits the data into train, validation and test
    Args:
        - sV: input matrix which is V.T
        - split: percentage of the input data that correspondes to training. Remaining part it split into two, for val. and test.
        - type: type of scaling to perform, which can be standard or minmax
        - scaler_name: name used to save the scaler
    Returns:
        - train: scaled train data
        - val: scaled validation data
        - test: scaled test data
        - train_idx: cut-off index corresponding to the training data set
        - val_idx: cut-off index corresponding to the validation data set
        - scaler: scaler object
    '''

    train_split = split
    val_split = (1 - train_split) / 2
    
    samples = sV.shape[-1]
    
    train_idx = int(samples * train_split)
    val_idx = int(samples * val_split)
    
    train = sV[:, :train_idx]
    val = sV[:, train_idx: train_idx + val_idx]
    test = sV[:, train_idx + val_idx:]

    if type.lower() == 'standard':
        scaler = StandardScaler()

    if type.lower() == 'minmax':
        scaler = MinMaxScaler(feature_range=(0, 1))

    train = scaler.fit_transform(train.transpose(1, 0)).transpose(1, 0)
    val = scaler.transform(val.transpose(1, 0)).transpose(1, 0)
    test = scaler.transform(test.transpose(1, 0)).transpose(1, 0)

    with open(f"{scaler_name}.pkl", "wb") as f:
        pickle.dump(scaler, f)

    return train, val, test, train_idx, val_idx, scaler

# %% [markdown]
# ### Error evaluation functions

# %%
def compute_MAE(y_true, y_pred): 
    '''
    Mean absolute error function
    Args:
        y_true: ground truth values
        y_pred: predicted values
    Return:
        Mean Absolute Error (MAE)
    '''  
    return np.mean(np.abs(y_true - y_pred))

def compute_MAPE(y_true, y_pred): 
    '''
    Mean absolute percentual error function
    Args:
        y_true: ground truth values
        y_pred: predicted values
    Return:
        Mean Absolute Percentual Error (MAPE)
    '''  
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def compute_MSE(y_true, y_pred):
    '''
    Relative mean squared error function
    Args:
        y_true: ground truth values
        y_pred: predicted values
    Return:
        Mean Squared Error (RMSE)
    '''  
    return np.mean((y_true - y_pred) ** 2)

def compute_PCC(y_true, y_pred):
    '''
    Compute the PCC score of the predictions
    Args:
        y_true: ground truth values
        y_pred: predicted values
    Return:
        PCC score
    '''  
    corrs = []
    for i in range(y_true.shape[-1]):
        PCC = pearsonr(y_true[..., i].flatten(), y_pred[..., i].flatten())[0]
        corrs.append(PCC)

    return np.mean(np.array(corrs))

# %% [markdown]
# ### Low-cost singular value decomposition (LC-SVD)

# %%
def optimalSensors(Tensor: np.ndarray, n_sensors: int):
  '''
  Finds the optimal sensors position using pysensors
  Args:
      - tensor (IxJ): snapshot matrix.
      - n_sensors: number of sensors to be used.
  Return:
      - sensors (1xn_sensors): vector of indexes for the optimal sensors.
  '''

  shape = Tensor.shape

  if Tensor.ndim == 3:
      Matrix = np.reshape(Tensor, (np.prod(shape[:-1]), shape[-1]))

      mesh_size = shape[:-1]

  else:
      norm = np.linalg.norm(Tensor.reshape(shape[0], np.prod(shape[1:])), axis=0)

      norm = np.reshape(norm, (1, *shape[1:]))

      Matrix = np.reshape(norm, (np.prod(shape[1:-1]), shape[-1]))

      mesh_size = shape[1:-1]

  X_train = np.transpose(Matrix, (1, 0))

  n_samples, n_features = X_train.shape

  print('Number of samples:', n_samples)
  print('Number of possible sensors:', n_features)

  model = ps.SSPOR(basis=ps.basis.SVD(n_basis_modes=2), n_sensors=n_sensors)

  model.fit(X_train)
  sensors = model.get_selected_sensors()

  sens = np.zeros(n_features)
  sens[sensors] = 1
  matrix = np.array(
      np.reshape(sens, mesh_size))

  x = []
  y = []
  z = []

  if len(shape) == 3:
      for i in range(shape[1]):
          for j in range(shape[0]):
              if matrix[j, i] == 1:
                  x.append(i)
                  y.append(j)

  elif len(shape) in [4, 5]:
      for i in range(shape[2]):
          for j in range(shape[1]):
              if matrix.ndim == 2:
                  if matrix[j, i] == 1:
                      x.append(i)
                      y.append(j)
              elif matrix.ndim == 3:
                  for k in range(shape[3]):
                      if matrix[j, i, k] == 1:
                          x.append(i)
                          y.append(j)
                          z.append(k)

  if matrix.shape == 2:
      z = None

  return sensors, x, y, z

def LCSVD(Ared: np.ndarray, tensor: np.ndarray, esvd: float, points: np.ndarray, time: list):
  """
  Low-cost singular value decomposition
  Args:
    - Ared: downsampled tensor
    - tensor: high-resolution tensor (ground truth)
    - esvd: singular value decomposition tolerance
    - points: array of points corresponding to the sensor positions
    - time: array of snapshot indexes

  Returns:
    - U: mxm matrix of the orthonormal eigenvectors of AA.T
    - S: diagonal matrix with r elements equal to the root of the positive eigenvalues of AA.T
    - V: transpose of a nxn matrix containing the orthonormal eigenvectors of A.TA
    - n_modes: number of modes retained during svd
    - TensorAprox: reconstructed tensor from low-resolution (Ared)
    - RRMSE: relative root mean squared error
  """

  shape = tensor.shape
  dims_prod = np.prod(shape[:-1])
  Tensor = np.reshape(tensor, (dims_prod, shape[-1]))

  Ured, S, Vred = np.linalg.svd(Ared, full_matrices = False)

  n_modes = 0
  norm = np.linalg.norm(S)
    
  for i in range(S.size):
      if np.linalg.norm(S[i:]) / norm <= esvd:
          pass
      else:
          n_modes += 1
            
  Sred = np.diag(S)
  Ured = Ured[:, :n_modes]
  Sred = Sred[:n_modes, :n_modes]
  Vred = Vred.conj().T
  Vred = Vred[:, :n_modes]

  Q, R = np.linalg.qr(Ured)
  Ured = Ured @ np.linalg.inv(R[:n_modes, :])
  Q1, R1 = np.linalg.qr(Vred)
  Vred = Vred @ np.linalg.inv(R1[:n_modes, :])

  ss = Ured.conj().T @ Ared @ Vred
  ss1 = np.sign(np.diag(np.diag(ss)))

  Vred = Vred @ ss1

  U = (Tensor[:, time] @ Vred) @ np.linalg.inv(Sred)
  V = (Tensor[points, :].conj().T @ Ured) @ np.linalg.inv(Sred)

  newshape = []
  newshape.append(shape[:-1])
  newshape.append(V.shape[0])
  newshape = list(newshape[0]) + [newshape[1]]

  TensorAprox = np.reshape((U @ Sred) @ V.conj().T, np.array(newshape))

  RRMSE = np.linalg.norm(np.reshape(tensor - TensorAprox, newshape=(np.size(tensor), 1)), ord=2) / np.linalg.norm(
      np.reshape(tensor, newshape=(np.size(tensor), 1)))

  return U, S[:n_modes], V, n_modes, TensorAprox, RRMSE

def sensorChecker(Tensor: np.ndarray, n_sensors: np.ndarray, esvd: float, tol: float) -> np.ndarray:
  '''
  Finds and verifies the optimal sensor positions based on an error threshold. This is used to calibrate the sensor positioning based on numerical data
  Args:
    - Tensor: high-resolution tensor used to find the optimal positions
    - n_sensors: number of sensors
    - esvd: singular value decomposition tolerance
    - tol: error tolerance threshold
  Returns:
    - sensors: optimal sensors vector
  '''

  RelativeErrorRMS = 1

  i = 1

  while RelativeErrorRMS * 100 > tol:

      print(f'Iteration number {i}')

      i += 1

      sensors, x, y, z = optimalSensors(Tensor[..., ::4], n_sensors)

      Ared = np.reshape(Tensor, (-1, Tensor.shape[-1]))

      Time = list(np.linspace(0, Tensor.shape[-1] - 1, Tensor.shape[-1]).astype(int))

      Ared = Ared[sensors, :]

      Ared = Ared[:, Time]

      _, _, _, _, _, RelativeErrorRMS = LCSVD(Ared = Ared, tensor = Tensor, esvd = esvd, points = sensors, time = Time)

  print(f'RRMSE - Reconstruction error for the optimal sensors combination: {(RelativeErrorRMS * 100):.3f}%\n')

  if Tensor.ndim == 3:
    fig, ax = plt.subplots(1, 1, figsize = (10, 4))
    plt.suptitle('Sensor positions')
    ax.contourf(Tensor[..., 0], alpha=0.5)
    ax.scatter(x, y, color='k')
    plt.grid(color = 'grey')
    # ax.set_aspect('equal')
    plt.tight_layout()
    
  if Tensor.ndim == 4:
    comps = Tensor.shape[0]
    fig, ax = plt.subplots(1, comps, figsize = (12, 4), sharey = True)
    plt.suptitle('Sensor positions')
    for col in range(comps):
        ax[col].contourf(Tensor[col, ..., 0], alpha=0.5)
        ax[col].scatter(x, y, color = 'k')
        # ax[col].set_aspect('equal')
        ax[col].grid(color = 'grey')
    plt.tight_layout()
      
  if Tensor.ndim == 5:
    comps = Tensor.shape[0]
    nz = int(Tensor.shape[3] / 2)
    fig, ax = plt.subplots(1, comps, figsize = (14, 4), sharey = True)
    plt.suptitle('Sensor positions in the XY plane')
    for col in range(comps):
        ax[col].contourf(Tensor[col, ..., nz, 0], alpha=0.5)
        ax[col].scatter(x, y, color = 'k')
        # ax[col].set_aspect('equal')
        ax[col].grid(color = 'grey')
    plt.tight_layout()

  return sensors, x, y, z

# %% [markdown]
# ### Load the input data
# Here, we load the numerical dataset and create a synthetic experimental dataset

# %%
### Data is usually stored in .mat format
numericalTensor = list(loadmat('Tensor_cylinder_Re100.mat').values())[-1]

### Creating a synthetic experimental dataset
noise_level = 0  # Adjust noise magnitude
noise = np.random.normal(loc = 0, scale = noise_level, size = numericalTensor.shape)
syntheticExperimentalTensorHighRes = numericalTensor + noise

### Display both datasets
fig, ax = plt.subplots(2, 3, width_ratios = [25, 25, 1], figsize = (12, 6))

# Numerical dataset
ax[0, 0].contourf(numericalTensor[0, ..., 0])
ax[0, 0].set(title = 'Num. - Streamwise velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
im1 = ax[0, 1].contourf(numericalTensor[1, ..., 0])
ax[0, 1].set(title = 'Num. - Normal velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
plt.colorbar(im1, cax = ax[0, 2])

# Synthetic experimental dataset before final downsample
ax[1, 0].contourf(syntheticExperimentalTensorHighRes[0, ..., 0])
ax[1, 0].set(title = 'Exp. - Streamwise velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
im3 = ax[1, 1].contourf(syntheticExperimentalTensorHighRes[1, ..., 0])
ax[1, 1].set(title = 'Exp. - Normal velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
plt.colorbar(im3, cax = ax[1, 2])
plt.tight_layout()

# %%
# Find the optimal sensor positions
optimal = False
n_sensors = 42 # Number of sensors

if optimal:
    print('Searching for optimal sensor positions...\n')

    esvd = 1e-03 # svd tolerance for mode retention
    tol = 0.5 # Reconstruction RRMSE tolerance threshold

    one_sensors, x, y, z = sensorChecker(Tensor = numericalTensor, n_sensors = n_sensors, esvd = esvd, tol = tol)
    
    if numericalTensor.ndim == 3:
        sensors = one_sensors
            
    else:
        last_value = np.prod(numericalTensor.shape[1:-1])

        sorted_sensors = sorted(one_sensors)

        sensors = sorted_sensors + [x + last_value for x in sorted_sensors]

else:
    print('Downsampling dataset equidistantly...\n')

    n_sensors_ = n_sensors * 2

    tenShape = numericalTensor.shape

    sensors = np.linspace(0, np.prod(tenShape[0:-1]) - 1, n_sensors_).astype(int)

Time = list(np.linspace(0, numericalTensor.shape[-1] - 1, numericalTensor.shape[-1]).astype(int))
# Out:
# Downsampling dataset equidistantly...

# %% [markdown]
# ### Experimental data collection using the optimal sensor positions

# %%
def find_factors(N):
    factors = [(i, N // i) for i in range(1, int(N**0.5) + 1) if N % i == 0]
    return factors

n_x, n_y = find_factors(n_sensors)[-1]

syntheticExperimentalTensor = np.reshape(syntheticExperimentalTensorHighRes, (-1, syntheticExperimentalTensorHighRes.shape[-1]))

syntheticExperimentalTensor = syntheticExperimentalTensor[sensors, :]

syntheticExperimentalTensor = syntheticExperimentalTensor[:, Time]

print(f'Downsampled tensor shape: {syntheticExperimentalTensor.shape}')

nv, nx, ny, nt = numericalTensor.shape

syntheticExperimental = syntheticExperimentalTensor.reshape(nv, n_x, n_y, nt)

# Synthetic experimental dataset before final downsample
fig, ax = plt.subplots(1, 3, width_ratios = [25, 25, 1], figsize = (8, 3))
ax[0].contourf(syntheticExperimental[0, ..., 0])
ax[0].set(title = 'Exp. - Streamwise velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
im3 = ax[1].contourf(syntheticExperimental[1, ..., 0])
ax[1].set(title = 'Exp. - Normal velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
plt.colorbar(im3, cax = ax[2])
plt.tight_layout()
# Out:
# Downsampled tensor shape: (84, 151)

# %% [markdown]
# ### Creating a pipeline to preprocess the data
# The goal is to enhance the resolution of `syntheticExperimentalTensor`, and forecast the next snapshots in high resolution.

# %%
def svdpreprocessing(Tensor, Ared, esvd, sensors, time, batch_size, seq_len, horizon, scaler_type, scaler_name):
    U, S, V, n_modes, A_reconst, _ = LCSVD(Ared, Tensor, esvd, sensors, time)
    S = np.diag(S)
    V = V.T  

    print(f'''
Low-cost singular value decomposition summary
        - n_modes (retained modes): {n_modes}
        - U (POD modes): {U.shape}
        - S (singular values): {S.shape}
        - V (temporal coefficients): {V.shape}
        - TensorAprox (reconstructed tensor): {A_reconst.shape}
        ''')
    
    ### SVD modes evolution    
    fig, ax = plt.subplots(1, 1)
    for i in range(S.shape[0]):
        ax.plot(i + 1, S[i][i] / S[0][0], "ko") 
        
    ax.set_yscale('log')      # Logarithmic scale in y axis
    ax.set_xlabel('SVD modes')
    ax.set_ylabel('Singular values')
    ax.set_title('SVD modes vs. Singular values')
    plt.show()

    # Fourier 
    fig, ax = plt.subplots(2, 2, figsize = (10, 10))
    for i, axs in zip(range(4), ax.flatten()):
        axs.set(title = f'Mode: {i + 1}')
        temporal_coefficients = V[i, :].squeeze()
        fft_result = fft(temporal_coefficients)
        frequencies = np.fft.fftfreq(len(temporal_coefficients))
        axs.plot(frequencies[:len(frequencies)//2], np.abs(fft_result)[:len(frequencies)//2])
        if i > 1:
            axs.set_xlabel('Frequency')

        if i % 2 == 0:
            axs.set_ylabel('Amplitude')

    plt.show()

    if A_reconst.ndim == 5:
        nz = int(A_reconst.shape[-2] / 2)
        
        fig, ax = plt.subplots(1, 3, figsize = (10, 3))
        ax[0].contourf(A_reconst[0, ..., nz, 0], cmap = 'magma')
        ax[1].contourf(A_reconst[1, ..., nz,  0], cmap = 'magma')
        ax[2].contourf(A_reconst[2, ..., nz, 0], cmap = 'magma')
        ax[0].set(xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
        ax[1].set(xlabel = 'X', xticks = [], yticks = []) 
        ax[2].set(xlabel = 'X', xticks = [], yticks = []);

    elif A_reconst.ndim == 4:
        fig, ax = plt.subplots(1, 2, figsize = (10, 3))
        ax[0].contourf(A_reconst[0, ..., 0], cmap = 'magma')
        ax[1].contourf(A_reconst[1, ..., 0], cmap = 'magma')
        ax[0].set(xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
        ax[1].set(xlabel ='X', xticks = [], yticks = []);

    elif A_reconst.ndim == 3:
        fig, ax = plt.subplots(1, 1, figsize = (10, 3))
        ax.contourf(A_reconst[..., 0], cmap = 'magma')
        ax.set(xlabel = 'X', ylabel = 'Y');

    plt.suptitle('Tensor reconstructed using LC-HOSVD')
    plt.tight_layout()
    plt.show()
    
    split = 0.7

    print('Scaling the data...')        
    train, val, test, train_idx, val_idx, data_scaler = scaler(V, split, scaler_type, scaler_name)

    labels = ['Train', 'Validation', 'Test']
    fig, axs = plt.subplots(2, 2, figsize = (10, 4))
    for i, ax in zip(range(4), axs.flatten()):
        ax.set_title(f'Mode: {i + 1}')
        ax.plot(train[i, :], c = 'red')
        ax.plot(range(train_idx, train_idx + val_idx), val[i, :], c = 'blue')
        ax.plot(range(train_idx + val_idx, V.shape[-1]), test[i, :], c = 'green')
        if i <= 1:
            ax.set(xticks = [])

        if i % 2 != 0:
            ax.set(yticks = [])
        

    fig.tight_layout()
    fig.subplots_adjust(bottom = 0.3)
    fig.legend(labels = labels, loc="lower center", ncol=3)
    
    plt.show()

    original_test = Tensor[..., train_idx + val_idx:]

    val = np.concatenate([train[:, -seq_len:], val], axis = 1)
    test = np.concatenate([val[:, -seq_len:], test], axis = 1)

    print(f'''
Split summary
    - Train samples: {train.shape}
    - Validation samples: {val.shape}
    - Test samples: {test.shape}
        ''')
    
    print('Creating data sequences...\n')
    train_seq, train_horizon = seqGenerator(train, seq_len, horizon)
    val_seq, val_horizon = seqGenerator(val, seq_len, horizon)
    test_seq, test_horizon = seqGenerator(test, seq_len, horizon)

    train_seq, val_seq, test_seq = train_seq.transpose(0, 2, 1), val_seq.transpose(0, 2, 1), test_seq.transpose(0, 2, 1)
    train_horizon, val_horizon, test_horizon = train_horizon.squeeze(), val_horizon.squeeze(), test_horizon.squeeze()
    
    print('Creating PyTorch datasets...\n')
    train_ds = TimeSeriesDataset(train_seq, train_horizon)
    val_ds = TimeSeriesDataset(val_seq, val_horizon)
    test_ds = TimeSeriesDataset(test_seq, test_horizon)

    print('Generating data loaders...\n')
    train_loader = DataLoader(train_ds, batch_size = batch_size, shuffle = True, drop_last = True)
    val_loader = DataLoader(val_ds, batch_size = batch_size, shuffle = False)
    test_loader = DataLoader(test_ds, batch_size = 1, shuffle = False)

    sample = next(iter(train_loader))
    print(f'Singular batch of the features (sequence): {sample[0].shape}')
    print(f'Singular batch of the target (horizon): {sample[1].shape}')

    print('\nData preprocessing complete!')

    return original_test, test, train_loader, val_loader, test_loader, n_modes, \
    train_ds, val_ds, U, S, train_seq, val_seq, test_seq, data_scaler

# %% [markdown]
# ### Full data preprocessing and model training pipeline

# %%
def generator(Tensor, Ared, esvd, sensors, Time, seq_len, horizon, batch_size, epochs, scaler_type, optimal, snapshots,
              model_save_path = 'LC-SVD-DLinear.pth', scaler_name = 'LC-SVD-DLinear_scaler'):

    print(colored('Step 1: Data preprocessing', 'red', attrs=["bold"]))
    test_data, test, train_loader, val_loader, test_loader, n_modes, train_ds, \
    val_ds, U, S, train_seq, val_seq, test_seq, data_scaler = svdpreprocessing(Tensor, Ared, esvd, sensors, Time, batch_size, seq_len, horizon, 
                                                                               scaler_type, scaler_name)

    print(colored('Step 2: Model definition', 'red', attrs=["bold"]))
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    
    model = DLinear(sequence = seq_len, horizon = horizon, kernel_size = seq_len + 1 if 
                    (seq_len + 1) % 2 != 0 else seq_len, individual = True, input_size = n_modes)

    model.to(device)
    print(model)
    total_params = sum(p.numel() for p in model.parameters())
    learn_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'Total parameters: {total_params}')
    print(f'Learnable parameters: {learn_params}')

    print(colored('Step 3: Model training with optimal hyperparams.', 'red', attrs=["bold"]))
    all_losses = []
    loss_fn = nn.MSELoss()

    if not optimal:
        learning_rate = 0.000174
        batch_size = 4
        optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

    else:
        train_loader, val_loader, learning_rate, weight_decay = hyperFinder(train_ds, val_ds, model, device)
        # Reinstanciate the model to avoid data leaking
        del model
        model = DLinear(sequence = seq_len, horizon = horizon, kernel_size = seq_len + 1 if 
                    (seq_len + 1) % 2 != 0 else seq_len, individual = True, input_size = n_modes)

        optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate, weight_decay = weight_decay)

    lr_patience = 10   
    es_patience = 15
    factor = 0.5

    lr_scheduler = LRScheduler(lr = learning_rate, optimizer = optimizer, patience = lr_patience, factor = factor)
    early_stopper = EarlyStopping(patience = es_patience, model_save_path = model_save_path)

    for epoch in range(epochs):
        train_loss = train_model(train_loader, model, loss_fn, optimizer, device)
        val_loss = val_model(val_loader, model, loss_fn, device)
        all_losses.append([train_loss, val_loss])

        print(f'\nEpoch [{epoch}/{epochs - 1}] - Train Loss: {train_loss:.6f} - Val Loss: {val_loss:.6f}')

        early_stopper(epoch, model, val_loss)
        if early_stopper.early_stop:
            break

        lr_scheduler(val_loss)

    print('Model trained successfully!')
    print(f'Best model has been saved as: {model_save_path}')

    print(colored('Step 4: Load the best epoch and plot the losses', 'red', attrs=["bold"]))
    model.load_state_dict(torch.load(model_save_path))
    model.eval()
    print('Model loaded')

    fig, ax = plt.subplots(1, 1, figsize = (6, 6))
    ax.plot(np.array(all_losses)[:, 0].reshape(-1, 1), c = 'k', label = 'Train loss')
    ax.plot(np.array(all_losses)[:, 1].reshape(-1, 1), c = 'r', label = 'Validation loss')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('MSE')
    ax.set_title('Training vs. Validation loss')
    ax.legend(loc = 'best')
    plt.show()

    print(colored('Step 5: Validate the model on test data' 'red', attrs=["bold"]))
    preds = []

    X = test_seq[0][np.newaxis, :, :].astype(float) 

    print(f'Input tensor (first sequence from the test data): {X.shape}')

    seq = torch.tensor(X.copy()).float().to(device) 

    num_snaps = test_data.shape[-1]

    with torch.no_grad():
        for i in range(num_snaps):
            y = model(seq)
            pred = y.detach().cpu().numpy()
            preds.append(data_scaler.inverse_transform(pred )) # de-scale data
            seq = torch.cat((seq, y[None, :, :]), axis = 1)
            seq = seq[:, -seq_len:, :]

    pred = U @ S @ np.array(preds).squeeze().T

    shape_ = test_data.shape

    pred = np.reshape(pred, shape_)

    RRMSE = np.linalg.norm(np.reshape(test_data - np.array(pred), newshape=(np.size(test_data), 1)), ord = 2) / np.linalg.norm(np.reshape(test_data, newshape = (np.size(test_data), 1))) * 100

    print(f'''
    Error summary
    RRMSE [%]: {RRMSE:.3f}
    MAE: {compute_MAE(test[:, seq_len:].T, np.array(preds).squeeze()):.3f}
    MSE: {compute_MSE(test[:, seq_len:].T, np.array(preds).squeeze()):.3f}
    ''')

    fig, ax = plt.subplots(2, 2, figsize = (10, 10))
    labels = ['Ground truth', 'Forecast']
    for i, axs in zip(range(4), ax.flatten()):
        test_modes = data_scaler.inverse_transform(test.T)[seq_len:, i].squeeze() 
        axs.plot(test_modes, c = 'k')
        axs.plot(np.array(preds)[..., i].squeeze(), alpha = 0.7, c = 'red')
        axs.set(title = f'Mode: {i + 1}')
        if i <= 1:
            axs.set(xticks = [])

    fig.tight_layout()
    fig.subplots_adjust(bottom = 0.1075)
    fig.legend(labels=labels, loc="lower center", ncol=2)

    print(colored('Step 6: Forecast new snapshots', 'red', attrs=["bold"]))

    X = test_seq[-1][np.newaxis, :, :].astype(float) 

    print(f'Input tensor (last sequence from the test data): {X.shape}')

    seq = torch.tensor(X.copy()).float().to(device) 

    preds = [] 

    num_snaps = snapshots

    with torch.no_grad():
        for i in range(num_snaps):
            y = model(seq)
            pred = y.detach().cpu().numpy()
            preds.append(data_scaler.inverse_transform(pred) ) # de-scale data
            seq = torch.cat((seq, y[None, :, :]), axis = 1)
            seq = seq[:, -seq_len:, :]
    
    forecast_sV = np.array(preds)

    print(f'Prediction shape [V.T]: {forecast_sV.squeeze().shape}')

    indxs = np.arange(len(np.array(test.T)), len(np.array(preds)) + len(np.array(test.T)))
    test_indxs = np.arange(len(np.array(test.T)))

    labels = ['Test data', 'Forecast']

    fig, ax = plt.subplots(2, 2, figsize = (10, 10))
    for i, axs in zip(range(4), ax.flatten()):
        axs.plot(data_scaler.inverse_transform(test.T)[:, i].squeeze() , c = 'k')
        axs.plot(indxs, np.array(preds)[..., i].squeeze(), c = 'red', alpha = 0.7)
        axs.set(title = f'Mode: {i + 1}')
        if i <= 1:
            axs.set(xticks = [])
    
    fig.tight_layout()
    fig.subplots_adjust(bottom = 0.1075)
    fig.legend(labels=labels, loc="lower center", ncol=2)
    
    plt.show()

    print(colored('Step 7: Reconstruct the new snapshots', 'red', attrs=["bold"]))
    forecast = U @ S @ (np.concatenate([data_scaler.inverse_transform(test.transpose(1, 0)), forecast_sV.squeeze()], axis = 0).T )

    nv, ny, nx, _ = Tensor.shape
    forecast = forecast.reshape((nv, ny, nx, -1))
    nz = None
        
    print(f'''
    Number of components: {nv}
    Number of points in x: {nx}
    Number of points in y: {ny}
    Number of points in z: {nz}
    ''')

    print(f'Reconstructed test + forecast data: {forecast.shape}')

    return test_data, forecast, test

# %% [markdown]
# ### Training and testing the model

# %%
# Select the parameters
esvd = 1e-2
seq_len = 30
horizon = 1
scaler_type = 'minmax'
batch_size = 4
snapshots = 500
optimal = True
epochs = 1000

# Preprocess the data and train the model
test_data, forecast, test = generator(numericalTensor, syntheticExperimentalTensor, esvd, sensors, Time, seq_len, horizon, batch_size, 
                                      epochs, scaler_type, optimal, snapshots)
# Out:
# Step 1: Data preprocessing
#
# Low-cost singular value decomposition summary
#         - n_modes (retained modes): 8
#         - U (POD modes): (178702, 8)
#         - S (singular values): (8, 8)
#         - V (temporal coefficients): (8, 151)
#         - TensorAprox (reconstructed tensor): (2, 199, 449, 151)
# Scaling the data...
# [I 2025-03-27 20:45:46,678] A new study created in memory with name: no-name-89e03cc4-b5a8-494a-899f-6dba5fac9158
# Split summary
#     - Train samples: (8, 105)
#     - Validation samples: (8, 52)
#     - Test samples: (8, 54)
#
# Creating data sequences...
#
# Creating PyTorch datasets...
#
# Generating data loaders...
#
# Singular batch of the features (sequence): torch.Size([4, 30, 8])
# Singular batch of the target (horizon): torch.Size([4, 8])
#
# Data preprocessing complete!
# Step 2: Model definition
# DLinear(
#   (decomposition): series_descomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(31,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): ModuleList(
#     (0-7): 8 x Linear(in_features=30, out_features=1, bias=True)
#   )
#   (Linear_Trend): ModuleList(
#     (0-7): 8 x Linear(in_features=30, out_features=1, bias=True)
#   )
# )
# Total parameters: 496
# Learnable parameters: 496
# Step 3: Model training with optimal hyperparams.
# [I 2025-03-27 20:45:47,683] Trial 0 finished with value: 0.4515654742717743 and parameters: {'weight_decay': 1.293919892027807e-13, 'lr': 0.0058462972192124965, 'batch_size': 32}. Best is trial 0 with value: 0.4515654742717743.
# [I 2025-03-27 20:45:51,319] Trial 1 finished with value: 0.011507481336593628 and parameters: {'weight_decay': 4.932348788810074e-06, 'lr': 0.0047979295077059565, 'batch_size': 8}. Best is trial 1 with value: 0.011507481336593628.
# [I 2025-03-27 20:45:54,802] Trial 2 finished with value: 0.00115353858564049 and parameters: {'weight_decay': 1.8168859154384657e-09, 'lr': 0.00010094719273730145, 'batch_size': 8}. Best is trial 2 with value: 0.00115353858564049.
# [I 2025-03-27 20:45:55,637] Trial 3 finished with value: 0.0011192905949428678 and parameters: {'weight_decay': 4.162432510308473e-05, 'lr': 0.0003795713867423366, 'batch_size': 32}. Best is trial 3 with value: 0.0011192905949428678.
# [I 2025-03-27 20:45:59,118] Trial 4 finished with value: 0.0036048591136932373 and parameters: {'weight_decay': 8.421731345308505e-05, 'lr': 0.0031375199456488874, 'batch_size': 8}. Best is trial 3 with value: 0.0011192905949428678.
# [I 2025-03-27 20:46:06,368] Trial 5 finished with value: 0.0007200961117632687 and parameters: {'weight_decay': 3.2133006532396896e-12, 'lr': 0.00016003230454291148, 'batch_size': 4}. Best is trial 5 with value: 0.0007200961117632687.
# [I 2025-03-27 20:46:08,203] Trial 6 finished with value: 0.0005214449483901262 and parameters: {'weight_decay': 7.473211109012365e-11, 'lr': 0.00033344810080058486, 'batch_size': 16}. Best is trial 6 with value: 0.0005214449483901262.
# [I 2025-03-27 20:46:08,260] Trial 7 pruned.
# [I 2025-03-27 20:46:15,683] Trial 8 finished with value: 0.0008014285122044384 and parameters: {'weight_decay': 2.442016364224564e-09, 'lr': 0.0005846145524593627, 'batch_size': 4}. Best is trial 6 with value: 0.0005214449483901262.
# [I 2025-03-27 20:46:15,704] Trial 9 pruned.
# [I 2025-03-27 20:46:15,768] Trial 10 pruned.
# [I 2025-03-27 20:46:23,417] Trial 11 finished with value: 0.0003679275687318295 and parameters: {'weight_decay': 1.3945800077455035e-12, 'lr': 0.0001256170922277133, 'batch_size': 4}. Best is trial 11 with value: 0.0003679275687318295.
# [I 2025-03-27 20:46:30,965] Trial 12 finished with value: 0.0003886745835188776 and parameters: {'weight_decay': 1.122819879949163e-11, 'lr': 0.00020183543472115782, 'batch_size': 4}. Best is trial 11 with value: 0.0003679275687318295.
# [I 2025-03-27 20:46:38,857] Trial 13 finished with value: 0.00031074261642061174 and parameters: {'weight_decay': 2.637482594046551e-15, 'lr': 0.00015136896988587222, 'batch_size': 4}. Best is trial 13 with value: 0.00031074261642061174.
# [I 2025-03-27 20:46:39,033] Trial 14 pruned.
# [I 2025-03-27 20:46:46,999] Trial 15 finished with value: 0.0002569715434219688 and parameters: {'weight_decay': 1.6370214683361555e-13, 'lr': 0.00010329894817303504, 'batch_size': 4}. Best is trial 15 with value: 0.0002569715434219688.
# [I 2025-03-27 20:46:55,699] Trial 16 finished with value: 0.00029669987270608544 and parameters: {'weight_decay': 1.0099391905590856e-13, 'lr': 0.0002042155838562816, 'batch_size': 4}. Best is trial 15 with value: 0.0002569715434219688.
# [I 2025-03-27 20:47:04,115] Trial 17 finished with value: 0.00028636326896958053 and parameters: {'weight_decay': 8.650859699144053e-14, 'lr': 0.00024785324316138683, 'batch_size': 4}. Best is trial 15 with value: 0.0002569715434219688.
# [I 2025-03-27 20:47:04,298] Trial 18 pruned.
# [I 2025-03-27 20:47:04,482] Trial 19 pruned.
# [I 2025-03-27 20:47:04,665] Trial 20 pruned.
# [I 2025-03-27 20:47:04,848] Trial 21 pruned.
# [I 2025-03-27 20:47:05,032] Trial 22 pruned.
# [I 2025-03-27 20:47:05,200] Trial 23 pruned.
# [I 2025-03-27 20:47:05,365] Trial 24 pruned.
# [I 2025-03-27 20:47:14,331] Trial 25 finished with value: 0.0005151116638444364 and parameters: {'weight_decay': 1.4860831019786593e-07, 'lr': 0.0001663097222290412, 'batch_size': 4}. Best is trial 15 with value: 0.0002569715434219688.
# [I 2025-03-27 20:47:14,380] Trial 26 pruned.
# [I 2025-03-27 20:47:14,481] Trial 27 pruned.
# [I 2025-03-27 20:47:14,547] Trial 28 pruned.
# [I 2025-03-27 20:47:14,581] Trial 29 pruned.
# [I 2025-03-27 20:47:22,982] Trial 30 finished with value: 0.00036809532321058214 and parameters: {'weight_decay': 1.1327570919232957e-14, 'lr': 0.0002417881884317538, 'batch_size': 4}. Best is trial 15 with value: 0.0002569715434219688.
# [I 2025-03-27 20:47:31,600] Trial 31 finished with value: 0.000260785105638206 and parameters: {'weight_decay': 1.3348054169889502e-15, 'lr': 0.00015953459651096285, 'batch_size': 4}. Best is trial 15 with value: 0.0002569715434219688.
# [I 2025-03-27 20:47:39,863] Trial 32 finished with value: 0.0002539170382078737 and parameters: {'weight_decay': 1.156884162479737e-15, 'lr': 0.0001813862929429358, 'batch_size': 4}. Best is trial 32 with value: 0.0002539170382078737.
# [I 2025-03-27 20:47:48,346] Trial 33 finished with value: 0.00018983073823619634 and parameters: {'weight_decay': 1.0588735327347961e-15, 'lr': 0.0001259180680647244, 'batch_size': 4}. Best is trial 33 with value: 0.00018983073823619634.
# [I 2025-03-27 20:47:52,678] Trial 34 finished with value: 0.00015908195928204805 and parameters: {'weight_decay': 1.820475952228296e-15, 'lr': 0.00010127788595268838, 'batch_size': 8}. Best is trial 34 with value: 0.00015908195928204805.
# [I 2025-03-27 20:47:56,745] Trial 35 finished with value: 0.00015436267131008208 and parameters: {'weight_decay': 6.467996673588444e-15, 'lr': 0.00010743636256942168, 'batch_size': 8}. Best is trial 35 with value: 0.00015436267131008208.
# [I 2025-03-27 20:48:01,019] Trial 36 finished with value: 0.00015486155461985618 and parameters: {'weight_decay': 4.746334322549909e-15, 'lr': 0.00012135111138667516, 'batch_size': 8}. Best is trial 35 with value: 0.00015436267131008208.
# [I 2025-03-27 20:48:05,445] Trial 37 finished with value: 0.00014627193741034716 and parameters: {'weight_decay': 7.36004013760396e-15, 'lr': 0.00012797106728432449, 'batch_size': 8}. Best is trial 37 with value: 0.00014627193741034716.
# [I 2025-03-27 20:48:10,978] Trial 38 finished with value: 0.00014027883298695087 and parameters: {'weight_decay': 1.1765020164519492e-14, 'lr': 0.00012817095668094154, 'batch_size': 8}. Best is trial 38 with value: 0.00014027883298695087.
# [I 2025-03-27 20:48:15,998] Trial 39 finished with value: 0.00013524452515412122 and parameters: {'weight_decay': 4.158103088721538e-12, 'lr': 0.00013311603501499944, 'batch_size': 8}. Best is trial 39 with value: 0.00013524452515412122.
# [I 2025-03-27 20:48:21,096] Trial 40 finished with value: 0.00013359596778173 and parameters: {'weight_decay': 1.0709296234655679e-11, 'lr': 0.00014594405668461638, 'batch_size': 8}. Best is trial 40 with value: 0.00013359596778173.
# [I 2025-03-27 20:48:26,244] Trial 41 finished with value: 0.0001283178135054186 and parameters: {'weight_decay': 3.6369191134480476e-12, 'lr': 0.00015122484524589773, 'batch_size': 8}. Best is trial 41 with value: 0.0001283178135054186.
# [I 2025-03-27 20:48:31,245] Trial 42 finished with value: 0.00012042972230119631 and parameters: {'weight_decay': 6.248748564798894e-12, 'lr': 0.000149030310150752, 'batch_size': 8}. Best is trial 42 with value: 0.00012042972230119631.
# [I 2025-03-27 20:48:36,227] Trial 43 finished with value: 0.00011327559332130477 and parameters: {'weight_decay': 7.578176977817944e-12, 'lr': 0.00014642924278367498, 'batch_size': 8}. Best is trial 43 with value: 0.00011327559332130477.
# [I 2025-03-27 20:48:36,360] Trial 44 pruned.
# [I 2025-03-27 20:48:41,276] Trial 45 finished with value: 0.00013904321531299502 and parameters: {'weight_decay': 7.0819373032053e-11, 'lr': 0.00029711801931614756, 'batch_size': 8}. Best is trial 43 with value: 0.00011327559332130477.
# [I 2025-03-27 20:48:41,380] Trial 46 pruned.
# [I 2025-03-27 20:48:41,493] Trial 47 pruned.
# [I 2025-03-27 20:48:41,624] Trial 48 pruned.
# [I 2025-03-27 20:48:41,760] Trial 49 pruned.
# Study statistics:
#      Number of finished trials:  50
#      Number of pruned trials:  20
#      Number of completed trials:  30
# Best trial:
#      Value:  0.00011327559332130477
#      Params:
#     weight_decay: 7.578176977817944e-12
#     lr: 0.00014642924278367498
#     batch_size: 8
#
# Epoch [0/999] - Train Loss: 0.303566 - Val Loss: 0.272469
#
# Epoch [1/999] - Train Loss: 0.282194 - Val Loss: 0.250712
#
# Epoch [2/999] - Train Loss: 0.259735 - Val Loss: 0.230003
#
# Epoch [3/999] - Train Loss: 0.235847 - Val Loss: 0.210757
#
# Epoch [4/999] - Train Loss: 0.216951 - Val Loss: 0.192830
#
# Epoch [5/999] - Train Loss: 0.196296 - Val Loss: 0.176485
#
# Epoch [6/999] - Train Loss: 0.179392 - Val Loss: 0.161097
#
# Epoch [7/999] - Train Loss: 0.163774 - Val Loss: 0.147189
#
# Epoch [8/999] - Train Loss: 0.150640 - Val Loss: 0.134351
#
# Epoch [9/999] - Train Loss: 0.135353 - Val Loss: 0.122611
#
# Epoch [10/999] - Train Loss: 0.125472 - Val Loss: 0.111657
#
# Epoch [11/999] - Train Loss: 0.112720 - Val Loss: 0.101660
#
# Epoch [12/999] - Train Loss: 0.101988 - Val Loss: 0.092768
#
# Epoch [13/999] - Train Loss: 0.093519 - Val Loss: 0.084565
#
# Epoch [14/999] - Train Loss: 0.085568 - Val Loss: 0.076985
#
# Epoch [15/999] - Train Loss: 0.076198 - Val Loss: 0.070241
#
# Epoch [16/999] - Train Loss: 0.070193 - Val Loss: 0.064071
#
# Epoch [17/999] - Train Loss: 0.063657 - Val Loss: 0.058475
#
# Epoch [18/999] - Train Loss: 0.057505 - Val Loss: 0.053470
#
# Epoch [19/999] - Train Loss: 0.052993 - Val Loss: 0.048941
#
# Epoch [20/999] - Train Loss: 0.048185 - Val Loss: 0.044811
#
# Epoch [21/999] - Train Loss: 0.043991 - Val Loss: 0.041042
#
# Epoch [22/999] - Train Loss: 0.039961 - Val Loss: 0.037696
#
# Epoch [23/999] - Train Loss: 0.036251 - Val Loss: 0.034665
#
# Epoch [24/999] - Train Loss: 0.033730 - Val Loss: 0.031949
#
# Epoch [25/999] - Train Loss: 0.030613 - Val Loss: 0.029505
#
# Epoch [26/999] - Train Loss: 0.028094 - Val Loss: 0.027302
#
# Epoch [27/999] - Train Loss: 0.026092 - Val Loss: 0.025323
#
# Epoch [28/999] - Train Loss: 0.024205 - Val Loss: 0.023537
#
# Epoch [29/999] - Train Loss: 0.021910 - Val Loss: 0.021887
#
# Epoch [30/999] - Train Loss: 0.020450 - Val Loss: 0.020396
#
# Epoch [31/999] - Train Loss: 0.018957 - Val Loss: 0.019036
#
# Epoch [32/999] - Train Loss: 0.017765 - Val Loss: 0.017807
#
# Epoch [33/999] - Train Loss: 0.016280 - Val Loss: 0.016695
#
# Epoch [34/999] - Train Loss: 0.015217 - Val Loss: 0.015683
#
# Epoch [35/999] - Train Loss: 0.014214 - Val Loss: 0.014790
#
# Epoch [36/999] - Train Loss: 0.013288 - Val Loss: 0.013957
#
# Epoch [37/999] - Train Loss: 0.012485 - Val Loss: 0.013196
#
# Epoch [38/999] - Train Loss: 0.011911 - Val Loss: 0.012447
#
# Epoch [39/999] - Train Loss: 0.010988 - Val Loss: 0.011766
#
# Epoch [40/999] - Train Loss: 0.010555 - Val Loss: 0.011152
#
# Epoch [41/999] - Train Loss: 0.009925 - Val Loss: 0.010575
#
# Epoch [42/999] - Train Loss: 0.009364 - Val Loss: 0.010041
#
# Epoch [43/999] - Train Loss: 0.008899 - Val Loss: 0.009537
#
# Epoch [44/999] - Train Loss: 0.008290 - Val Loss: 0.009078
#
# Epoch [45/999] - Train Loss: 0.007878 - Val Loss: 0.008642
#
# Epoch [46/999] - Train Loss: 0.007451 - Val Loss: 0.008252
#
# Epoch [47/999] - Train Loss: 0.007166 - Val Loss: 0.007883
#
# Epoch [48/999] - Train Loss: 0.006774 - Val Loss: 0.007514
#
# Epoch [49/999] - Train Loss: 0.006506 - Val Loss: 0.007184
#
# Epoch [50/999] - Train Loss: 0.006126 - Val Loss: 0.006882
#
# Epoch [51/999] - Train Loss: 0.005876 - Val Loss: 0.006586
#
# Epoch [52/999] - Train Loss: 0.005657 - Val Loss: 0.006301
#
# Epoch [53/999] - Train Loss: 0.005264 - Val Loss: 0.006050
#
# Epoch [54/999] - Train Loss: 0.005135 - Val Loss: 0.005798
#
# Epoch [55/999] - Train Loss: 0.004968 - Val Loss: 0.005554
#
# Epoch [56/999] - Train Loss: 0.004766 - Val Loss: 0.005330
#
# Epoch [57/999] - Train Loss: 0.004534 - Val Loss: 0.005108
#
# Epoch [58/999] - Train Loss: 0.004240 - Val Loss: 0.004906
#
# Epoch [59/999] - Train Loss: 0.004143 - Val Loss: 0.004729
#
# Epoch [60/999] - Train Loss: 0.004018 - Val Loss: 0.004535
#
# Epoch [61/999] - Train Loss: 0.003905 - Val Loss: 0.004363
#
# Epoch [62/999] - Train Loss: 0.003772 - Val Loss: 0.004194
#
# Epoch [63/999] - Train Loss: 0.003626 - Val Loss: 0.004037
#
# Epoch [64/999] - Train Loss: 0.003406 - Val Loss: 0.003886
#
# Epoch [65/999] - Train Loss: 0.003299 - Val Loss: 0.003744
#
# Epoch [66/999] - Train Loss: 0.003246 - Val Loss: 0.003613
#
# Epoch [67/999] - Train Loss: 0.003161 - Val Loss: 0.003476
#
# Epoch [68/999] - Train Loss: 0.003002 - Val Loss: 0.003363
#
# Epoch [69/999] - Train Loss: 0.002997 - Val Loss: 0.003248
#
# Epoch [70/999] - Train Loss: 0.002822 - Val Loss: 0.003142
#
# Epoch [71/999] - Train Loss: 0.002827 - Val Loss: 0.003036
#
# Epoch [72/999] - Train Loss: 0.002672 - Val Loss: 0.002934
#
# Epoch [73/999] - Train Loss: 0.002636 - Val Loss: 0.002835
#
# Epoch [74/999] - Train Loss: 0.002557 - Val Loss: 0.002745
#
# Epoch [75/999] - Train Loss: 0.002494 - Val Loss: 0.002660
#
# Epoch [76/999] - Train Loss: 0.002438 - Val Loss: 0.002576
#
# Epoch [77/999] - Train Loss: 0.002364 - Val Loss: 0.002504
#
# Epoch [78/999] - Train Loss: 0.002245 - Val Loss: 0.002429
#
# Epoch [79/999] - Train Loss: 0.002236 - Val Loss: 0.002361
#
# Epoch [80/999] - Train Loss: 0.002180 - Val Loss: 0.002290
#
# Epoch [81/999] - Train Loss: 0.002072 - Val Loss: 0.002234
#
# Epoch [82/999] - Train Loss: 0.002047 - Val Loss: 0.002178
#
# Epoch [83/999] - Train Loss: 0.002045 - Val Loss: 0.002129
#
# Epoch [84/999] - Train Loss: 0.001977 - Val Loss: 0.002069
#
# Epoch [85/999] - Train Loss: 0.001917 - Val Loss: 0.002018
#
# Epoch [86/999] - Train Loss: 0.001868 - Val Loss: 0.001973
#
# Epoch [87/999] - Train Loss: 0.001865 - Val Loss: 0.001925
#
# Epoch [88/999] - Train Loss: 0.001800 - Val Loss: 0.001882
#
# Epoch [89/999] - Train Loss: 0.001767 - Val Loss: 0.001838
#
# Epoch [90/999] - Train Loss: 0.001757 - Val Loss: 0.001795
#
# Epoch [91/999] - Train Loss: 0.001695 - Val Loss: 0.001752
#
# Epoch [92/999] - Train Loss: 0.001641 - Val Loss: 0.001722
#
# Epoch [93/999] - Train Loss: 0.001650 - Val Loss: 0.001686
#
# Epoch [94/999] - Train Loss: 0.001625 - Val Loss: 0.001651
#
# Epoch [95/999] - Train Loss: 0.001562 - Val Loss: 0.001614
#
# Epoch [96/999] - Train Loss: 0.001564 - Val Loss: 0.001577
#
# Epoch [97/999] - Train Loss: 0.001531 - Val Loss: 0.001546
#
# Epoch [98/999] - Train Loss: 0.001510 - Val Loss: 0.001513
#
# Epoch [99/999] - Train Loss: 0.001505 - Val Loss: 0.001487
#
# Epoch [100/999] - Train Loss: 0.001480 - Val Loss: 0.001462
#
# Epoch [101/999] - Train Loss: 0.001469 - Val Loss: 0.001440
#
# Epoch [102/999] - Train Loss: 0.001425 - Val Loss: 0.001412
#
# Epoch [103/999] - Train Loss: 0.001421 - Val Loss: 0.001390
#
# Epoch [104/999] - Train Loss: 0.001378 - Val Loss: 0.001364
#
# Epoch [105/999] - Train Loss: 0.001365 - Val Loss: 0.001346
#
# Epoch [106/999] - Train Loss: 0.001342 - Val Loss: 0.001328
#
# Epoch [107/999] - Train Loss: 0.001314 - Val Loss: 0.001309
#
# Epoch [108/999] - Train Loss: 0.001292 - Val Loss: 0.001283
#
# Epoch [109/999] - Train Loss: 0.001310 - Val Loss: 0.001263
#
# Epoch [110/999] - Train Loss: 0.001288 - Val Loss: 0.001240
#
# Epoch [111/999] - Train Loss: 0.001253 - Val Loss: 0.001222
#
# Epoch [112/999] - Train Loss: 0.001226 - Val Loss: 0.001205
#
# Epoch [113/999] - Train Loss: 0.001234 - Val Loss: 0.001190
#
# Epoch [114/999] - Train Loss: 0.001222 - Val Loss: 0.001175
#
# Epoch [115/999] - Train Loss: 0.001198 - Val Loss: 0.001163
#
# Epoch [116/999] - Train Loss: 0.001179 - Val Loss: 0.001147
#
# Epoch [117/999] - Train Loss: 0.001152 - Val Loss: 0.001135
#
# Epoch [118/999] - Train Loss: 0.001167 - Val Loss: 0.001119
#
# Epoch [119/999] - Train Loss: 0.001119 - Val Loss: 0.001100
#
# Epoch [120/999] - Train Loss: 0.001153 - Val Loss: 0.001090
#
# Epoch [121/999] - Train Loss: 0.001116 - Val Loss: 0.001072
#
# Epoch [122/999] - Train Loss: 0.001097 - Val Loss: 0.001057
#
# Epoch [123/999] - Train Loss: 0.001085 - Val Loss: 0.001047
#
# Epoch [124/999] - Train Loss: 0.001080 - Val Loss: 0.001032
#
# Epoch [125/999] - Train Loss: 0.001056 - Val Loss: 0.001019
#
# Epoch [126/999] - Train Loss: 0.001073 - Val Loss: 0.001010
#
# Epoch [127/999] - Train Loss: 0.001059 - Val Loss: 0.000993
#
# Epoch [128/999] - Train Loss: 0.001031 - Val Loss: 0.000988
#
# Epoch [129/999] - Train Loss: 0.001035 - Val Loss: 0.000980
#
# Epoch [130/999] - Train Loss: 0.001037 - Val Loss: 0.000970
#
# Epoch [131/999] - Train Loss: 0.001006 - Val Loss: 0.000964
#
# Epoch [132/999] - Train Loss: 0.000993 - Val Loss: 0.000954
#
# Epoch [133/999] - Train Loss: 0.000996 - Val Loss: 0.000947
#
# Epoch [134/999] - Train Loss: 0.000986 - Val Loss: 0.000936
#
# Epoch [135/999] - Train Loss: 0.000969 - Val Loss: 0.000927
#
# Epoch [136/999] - Train Loss: 0.000957 - Val Loss: 0.000920
#
# Epoch [137/999] - Train Loss: 0.000970 - Val Loss: 0.000918
#
# Epoch [138/999] - Train Loss: 0.000963 - Val Loss: 0.000908
#
# Epoch [139/999] - Train Loss: 0.000951 - Val Loss: 0.000896
#
# Epoch [140/999] - Train Loss: 0.000943 - Val Loss: 0.000890
#
# Epoch [141/999] - Train Loss: 0.000933 - Val Loss: 0.000884
#
# Epoch [142/999] - Train Loss: 0.000914 - Val Loss: 0.000876
#
# Epoch [143/999] - Train Loss: 0.000914 - Val Loss: 0.000869
#
# Epoch [144/999] - Train Loss: 0.000913 - Val Loss: 0.000866
#
# Epoch [145/999] - Train Loss: 0.000900 - Val Loss: 0.000855
#
# Epoch [146/999] - Train Loss: 0.000893 - Val Loss: 0.000848
#
# Epoch [147/999] - Train Loss: 0.000890 - Val Loss: 0.000844
#
# Epoch [148/999] - Train Loss: 0.000879 - Val Loss: 0.000837
#
# Epoch [149/999] - Train Loss: 0.000872 - Val Loss: 0.000836
#
# Epoch [150/999] - Train Loss: 0.000864 - Val Loss: 0.000824
#
# Epoch [151/999] - Train Loss: 0.000857 - Val Loss: 0.000816
#
# Epoch [152/999] - Train Loss: 0.000843 - Val Loss: 0.000811
#
# Epoch [153/999] - Train Loss: 0.000846 - Val Loss: 0.000803
#
# Epoch [154/999] - Train Loss: 0.000847 - Val Loss: 0.000797
#
# Epoch [155/999] - Train Loss: 0.000840 - Val Loss: 0.000791
#
# Epoch [156/999] - Train Loss: 0.000840 - Val Loss: 0.000784
#
# Epoch [157/999] - Train Loss: 0.000819 - Val Loss: 0.000782
#
# Epoch [158/999] - Train Loss: 0.000822 - Val Loss: 0.000776
#
# Epoch [159/999] - Train Loss: 0.000825 - Val Loss: 0.000771
#
# Epoch [160/999] - Train Loss: 0.000818 - Val Loss: 0.000766
#
# Epoch [161/999] - Train Loss: 0.000801 - Val Loss: 0.000763
#
# Epoch [162/999] - Train Loss: 0.000799 - Val Loss: 0.000761
#
# Epoch [163/999] - Train Loss: 0.000795 - Val Loss: 0.000756
#
# Epoch [164/999] - Train Loss: 0.000794 - Val Loss: 0.000750
#
# Epoch [165/999] - Train Loss: 0.000793 - Val Loss: 0.000749
#
# Epoch [166/999] - Train Loss: 0.000783 - Val Loss: 0.000747
#
# Epoch [167/999] - Train Loss: 0.000795 - Val Loss: 0.000742
#
# Epoch [168/999] - Train Loss: 0.000782 - Val Loss: 0.000739
#
# Epoch [169/999] - Train Loss: 0.000772 - Val Loss: 0.000736
#
# Epoch [170/999] - Train Loss: 0.000774 - Val Loss: 0.000733
#
# Epoch [171/999] - Train Loss: 0.000766 - Val Loss: 0.000725
#
# Epoch [172/999] - Train Loss: 0.000759 - Val Loss: 0.000720
#
# Epoch [173/999] - Train Loss: 0.000761 - Val Loss: 0.000711
#
# Epoch [174/999] - Train Loss: 0.000756 - Val Loss: 0.000714
#
# Epoch [175/999] - Train Loss: 0.000735 - Val Loss: 0.000709
#
# Epoch [176/999] - Train Loss: 0.000742 - Val Loss: 0.000705
#
# Epoch [177/999] - Train Loss: 0.000735 - Val Loss: 0.000696
#
# Epoch [178/999] - Train Loss: 0.000734 - Val Loss: 0.000690
#
# Epoch [179/999] - Train Loss: 0.000734 - Val Loss: 0.000686
#
# Epoch [180/999] - Train Loss: 0.000722 - Val Loss: 0.000680
#
# Epoch [181/999] - Train Loss: 0.000731 - Val Loss: 0.000682
#
# Epoch [182/999] - Train Loss: 0.000719 - Val Loss: 0.000681
#
# Epoch [183/999] - Train Loss: 0.000707 - Val Loss: 0.000679
#
# Epoch [184/999] - Train Loss: 0.000712 - Val Loss: 0.000674
#
# Epoch [185/999] - Train Loss: 0.000698 - Val Loss: 0.000677
#
# Epoch [186/999] - Train Loss: 0.000701 - Val Loss: 0.000672
#
# Epoch [187/999] - Train Loss: 0.000701 - Val Loss: 0.000666
#
# Epoch [188/999] - Train Loss: 0.000693 - Val Loss: 0.000660
#
# Epoch [189/999] - Train Loss: 0.000693 - Val Loss: 0.000657
#
# Epoch [190/999] - Train Loss: 0.000674 - Val Loss: 0.000655
#
# Epoch [191/999] - Train Loss: 0.000681 - Val Loss: 0.000652
#
# Epoch [192/999] - Train Loss: 0.000685 - Val Loss: 0.000645
#
# Epoch [193/999] - Train Loss: 0.000676 - Val Loss: 0.000645
#
# Epoch [194/999] - Train Loss: 0.000676 - Val Loss: 0.000636
#
# Epoch [195/999] - Train Loss: 0.000666 - Val Loss: 0.000637
#
# Epoch [196/999] - Train Loss: 0.000656 - Val Loss: 0.000635
#
# Epoch [197/999] - Train Loss: 0.000662 - Val Loss: 0.000631
#
# Epoch [198/999] - Train Loss: 0.000660 - Val Loss: 0.000630
#
# Epoch [199/999] - Train Loss: 0.000653 - Val Loss: 0.000626
#
# Epoch [200/999] - Train Loss: 0.000658 - Val Loss: 0.000626
#
# Epoch [201/999] - Train Loss: 0.000647 - Val Loss: 0.000621
#
# Epoch [202/999] - Train Loss: 0.000649 - Val Loss: 0.000614
#
# Epoch [203/999] - Train Loss: 0.000631 - Val Loss: 0.000610
#
# Epoch [204/999] - Train Loss: 0.000624 - Val Loss: 0.000608
#
# Epoch [205/999] - Train Loss: 0.000636 - Val Loss: 0.000608
#
# Epoch [206/999] - Train Loss: 0.000630 - Val Loss: 0.000609
#
# Epoch [207/999] - Train Loss: 0.000631 - Val Loss: 0.000610
#
# Epoch [208/999] - Train Loss: 0.000637 - Val Loss: 0.000607
#
# Epoch [209/999] - Train Loss: 0.000630 - Val Loss: 0.000601
#
# Epoch [210/999] - Train Loss: 0.000616 - Val Loss: 0.000599
#
# Epoch [211/999] - Train Loss: 0.000616 - Val Loss: 0.000592
#
# Epoch [212/999] - Train Loss: 0.000613 - Val Loss: 0.000590
#
# Epoch [213/999] - Train Loss: 0.000621 - Val Loss: 0.000586
#
# Epoch [214/999] - Train Loss: 0.000609 - Val Loss: 0.000581
#
# Epoch [215/999] - Train Loss: 0.000617 - Val Loss: 0.000579
#
# Epoch [216/999] - Train Loss: 0.000604 - Val Loss: 0.000577
#
# Epoch [217/999] - Train Loss: 0.000599 - Val Loss: 0.000574
#
# Epoch [218/999] - Train Loss: 0.000605 - Val Loss: 0.000570
#
# Epoch [219/999] - Train Loss: 0.000596 - Val Loss: 0.000568
#
# Epoch [220/999] - Train Loss: 0.000595 - Val Loss: 0.000564
#
# Epoch [221/999] - Train Loss: 0.000592 - Val Loss: 0.000563
#
# Epoch [222/999] - Train Loss: 0.000594 - Val Loss: 0.000558
#
# Epoch [223/999] - Train Loss: 0.000596 - Val Loss: 0.000558
#
# Epoch [224/999] - Train Loss: 0.000578 - Val Loss: 0.000555
#
# Epoch [225/999] - Train Loss: 0.000588 - Val Loss: 0.000549
#
# Epoch [226/999] - Train Loss: 0.000581 - Val Loss: 0.000547
#
# Epoch [227/999] - Train Loss: 0.000570 - Val Loss: 0.000547
#
# Epoch [228/999] - Train Loss: 0.000576 - Val Loss: 0.000542
#
# Epoch [229/999] - Train Loss: 0.000569 - Val Loss: 0.000538
#
# Epoch [230/999] - Train Loss: 0.000568 - Val Loss: 0.000536
#
# Epoch [231/999] - Train Loss: 0.000565 - Val Loss: 0.000537
#
# Epoch [232/999] - Train Loss: 0.000559 - Val Loss: 0.000539
#
# Epoch [233/999] - Train Loss: 0.000566 - Val Loss: 0.000536
#
# Epoch [234/999] - Train Loss: 0.000568 - Val Loss: 0.000535
#
# Epoch [235/999] - Train Loss: 0.000562 - Val Loss: 0.000531
#
# Epoch [236/999] - Train Loss: 0.000554 - Val Loss: 0.000527
#
# Epoch [237/999] - Train Loss: 0.000563 - Val Loss: 0.000526
#
# Epoch [238/999] - Train Loss: 0.000551 - Val Loss: 0.000524
#
# Epoch [239/999] - Train Loss: 0.000554 - Val Loss: 0.000522
#
# Epoch [240/999] - Train Loss: 0.000547 - Val Loss: 0.000518
#
# Epoch [241/999] - Train Loss: 0.000550 - Val Loss: 0.000514
#
# Epoch [242/999] - Train Loss: 0.000546 - Val Loss: 0.000512
#
# Epoch [243/999] - Train Loss: 0.000542 - Val Loss: 0.000511
#
# Epoch [244/999] - Train Loss: 0.000531 - Val Loss: 0.000510
#
# Epoch [245/999] - Train Loss: 0.000532 - Val Loss: 0.000513
#
# Epoch [246/999] - Train Loss: 0.000535 - Val Loss: 0.000511
#
# Epoch [247/999] - Train Loss: 0.000534 - Val Loss: 0.000509
#
# Epoch [248/999] - Train Loss: 0.000533 - Val Loss: 0.000506
#
# Epoch [249/999] - Train Loss: 0.000517 - Val Loss: 0.000506
#
# Epoch [250/999] - Train Loss: 0.000526 - Val Loss: 0.000502
#
# Epoch [251/999] - Train Loss: 0.000518 - Val Loss: 0.000498
#
# Epoch [252/999] - Train Loss: 0.000512 - Val Loss: 0.000497
#
# Epoch [253/999] - Train Loss: 0.000519 - Val Loss: 0.000496
#
# Epoch [254/999] - Train Loss: 0.000518 - Val Loss: 0.000493
#
# Epoch [255/999] - Train Loss: 0.000510 - Val Loss: 0.000490
#
# Epoch [256/999] - Train Loss: 0.000508 - Val Loss: 0.000487
#
# Epoch [257/999] - Train Loss: 0.000513 - Val Loss: 0.000488
#
# Epoch [258/999] - Train Loss: 0.000510 - Val Loss: 0.000486
#
# Epoch [259/999] - Train Loss: 0.000505 - Val Loss: 0.000483
#
# Epoch [260/999] - Train Loss: 0.000510 - Val Loss: 0.000483
#
# Epoch [261/999] - Train Loss: 0.000499 - Val Loss: 0.000476
#
# Epoch [262/999] - Train Loss: 0.000494 - Val Loss: 0.000478
#
# Epoch [263/999] - Train Loss: 0.000494 - Val Loss: 0.000472
#
# Epoch [264/999] - Train Loss: 0.000506 - Val Loss: 0.000470
#
# Epoch [265/999] - Train Loss: 0.000495 - Val Loss: 0.000469
#
# Epoch [266/999] - Train Loss: 0.000494 - Val Loss: 0.000471
#
# Epoch [267/999] - Train Loss: 0.000487 - Val Loss: 0.000472
#
# Epoch [268/999] - Train Loss: 0.000491 - Val Loss: 0.000468
#
# Epoch [269/999] - Train Loss: 0.000493 - Val Loss: 0.000466
#
# Epoch [270/999] - Train Loss: 0.000486 - Val Loss: 0.000462
#
# Epoch [271/999] - Train Loss: 0.000485 - Val Loss: 0.000462
#
# Epoch [272/999] - Train Loss: 0.000476 - Val Loss: 0.000459
#
# Epoch [273/999] - Train Loss: 0.000482 - Val Loss: 0.000459
#
# Epoch [274/999] - Train Loss: 0.000477 - Val Loss: 0.000459
#
# Epoch [275/999] - Train Loss: 0.000468 - Val Loss: 0.000456
#
# Epoch [276/999] - Train Loss: 0.000473 - Val Loss: 0.000450
#
# Epoch [277/999] - Train Loss: 0.000472 - Val Loss: 0.000448
#
# Epoch [278/999] - Train Loss: 0.000469 - Val Loss: 0.000448
#
# Epoch [279/999] - Train Loss: 0.000461 - Val Loss: 0.000444
#
# Epoch [280/999] - Train Loss: 0.000459 - Val Loss: 0.000439
#
# Epoch [281/999] - Train Loss: 0.000467 - Val Loss: 0.000443
#
# Epoch [282/999] - Train Loss: 0.000464 - Val Loss: 0.000440
#
# Epoch [283/999] - Train Loss: 0.000464 - Val Loss: 0.000438
#
# Epoch [284/999] - Train Loss: 0.000458 - Val Loss: 0.000439
#
# Epoch [285/999] - Train Loss: 0.000462 - Val Loss: 0.000439
#
# Epoch [286/999] - Train Loss: 0.000455 - Val Loss: 0.000435
#
# Epoch [287/999] - Train Loss: 0.000454 - Val Loss: 0.000431
#
# Epoch [288/999] - Train Loss: 0.000454 - Val Loss: 0.000433
#
# Epoch [289/999] - Train Loss: 0.000450 - Val Loss: 0.000430
#
# Epoch [290/999] - Train Loss: 0.000456 - Val Loss: 0.000428
#
# Epoch [291/999] - Train Loss: 0.000447 - Val Loss: 0.000431
#
# Epoch [292/999] - Train Loss: 0.000440 - Val Loss: 0.000428
#
# Epoch [293/999] - Train Loss: 0.000446 - Val Loss: 0.000421
#
# Epoch [294/999] - Train Loss: 0.000443 - Val Loss: 0.000421
#
# Epoch [295/999] - Train Loss: 0.000437 - Val Loss: 0.000419
#
# Epoch [296/999] - Train Loss: 0.000439 - Val Loss: 0.000419
#
# Epoch [297/999] - Train Loss: 0.000434 - Val Loss: 0.000422
#
# Epoch [298/999] - Train Loss: 0.000440 - Val Loss: 0.000427
#
# Epoch [299/999] - Train Loss: 0.000441 - Val Loss: 0.000422
#
# Epoch [300/999] - Train Loss: 0.000430 - Val Loss: 0.000420
#
# Epoch [301/999] - Train Loss: 0.000424 - Val Loss: 0.000417
#
# Epoch [302/999] - Train Loss: 0.000425 - Val Loss: 0.000411
#
# Epoch [303/999] - Train Loss: 0.000425 - Val Loss: 0.000406
#
# Epoch [304/999] - Train Loss: 0.000432 - Val Loss: 0.000408
#
# Epoch [305/999] - Train Loss: 0.000430 - Val Loss: 0.000403
#
# Epoch [306/999] - Train Loss: 0.000421 - Val Loss: 0.000405
#
# Epoch [307/999] - Train Loss: 0.000426 - Val Loss: 0.000410
#
# Epoch [308/999] - Train Loss: 0.000425 - Val Loss: 0.000408
#
# Epoch [309/999] - Train Loss: 0.000425 - Val Loss: 0.000404
#
# Epoch [310/999] - Train Loss: 0.000416 - Val Loss: 0.000399
#
# Epoch [311/999] - Train Loss: 0.000412 - Val Loss: 0.000392
#
# Epoch [312/999] - Train Loss: 0.000411 - Val Loss: 0.000393
#
# Epoch [313/999] - Train Loss: 0.000411 - Val Loss: 0.000394
#
# Epoch [314/999] - Train Loss: 0.000413 - Val Loss: 0.000394
#
# Epoch [315/999] - Train Loss: 0.000408 - Val Loss: 0.000390
#
# Epoch [316/999] - Train Loss: 0.000407 - Val Loss: 0.000391
#
# Epoch [317/999] - Train Loss: 0.000414 - Val Loss: 0.000391
#
# Epoch [318/999] - Train Loss: 0.000403 - Val Loss: 0.000390
#
# Epoch [319/999] - Train Loss: 0.000406 - Val Loss: 0.000393
#
# Epoch [320/999] - Train Loss: 0.000405 - Val Loss: 0.000386
#
# Epoch [321/999] - Train Loss: 0.000405 - Val Loss: 0.000384
#
# Epoch [322/999] - Train Loss: 0.000403 - Val Loss: 0.000385
#
# Epoch [323/999] - Train Loss: 0.000398 - Val Loss: 0.000390
#
# Epoch [324/999] - Train Loss: 0.000403 - Val Loss: 0.000382
#
# Epoch [325/999] - Train Loss: 0.000391 - Val Loss: 0.000379
#
# Epoch [326/999] - Train Loss: 0.000390 - Val Loss: 0.000378
#
# Epoch [327/999] - Train Loss: 0.000398 - Val Loss: 0.000374
#
# Epoch [328/999] - Train Loss: 0.000391 - Val Loss: 0.000376
#
# Epoch [329/999] - Train Loss: 0.000391 - Val Loss: 0.000377
#
# Epoch [330/999] - Train Loss: 0.000387 - Val Loss: 0.000372
#
# Epoch [331/999] - Train Loss: 0.000387 - Val Loss: 0.000374
#
# Epoch [332/999] - Train Loss: 0.000383 - Val Loss: 0.000374
#
# Epoch [333/999] - Train Loss: 0.000391 - Val Loss: 0.000373
#
# Epoch [334/999] - Train Loss: 0.000384 - Val Loss: 0.000370
#
# Epoch [335/999] - Train Loss: 0.000380 - Val Loss: 0.000368
#
# Epoch [336/999] - Train Loss: 0.000384 - Val Loss: 0.000364
#
# Epoch [337/999] - Train Loss: 0.000379 - Val Loss: 0.000361
#
# Epoch [338/999] - Train Loss: 0.000380 - Val Loss: 0.000362
#
# Epoch [339/999] - Train Loss: 0.000369 - Val Loss: 0.000356
#
# Epoch [340/999] - Train Loss: 0.000376 - Val Loss: 0.000356
#
# Epoch [341/999] - Train Loss: 0.000371 - Val Loss: 0.000359
#
# Epoch [342/999] - Train Loss: 0.000374 - Val Loss: 0.000357
#
# Epoch [343/999] - Train Loss: 0.000369 - Val Loss: 0.000358
#
# Epoch [344/999] - Train Loss: 0.000376 - Val Loss: 0.000355
#
# Epoch [345/999] - Train Loss: 0.000375 - Val Loss: 0.000356
#
# Epoch [346/999] - Train Loss: 0.000368 - Val Loss: 0.000352
#
# Epoch [347/999] - Train Loss: 0.000370 - Val Loss: 0.000351
#
# Epoch [348/999] - Train Loss: 0.000365 - Val Loss: 0.000351
#
# Epoch [349/999] - Train Loss: 0.000366 - Val Loss: 0.000350
#
# Epoch [350/999] - Train Loss: 0.000355 - Val Loss: 0.000352
#
# Epoch [351/999] - Train Loss: 0.000354 - Val Loss: 0.000354
#
# Epoch [352/999] - Train Loss: 0.000359 - Val Loss: 0.000354
#
# Epoch [353/999] - Train Loss: 0.000363 - Val Loss: 0.000351
#
# Epoch [354/999] - Train Loss: 0.000357 - Val Loss: 0.000343
#
# Epoch [355/999] - Train Loss: 0.000352 - Val Loss: 0.000342
#
# Epoch [356/999] - Train Loss: 0.000358 - Val Loss: 0.000339
#
# Epoch [357/999] - Train Loss: 0.000352 - Val Loss: 0.000335
#
# Epoch [358/999] - Train Loss: 0.000347 - Val Loss: 0.000339
#
# Epoch [359/999] - Train Loss: 0.000358 - Val Loss: 0.000335
#
# Epoch [360/999] - Train Loss: 0.000349 - Val Loss: 0.000333
#
# Epoch [361/999] - Train Loss: 0.000350 - Val Loss: 0.000332
#
# Epoch [362/999] - Train Loss: 0.000350 - Val Loss: 0.000329
#
# Epoch [363/999] - Train Loss: 0.000351 - Val Loss: 0.000329
#
# Epoch [364/999] - Train Loss: 0.000342 - Val Loss: 0.000327
#
# Epoch [365/999] - Train Loss: 0.000346 - Val Loss: 0.000326
#
# Epoch [366/999] - Train Loss: 0.000346 - Val Loss: 0.000321
#
# Epoch [367/999] - Train Loss: 0.000345 - Val Loss: 0.000321
#
# Epoch [368/999] - Train Loss: 0.000339 - Val Loss: 0.000327
#
# Epoch [369/999] - Train Loss: 0.000336 - Val Loss: 0.000320
#
# Epoch [370/999] - Train Loss: 0.000338 - Val Loss: 0.000324
#
# Epoch [371/999] - Train Loss: 0.000339 - Val Loss: 0.000324
#
# Epoch [372/999] - Train Loss: 0.000336 - Val Loss: 0.000324
#
# Epoch [373/999] - Train Loss: 0.000340 - Val Loss: 0.000321
#
# Epoch [374/999] - Train Loss: 0.000330 - Val Loss: 0.000318
#
# Epoch [375/999] - Train Loss: 0.000336 - Val Loss: 0.000320
#
# Epoch [376/999] - Train Loss: 0.000328 - Val Loss: 0.000319
#
# Epoch [377/999] - Train Loss: 0.000328 - Val Loss: 0.000313
#
# Epoch [378/999] - Train Loss: 0.000331 - Val Loss: 0.000311
#
# Epoch [379/999] - Train Loss: 0.000330 - Val Loss: 0.000309
#
# Epoch [380/999] - Train Loss: 0.000327 - Val Loss: 0.000310
#
# Epoch [381/999] - Train Loss: 0.000325 - Val Loss: 0.000307
#
# Epoch [382/999] - Train Loss: 0.000325 - Val Loss: 0.000307
#
# Epoch [383/999] - Train Loss: 0.000322 - Val Loss: 0.000311
#
# Epoch [384/999] - Train Loss: 0.000322 - Val Loss: 0.000308
#
# Epoch [385/999] - Train Loss: 0.000318 - Val Loss: 0.000309
#
# Epoch [386/999] - Train Loss: 0.000318 - Val Loss: 0.000306
#
# Epoch [387/999] - Train Loss: 0.000322 - Val Loss: 0.000303
#
# Epoch [388/999] - Train Loss: 0.000315 - Val Loss: 0.000305
#
# Epoch [389/999] - Train Loss: 0.000315 - Val Loss: 0.000308
#
# Epoch [390/999] - Train Loss: 0.000315 - Val Loss: 0.000303
#
# Epoch [391/999] - Train Loss: 0.000315 - Val Loss: 0.000299
#
# Epoch [392/999] - Train Loss: 0.000310 - Val Loss: 0.000299
#
# Epoch [393/999] - Train Loss: 0.000315 - Val Loss: 0.000296
#
# Epoch [394/999] - Train Loss: 0.000313 - Val Loss: 0.000298
#
# Epoch [395/999] - Train Loss: 0.000310 - Val Loss: 0.000299
#
# Epoch [396/999] - Train Loss: 0.000306 - Val Loss: 0.000299
#
# Epoch [397/999] - Train Loss: 0.000300 - Val Loss: 0.000298
#
# Epoch [398/999] - Train Loss: 0.000301 - Val Loss: 0.000297
#
# Epoch [399/999] - Train Loss: 0.000304 - Val Loss: 0.000298
#
# Epoch [400/999] - Train Loss: 0.000300 - Val Loss: 0.000294
#
# Epoch [401/999] - Train Loss: 0.000304 - Val Loss: 0.000290
#
# Epoch [402/999] - Train Loss: 0.000298 - Val Loss: 0.000286
#
# Epoch [403/999] - Train Loss: 0.000303 - Val Loss: 0.000285
#
# Epoch [404/999] - Train Loss: 0.000296 - Val Loss: 0.000287
#
# Epoch [405/999] - Train Loss: 0.000296 - Val Loss: 0.000283
#
# Epoch [406/999] - Train Loss: 0.000300 - Val Loss: 0.000282
#
# Epoch [407/999] - Train Loss: 0.000292 - Val Loss: 0.000283
#
# Epoch [408/999] - Train Loss: 0.000295 - Val Loss: 0.000284
#
# Epoch [409/999] - Train Loss: 0.000299 - Val Loss: 0.000285
#
# Epoch [410/999] - Train Loss: 0.000292 - Val Loss: 0.000281
#
# Epoch [411/999] - Train Loss: 0.000293 - Val Loss: 0.000284
#
# Epoch [412/999] - Train Loss: 0.000292 - Val Loss: 0.000282
#
# Epoch [413/999] - Train Loss: 0.000294 - Val Loss: 0.000275
#
# Epoch [414/999] - Train Loss: 0.000285 - Val Loss: 0.000271
#
# Epoch [415/999] - Train Loss: 0.000289 - Val Loss: 0.000273
#
# Epoch [416/999] - Train Loss: 0.000279 - Val Loss: 0.000276
#
# Epoch [417/999] - Train Loss: 0.000288 - Val Loss: 0.000274
#
# Epoch [418/999] - Train Loss: 0.000289 - Val Loss: 0.000282
#
# Epoch [419/999] - Train Loss: 0.000286 - Val Loss: 0.000275
#
# Epoch [420/999] - Train Loss: 0.000280 - Val Loss: 0.000271
#
# Epoch [421/999] - Train Loss: 0.000279 - Val Loss: 0.000266
#
# Epoch [422/999] - Train Loss: 0.000283 - Val Loss: 0.000267
#
# Epoch [423/999] - Train Loss: 0.000282 - Val Loss: 0.000264
#
# Epoch [424/999] - Train Loss: 0.000279 - Val Loss: 0.000263
#
# Epoch [425/999] - Train Loss: 0.000277 - Val Loss: 0.000268
#
# Epoch [426/999] - Train Loss: 0.000278 - Val Loss: 0.000269
#
# Epoch [427/999] - Train Loss: 0.000274 - Val Loss: 0.000264
#
# Epoch [428/999] - Train Loss: 0.000276 - Val Loss: 0.000262
#
# Epoch [429/999] - Train Loss: 0.000276 - Val Loss: 0.000259
#
# Epoch [430/999] - Train Loss: 0.000268 - Val Loss: 0.000260
#
# Epoch [431/999] - Train Loss: 0.000268 - Val Loss: 0.000262
#
# Epoch [432/999] - Train Loss: 0.000269 - Val Loss: 0.000257
#
# Epoch [433/999] - Train Loss: 0.000272 - Val Loss: 0.000252
#
# Epoch [434/999] - Train Loss: 0.000267 - Val Loss: 0.000250
#
# Epoch [435/999] - Train Loss: 0.000273 - Val Loss: 0.000249
#
# Epoch [436/999] - Train Loss: 0.000260 - Val Loss: 0.000252
#
# Epoch [437/999] - Train Loss: 0.000262 - Val Loss: 0.000251
#
# Epoch [438/999] - Train Loss: 0.000267 - Val Loss: 0.000250
#
# Epoch [439/999] - Train Loss: 0.000261 - Val Loss: 0.000250
#
# Epoch [440/999] - Train Loss: 0.000262 - Val Loss: 0.000255
#
# Epoch [441/999] - Train Loss: 0.000258 - Val Loss: 0.000252
#
# Epoch [442/999] - Train Loss: 0.000261 - Val Loss: 0.000254
#
# Epoch [443/999] - Train Loss: 0.000262 - Val Loss: 0.000243
#
# Epoch [444/999] - Train Loss: 0.000261 - Val Loss: 0.000239
#
# Epoch [445/999] - Train Loss: 0.000258 - Val Loss: 0.000239
#
# Epoch [446/999] - Train Loss: 0.000257 - Val Loss: 0.000245
#
# Epoch [447/999] - Train Loss: 0.000250 - Val Loss: 0.000245
#
# Epoch [448/999] - Train Loss: 0.000252 - Val Loss: 0.000240
#
# Epoch [449/999] - Train Loss: 0.000251 - Val Loss: 0.000238
#
# Epoch [450/999] - Train Loss: 0.000256 - Val Loss: 0.000241
#
# Epoch [451/999] - Train Loss: 0.000249 - Val Loss: 0.000243
#
# Epoch [452/999] - Train Loss: 0.000247 - Val Loss: 0.000241
#
# Epoch [453/999] - Train Loss: 0.000244 - Val Loss: 0.000237
#
# Epoch [454/999] - Train Loss: 0.000245 - Val Loss: 0.000234
#
# Epoch [455/999] - Train Loss: 0.000248 - Val Loss: 0.000228
#
# Epoch [456/999] - Train Loss: 0.000250 - Val Loss: 0.000228
#
# Epoch [457/999] - Train Loss: 0.000245 - Val Loss: 0.000231
#
# Epoch [458/999] - Train Loss: 0.000244 - Val Loss: 0.000230
#
# Epoch [459/999] - Train Loss: 0.000247 - Val Loss: 0.000234
#
# Epoch [460/999] - Train Loss: 0.000245 - Val Loss: 0.000236
#
# Epoch [461/999] - Train Loss: 0.000235 - Val Loss: 0.000234
#
# Epoch [462/999] - Train Loss: 0.000238 - Val Loss: 0.000229
#
# Epoch [463/999] - Train Loss: 0.000241 - Val Loss: 0.000229
#
# Epoch [464/999] - Train Loss: 0.000239 - Val Loss: 0.000225
#
# Epoch [465/999] - Train Loss: 0.000239 - Val Loss: 0.000226
#
# Epoch [466/999] - Train Loss: 0.000236 - Val Loss: 0.000227
#
# Epoch [467/999] - Train Loss: 0.000238 - Val Loss: 0.000224
#
# Epoch [468/999] - Train Loss: 0.000231 - Val Loss: 0.000221
#
# Epoch [469/999] - Train Loss: 0.000237 - Val Loss: 0.000224
#
# Epoch [470/999] - Train Loss: 0.000234 - Val Loss: 0.000220
#
# Epoch [471/999] - Train Loss: 0.000228 - Val Loss: 0.000221
#
# Epoch [472/999] - Train Loss: 0.000232 - Val Loss: 0.000221
#
# Epoch [473/999] - Train Loss: 0.000231 - Val Loss: 0.000219
#
# Epoch [474/999] - Train Loss: 0.000230 - Val Loss: 0.000220
#
# Epoch [475/999] - Train Loss: 0.000228 - Val Loss: 0.000218
#
# Epoch [476/999] - Train Loss: 0.000226 - Val Loss: 0.000218
#
# Epoch [477/999] - Train Loss: 0.000231 - Val Loss: 0.000212
#
# Epoch [478/999] - Train Loss: 0.000224 - Val Loss: 0.000213
#
# Epoch [479/999] - Train Loss: 0.000228 - Val Loss: 0.000218
#
# Epoch [480/999] - Train Loss: 0.000225 - Val Loss: 0.000211
#
# Epoch [481/999] - Train Loss: 0.000217 - Val Loss: 0.000212
#
# Epoch [482/999] - Train Loss: 0.000226 - Val Loss: 0.000213
#
# Epoch [483/999] - Train Loss: 0.000218 - Val Loss: 0.000209
#
# Epoch [484/999] - Train Loss: 0.000222 - Val Loss: 0.000207
#
# Epoch [485/999] - Train Loss: 0.000221 - Val Loss: 0.000204
#
# Epoch [486/999] - Train Loss: 0.000224 - Val Loss: 0.000206
#
# Epoch [487/999] - Train Loss: 0.000218 - Val Loss: 0.000201
#
# Epoch [488/999] - Train Loss: 0.000215 - Val Loss: 0.000201
#
# Epoch [489/999] - Train Loss: 0.000218 - Val Loss: 0.000202
#
# Epoch [490/999] - Train Loss: 0.000217 - Val Loss: 0.000200
#
# Epoch [491/999] - Train Loss: 0.000216 - Val Loss: 0.000202
#
# Epoch [492/999] - Train Loss: 0.000218 - Val Loss: 0.000205
#
# Epoch [493/999] - Train Loss: 0.000213 - Val Loss: 0.000206
#
# Epoch [494/999] - Train Loss: 0.000214 - Val Loss: 0.000201
#
# Epoch [495/999] - Train Loss: 0.000212 - Val Loss: 0.000208
#
# Epoch [496/999] - Train Loss: 0.000213 - Val Loss: 0.000201
#
# Epoch [497/999] - Train Loss: 0.000210 - Val Loss: 0.000198
#
# Epoch [498/999] - Train Loss: 0.000209 - Val Loss: 0.000197
#
# Epoch [499/999] - Train Loss: 0.000202 - Val Loss: 0.000197
#
# Epoch [500/999] - Train Loss: 0.000208 - Val Loss: 0.000193
#
# Epoch [501/999] - Train Loss: 0.000207 - Val Loss: 0.000195
#
# Epoch [502/999] - Train Loss: 0.000203 - Val Loss: 0.000191
#
# Epoch [503/999] - Train Loss: 0.000204 - Val Loss: 0.000189
#
# Epoch [504/999] - Train Loss: 0.000206 - Val Loss: 0.000196
#
# Epoch [505/999] - Train Loss: 0.000204 - Val Loss: 0.000197
#
# Epoch [506/999] - Train Loss: 0.000205 - Val Loss: 0.000197
#
# Epoch [507/999] - Train Loss: 0.000201 - Val Loss: 0.000190
#
# Epoch [508/999] - Train Loss: 0.000203 - Val Loss: 0.000189
#
# Epoch [509/999] - Train Loss: 0.000200 - Val Loss: 0.000189
#
# Epoch [510/999] - Train Loss: 0.000202 - Val Loss: 0.000193
#
# Epoch [511/999] - Train Loss: 0.000202 - Val Loss: 0.000189
#
# Epoch [512/999] - Train Loss: 0.000199 - Val Loss: 0.000190
#
# Epoch [513/999] - Train Loss: 0.000198 - Val Loss: 0.000186
#
# Epoch [514/999] - Train Loss: 0.000196 - Val Loss: 0.000187
#
# Epoch [515/999] - Train Loss: 0.000197 - Val Loss: 0.000184
#
# Epoch [516/999] - Train Loss: 0.000196 - Val Loss: 0.000190
#
# Epoch [517/999] - Train Loss: 0.000192 - Val Loss: 0.000184
#
# Epoch [518/999] - Train Loss: 0.000190 - Val Loss: 0.000186
#
# Epoch [519/999] - Train Loss: 0.000193 - Val Loss: 0.000182
#
# Epoch [520/999] - Train Loss: 0.000190 - Val Loss: 0.000181
#
# Epoch [521/999] - Train Loss: 0.000194 - Val Loss: 0.000187
#
# Epoch [522/999] - Train Loss: 0.000188 - Val Loss: 0.000177
#
# Epoch [523/999] - Train Loss: 0.000186 - Val Loss: 0.000175
#
# Epoch [524/999] - Train Loss: 0.000186 - Val Loss: 0.000178
#
# Epoch [525/999] - Train Loss: 0.000188 - Val Loss: 0.000180
#
# Epoch [526/999] - Train Loss: 0.000188 - Val Loss: 0.000177
#
# Epoch [527/999] - Train Loss: 0.000183 - Val Loss: 0.000174
#
# Epoch [528/999] - Train Loss: 0.000183 - Val Loss: 0.000177
#
# Epoch [529/999] - Train Loss: 0.000185 - Val Loss: 0.000175
#
# Epoch [530/999] - Train Loss: 0.000184 - Val Loss: 0.000171
#
# Epoch [531/999] - Train Loss: 0.000181 - Val Loss: 0.000171
#
# Epoch [532/999] - Train Loss: 0.000185 - Val Loss: 0.000173
#
# Epoch [533/999] - Train Loss: 0.000181 - Val Loss: 0.000173
#
# Epoch [534/999] - Train Loss: 0.000180 - Val Loss: 0.000168
#
# Epoch [535/999] - Train Loss: 0.000181 - Val Loss: 0.000165
#
# Epoch [536/999] - Train Loss: 0.000174 - Val Loss: 0.000173
#
# Epoch [537/999] - Train Loss: 0.000176 - Val Loss: 0.000176
#
# Epoch [538/999] - Train Loss: 0.000181 - Val Loss: 0.000177
#
# Epoch [539/999] - Train Loss: 0.000181 - Val Loss: 0.000166
#
# Epoch [540/999] - Train Loss: 0.000177 - Val Loss: 0.000165
#
# Epoch [541/999] - Train Loss: 0.000180 - Val Loss: 0.000165
#
# Epoch [542/999] - Train Loss: 0.000179 - Val Loss: 0.000161
#
# Epoch [543/999] - Train Loss: 0.000172 - Val Loss: 0.000164
#
# Epoch [544/999] - Train Loss: 0.000176 - Val Loss: 0.000162
#
# Epoch [545/999] - Train Loss: 0.000174 - Val Loss: 0.000168
#
# Epoch [546/999] - Train Loss: 0.000170 - Val Loss: 0.000160
#
# Epoch [547/999] - Train Loss: 0.000172 - Val Loss: 0.000162
#
# Epoch [548/999] - Train Loss: 0.000172 - Val Loss: 0.000160
#
# Epoch [549/999] - Train Loss: 0.000173 - Val Loss: 0.000160
#
# Epoch [550/999] - Train Loss: 0.000169 - Val Loss: 0.000162
#
# Epoch [551/999] - Train Loss: 0.000169 - Val Loss: 0.000158
#
# Epoch [552/999] - Train Loss: 0.000171 - Val Loss: 0.000156
#
# Epoch [553/999] - Train Loss: 0.000166 - Val Loss: 0.000161
#
# Epoch [554/999] - Train Loss: 0.000169 - Val Loss: 0.000163
#
# Epoch [555/999] - Train Loss: 0.000164 - Val Loss: 0.000157
#
# Epoch [556/999] - Train Loss: 0.000162 - Val Loss: 0.000157
#
# Epoch [557/999] - Train Loss: 0.000164 - Val Loss: 0.000155
#
# Epoch [558/999] - Train Loss: 0.000165 - Val Loss: 0.000152
#
# Epoch [559/999] - Train Loss: 0.000164 - Val Loss: 0.000151
#
# Epoch [560/999] - Train Loss: 0.000161 - Val Loss: 0.000152
#
# Epoch [561/999] - Train Loss: 0.000161 - Val Loss: 0.000150
#
# Epoch [562/999] - Train Loss: 0.000165 - Val Loss: 0.000146
#
# Epoch [563/999] - Train Loss: 0.000156 - Val Loss: 0.000147
#
# Epoch [564/999] - Train Loss: 0.000159 - Val Loss: 0.000151
#
# Epoch [565/999] - Train Loss: 0.000161 - Val Loss: 0.000153
#
# Epoch [566/999] - Train Loss: 0.000157 - Val Loss: 0.000152
#
# Epoch [567/999] - Train Loss: 0.000157 - Val Loss: 0.000148
#
# Epoch [568/999] - Train Loss: 0.000155 - Val Loss: 0.000148
#
# Epoch [569/999] - Train Loss: 0.000157 - Val Loss: 0.000144
#
# Epoch [570/999] - Train Loss: 0.000158 - Val Loss: 0.000147
#
# Epoch [571/999] - Train Loss: 0.000159 - Val Loss: 0.000147
#
# Epoch [572/999] - Train Loss: 0.000155 - Val Loss: 0.000141
#
# Epoch [573/999] - Train Loss: 0.000155 - Val Loss: 0.000148
#
# Epoch [574/999] - Train Loss: 0.000156 - Val Loss: 0.000144
#
# Epoch [575/999] - Train Loss: 0.000152 - Val Loss: 0.000145
#
# Epoch [576/999] - Train Loss: 0.000153 - Val Loss: 0.000146
#
# Epoch [577/999] - Train Loss: 0.000153 - Val Loss: 0.000144
#
# Epoch [578/999] - Train Loss: 0.000152 - Val Loss: 0.000138
#
# Epoch [579/999] - Train Loss: 0.000152 - Val Loss: 0.000141
#
# Epoch [580/999] - Train Loss: 0.000149 - Val Loss: 0.000136
#
# Epoch [581/999] - Train Loss: 0.000151 - Val Loss: 0.000138
#
# Epoch [582/999] - Train Loss: 0.000148 - Val Loss: 0.000141
#
# Epoch [583/999] - Train Loss: 0.000149 - Val Loss: 0.000141
#
# Epoch [584/999] - Train Loss: 0.000148 - Val Loss: 0.000138
#
# Epoch [585/999] - Train Loss: 0.000145 - Val Loss: 0.000138
#
# Epoch [586/999] - Train Loss: 0.000146 - Val Loss: 0.000138
#
# Epoch [587/999] - Train Loss: 0.000145 - Val Loss: 0.000136
#
# Epoch [588/999] - Train Loss: 0.000142 - Val Loss: 0.000133
#
# Epoch [589/999] - Train Loss: 0.000147 - Val Loss: 0.000134
#
# Epoch [590/999] - Train Loss: 0.000144 - Val Loss: 0.000134
#
# Epoch [591/999] - Train Loss: 0.000146 - Val Loss: 0.000135
#
# Epoch [592/999] - Train Loss: 0.000143 - Val Loss: 0.000135
#
# Epoch [593/999] - Train Loss: 0.000143 - Val Loss: 0.000133
#
# Epoch [594/999] - Train Loss: 0.000139 - Val Loss: 0.000131
#
# Epoch [595/999] - Train Loss: 0.000141 - Val Loss: 0.000129
#
# Epoch [596/999] - Train Loss: 0.000142 - Val Loss: 0.000133
#
# Epoch [597/999] - Train Loss: 0.000141 - Val Loss: 0.000128
#
# Epoch [598/999] - Train Loss: 0.000140 - Val Loss: 0.000126
#
# Epoch [599/999] - Train Loss: 0.000140 - Val Loss: 0.000133
#
# Epoch [600/999] - Train Loss: 0.000134 - Val Loss: 0.000129
#
# Epoch [601/999] - Train Loss: 0.000137 - Val Loss: 0.000128
#
# Epoch [602/999] - Train Loss: 0.000139 - Val Loss: 0.000129
#
# Epoch [603/999] - Train Loss: 0.000135 - Val Loss: 0.000125
#
# Epoch [604/999] - Train Loss: 0.000137 - Val Loss: 0.000125
#
# Epoch [605/999] - Train Loss: 0.000137 - Val Loss: 0.000131
#
# Epoch [606/999] - Train Loss: 0.000134 - Val Loss: 0.000123
#
# Epoch [607/999] - Train Loss: 0.000137 - Val Loss: 0.000128
#
# Epoch [608/999] - Train Loss: 0.000134 - Val Loss: 0.000123
#
# Epoch [609/999] - Train Loss: 0.000136 - Val Loss: 0.000124
#
# Epoch [610/999] - Train Loss: 0.000133 - Val Loss: 0.000129
#
# Epoch [611/999] - Train Loss: 0.000134 - Val Loss: 0.000123
#
# Epoch [612/999] - Train Loss: 0.000133 - Val Loss: 0.000122
#
# Epoch [613/999] - Train Loss: 0.000129 - Val Loss: 0.000127
#
# Epoch [614/999] - Train Loss: 0.000131 - Val Loss: 0.000125
#
# Epoch [615/999] - Train Loss: 0.000130 - Val Loss: 0.000120
#
# Epoch [616/999] - Train Loss: 0.000130 - Val Loss: 0.000117
#
# Epoch [617/999] - Train Loss: 0.000128 - Val Loss: 0.000121
#
# Epoch [618/999] - Train Loss: 0.000126 - Val Loss: 0.000119
#
# Epoch [619/999] - Train Loss: 0.000128 - Val Loss: 0.000120
#
# Epoch [620/999] - Train Loss: 0.000128 - Val Loss: 0.000118
#
# Epoch [621/999] - Train Loss: 0.000131 - Val Loss: 0.000117
#
# Epoch [622/999] - Train Loss: 0.000127 - Val Loss: 0.000124
#
# Epoch [623/999] - Train Loss: 0.000129 - Val Loss: 0.000121
#
# Epoch [624/999] - Train Loss: 0.000127 - Val Loss: 0.000118
#
# Epoch [625/999] - Train Loss: 0.000126 - Val Loss: 0.000116
#
# Epoch [626/999] - Train Loss: 0.000122 - Val Loss: 0.000117
#
# Epoch [627/999] - Train Loss: 0.000125 - Val Loss: 0.000115
#
# Epoch [628/999] - Train Loss: 0.000124 - Val Loss: 0.000114
#
# Epoch [629/999] - Train Loss: 0.000122 - Val Loss: 0.000119
#
# Epoch [630/999] - Train Loss: 0.000124 - Val Loss: 0.000115
#
# Epoch [631/999] - Train Loss: 0.000124 - Val Loss: 0.000114
#
# ...
#
# Epoch [662/999] - Train Loss: 0.000106 - Val Loss: 0.000102
#
# Epoch [663/999] - Train Loss: 0.000107 - Val Loss: 0.000103
#
# Epoch [664/999] - Train Loss: 0.000109 - Val Loss: 0.000100
#
# Epoch [665/999] - Train Loss: 0.000108 - Val Loss: 0.000100
#
# Epoch [666/999] - Train Loss: 0.000105 - Val Loss: 0.000100
#
# Epoch [667/999] - Train Loss: 0.000107 - Val Loss: 0.000103
#
# Epoch [668/999] - Train Loss: 0.000105 - Val Loss: 0.000101
#
# Epoch [669/999] - Train Loss: 0.000105 - Val Loss: 0.000097
#
# Epoch [670/999] - Train Loss: 0.000107 - Val Loss: 0.000098
#
# Epoch [671/999] - Train Loss: 0.000107 - Val Loss: 0.000098
#
# Epoch [672/999] - Train Loss: 0.000106 - Val Loss: 0.000096
#
# Epoch [673/999] - Train Loss: 0.000104 - Val Loss: 0.000093
#
# Epoch [674/999] - Train Loss: 0.000103 - Val Loss: 0.000097
#
# Epoch [675/999] - Train Loss: 0.000102 - Val Loss: 0.000098
#
# Epoch [676/999] - Train Loss: 0.000104 - Val Loss: 0.000096
#
# Epoch [677/999] - Train Loss: 0.000099 - Val Loss: 0.000096
#
# Epoch [678/999] - Train Loss: 0.000103 - Val Loss: 0.000098
#
# Epoch [679/999] - Train Loss: 0.000102 - Val Loss: 0.000095
#
# Epoch [680/999] - Train Loss: 0.000101 - Val Loss: 0.000091
#
# Epoch [681/999] - Train Loss: 0.000102 - Val Loss: 0.000095
#
# Epoch [682/999] - Train Loss: 0.000099 - Val Loss: 0.000094
#
# Epoch [683/999] - Train Loss: 0.000100 - Val Loss: 0.000090
#
# Epoch [684/999] - Train Loss: 0.000100 - Val Loss: 0.000090
#
# Epoch [685/999] - Train Loss: 0.000100 - Val Loss: 0.000093
#
# Epoch [686/999] - Train Loss: 0.000099 - Val Loss: 0.000091
#
# Epoch [687/999] - Train Loss: 0.000100 - Val Loss: 0.000093
#
# Epoch [688/999] - Train Loss: 0.000098 - Val Loss: 0.000090
#
# Epoch [689/999] - Train Loss: 0.000098 - Val Loss: 0.000091
#
# Epoch [690/999] - Train Loss: 0.000097 - Val Loss: 0.000092
#
# Epoch [691/999] - Train Loss: 0.000099 - Val Loss: 0.000091
#
# Epoch [692/999] - Train Loss: 0.000097 - Val Loss: 0.000091
#
# Epoch [693/999] - Train Loss: 0.000097 - Val Loss: 0.000092
#
# Epoch [694/999] - Train Loss: 0.000097 - Val Loss: 0.000089
#
# Epoch [695/999] - Train Loss: 0.000095 - Val Loss: 0.000087
#
# Epoch [696/999] - Train Loss: 0.000097 - Val Loss: 0.000091
#
# Epoch [697/999] - Train Loss: 0.000095 - Val Loss: 0.000089
#
# Epoch [698/999] - Train Loss: 0.000096 - Val Loss: 0.000088
#
# Epoch [699/999] - Train Loss: 0.000094 - Val Loss: 0.000089
#
# Epoch [700/999] - Train Loss: 0.000095 - Val Loss: 0.000083
#
# Epoch [701/999] - Train Loss: 0.000095 - Val Loss: 0.000088
#
# Epoch [702/999] - Train Loss: 0.000093 - Val Loss: 0.000090
#
# Epoch [703/999] - Train Loss: 0.000091 - Val Loss: 0.000085
#
# Epoch [704/999] - Train Loss: 0.000093 - Val Loss: 0.000085
#
# Epoch [705/999] - Train Loss: 0.000094 - Val Loss: 0.000087
#
# Epoch [706/999] - Train Loss: 0.000091 - Val Loss: 0.000086
#
# Epoch [707/999] - Train Loss: 0.000093 - Val Loss: 0.000085
#
# Epoch [708/999] - Train Loss: 0.000092 - Val Loss: 0.000087
#
# Epoch [709/999] - Train Loss: 0.000094 - Val Loss: 0.000082
#
# Epoch [710/999] - Train Loss: 0.000089 - Val Loss: 0.000085
#
# Epoch [711/999] - Train Loss: 0.000092 - Val Loss: 0.000085
#
# Epoch [712/999] - Train Loss: 0.000091 - Val Loss: 0.000083
#
# Epoch [713/999] - Train Loss: 0.000090 - Val Loss: 0.000084
#
# Epoch [714/999] - Train Loss: 0.000089 - Val Loss: 0.000084
#
# Epoch [715/999] - Train Loss: 0.000090 - Val Loss: 0.000081
#
# Epoch [716/999] - Train Loss: 0.000090 - Val Loss: 0.000080
#
# Epoch [717/999] - Train Loss: 0.000088 - Val Loss: 0.000082
#
# Epoch [718/999] - Train Loss: 0.000088 - Val Loss: 0.000083
#
# Epoch [719/999] - Train Loss: 0.000087 - Val Loss: 0.000081
#
# Epoch [720/999] - Train Loss: 0.000089 - Val Loss: 0.000081
#
# Epoch [721/999] - Train Loss: 0.000087 - Val Loss: 0.000082
#
# Epoch [722/999] - Train Loss: 0.000089 - Val Loss: 0.000082
#
# Epoch [723/999] - Train Loss: 0.000085 - Val Loss: 0.000081
#
# Epoch [724/999] - Train Loss: 0.000086 - Val Loss: 0.000080
#
# Epoch [725/999] - Train Loss: 0.000086 - Val Loss: 0.000080
#
# Epoch [726/999] - Train Loss: 0.000086 - Val Loss: 0.000077
#
# Epoch [727/999] - Train Loss: 0.000086 - Val Loss: 0.000081
#
# Epoch [728/999] - Train Loss: 0.000084 - Val Loss: 0.000077
#
# Epoch [729/999] - Train Loss: 0.000086 - Val Loss: 0.000082
#
# Epoch [730/999] - Train Loss: 0.000085 - Val Loss: 0.000079
#
# Epoch [731/999] - Train Loss: 0.000084 - Val Loss: 0.000076
#
# Epoch [732/999] - Train Loss: 0.000084 - Val Loss: 0.000079
#
# Epoch [733/999] - Train Loss: 0.000086 - Val Loss: 0.000080
#
# Epoch [734/999] - Train Loss: 0.000082 - Val Loss: 0.000077
#
# Epoch [735/999] - Train Loss: 0.000084 - Val Loss: 0.000079
#
# Epoch [736/999] - Train Loss: 0.000083 - Val Loss: 0.000076
#
# Epoch [737/999] - Train Loss: 0.000084 - Val Loss: 0.000077
#
# Epoch [738/999] - Train Loss: 0.000081 - Val Loss: 0.000077
#
# Epoch [739/999] - Train Loss: 0.000083 - Val Loss: 0.000077
#
# Epoch [740/999] - Train Loss: 0.000081 - Val Loss: 0.000077
#
# Epoch [741/999] - Train Loss: 0.000083 - Val Loss: 0.000076
#
# Epoch [742/999] - Train Loss: 0.000083 - Val Loss: 0.000074
#
# Epoch [743/999] - Train Loss: 0.000082 - Val Loss: 0.000078
#
# Epoch [744/999] - Train Loss: 0.000082 - Val Loss: 0.000074
#
# Epoch [745/999] - Train Loss: 0.000082 - Val Loss: 0.000072
#
# Epoch [746/999] - Train Loss: 0.000079 - Val Loss: 0.000077
#
# Epoch [747/999] - Train Loss: 0.000080 - Val Loss: 0.000074
#
# Epoch [748/999] - Train Loss: 0.000081 - Val Loss: 0.000074
#
# Epoch [749/999] - Train Loss: 0.000079 - Val Loss: 0.000072
#
# Epoch [750/999] - Train Loss: 0.000080 - Val Loss: 0.000072
#
# Epoch [751/999] - Train Loss: 0.000079 - Val Loss: 0.000074
#
# Epoch [752/999] - Train Loss: 0.000076 - Val Loss: 0.000073
#
# Epoch [753/999] - Train Loss: 0.000078 - Val Loss: 0.000071
#
# Epoch [754/999] - Train Loss: 0.000079 - Val Loss: 0.000072
#
# Epoch [755/999] - Train Loss: 0.000078 - Val Loss: 0.000073
#
# Epoch [756/999] - Train Loss: 0.000079 - Val Loss: 0.000075
#
# Epoch [757/999] - Train Loss: 0.000077 - Val Loss: 0.000069
#
# Epoch [758/999] - Train Loss: 0.000078 - Val Loss: 0.000073
#
# Epoch [759/999] - Train Loss: 0.000075 - Val Loss: 0.000073
#
# Epoch [760/999] - Train Loss: 0.000077 - Val Loss: 0.000071
#
# Epoch [761/999] - Train Loss: 0.000073 - Val Loss: 0.000071
#
# Epoch [762/999] - Train Loss: 0.000077 - Val Loss: 0.000071
#
# Epoch [763/999] - Train Loss: 0.000076 - Val Loss: 0.000071
#
# Epoch [764/999] - Train Loss: 0.000076 - Val Loss: 0.000069
#
# Epoch [765/999] - Train Loss: 0.000075 - Val Loss: 0.000068
#
# Epoch [766/999] - Train Loss: 0.000074 - Val Loss: 0.000072
#
# Epoch [767/999] - Train Loss: 0.000073 - Val Loss: 0.000067
#
# Epoch [768/999] - Train Loss: 0.000076 - Val Loss: 0.000065
#
# Epoch [769/999] - Train Loss: 0.000077 - Val Loss: 0.000074
#
# Epoch [770/999] - Train Loss: 0.000074 - Val Loss: 0.000067
#
# Epoch [771/999] - Train Loss: 0.000074 - Val Loss: 0.000065
#
# Epoch [772/999] - Train Loss: 0.000073 - Val Loss: 0.000069
#
# Epoch [773/999] - Train Loss: 0.000073 - Val Loss: 0.000068
#
# Epoch [774/999] - Train Loss: 0.000073 - Val Loss: 0.000066
#
# Epoch [775/999] - Train Loss: 0.000071 - Val Loss: 0.000068
#
# Epoch [776/999] - Train Loss: 0.000072 - Val Loss: 0.000068
#
# Epoch [777/999] - Train Loss: 0.000073 - Val Loss: 0.000069
#
# Epoch [778/999] - Train Loss: 0.000071 - Val Loss: 0.000067
#
# Epoch [779/999] - Train Loss: 0.000071 - Val Loss: 0.000066
# Learning rate dropped to: 7.321462139183749e-05
#
# Epoch [780/999] - Train Loss: 0.000071 - Val Loss: 0.000064
#
# Epoch [781/999] - Train Loss: 0.000070 - Val Loss: 0.000066
#
# Epoch [782/999] - Train Loss: 0.000071 - Val Loss: 0.000067
#
# Epoch [783/999] - Train Loss: 0.000070 - Val Loss: 0.000067
#
# Epoch [784/999] - Train Loss: 0.000070 - Val Loss: 0.000064
#
# Epoch [785/999] - Train Loss: 0.000071 - Val Loss: 0.000067
#
# Epoch [786/999] - Train Loss: 0.000069 - Val Loss: 0.000067
#
# Epoch [787/999] - Train Loss: 0.000071 - Val Loss: 0.000065
#
# Epoch [788/999] - Train Loss: 0.000070 - Val Loss: 0.000066
#
# Epoch [789/999] - Train Loss: 0.000070 - Val Loss: 0.000065
#
# Epoch [790/999] - Train Loss: 0.000069 - Val Loss: 0.000063
#
# Epoch [791/999] - Train Loss: 0.000070 - Val Loss: 0.000065
#
# Epoch [792/999] - Train Loss: 0.000069 - Val Loss: 0.000065
#
# Epoch [793/999] - Train Loss: 0.000069 - Val Loss: 0.000064
#
# Epoch [794/999] - Train Loss: 0.000070 - Val Loss: 0.000063
#
# Epoch [795/999] - Train Loss: 0.000068 - Val Loss: 0.000066
#
# Epoch [796/999] - Train Loss: 0.000069 - Val Loss: 0.000066
#
# Epoch [797/999] - Train Loss: 0.000070 - Val Loss: 0.000064
#
# Epoch [798/999] - Train Loss: 0.000068 - Val Loss: 0.000065
#
# Epoch [799/999] - Train Loss: 0.000068 - Val Loss: 0.000066
#
# Epoch [800/999] - Train Loss: 0.000068 - Val Loss: 0.000063
#
# Epoch [801/999] - Train Loss: 0.000067 - Val Loss: 0.000063
#
# Epoch [802/999] - Train Loss: 0.000068 - Val Loss: 0.000064
#
# Epoch [803/999] - Train Loss: 0.000069 - Val Loss: 0.000064
#
# Epoch [804/999] - Train Loss: 0.000067 - Val Loss: 0.000064
#
# Epoch [805/999] - Train Loss: 0.000069 - Val Loss: 0.000064
#
# Epoch [806/999] - Train Loss: 0.000067 - Val Loss: 0.000062
#
# Epoch [807/999] - Train Loss: 0.000068 - Val Loss: 0.000063
#
# Epoch [808/999] - Train Loss: 0.000066 - Val Loss: 0.000063
#
# Epoch [809/999] - Train Loss: 0.000066 - Val Loss: 0.000063
#
# Epoch [810/999] - Train Loss: 0.000067 - Val Loss: 0.000063
#
# Epoch [811/999] - Train Loss: 0.000067 - Val Loss: 0.000065
#
# Epoch [812/999] - Train Loss: 0.000067 - Val Loss: 0.000063
#
# Epoch [813/999] - Train Loss: 0.000066 - Val Loss: 0.000063
#
# Epoch [814/999] - Train Loss: 0.000066 - Val Loss: 0.000061
#
# Epoch [815/999] - Train Loss: 0.000067 - Val Loss: 0.000063
#
# Epoch [816/999] - Train Loss: 0.000066 - Val Loss: 0.000063
#
# Epoch [817/999] - Train Loss: 0.000067 - Val Loss: 0.000062
#
# Epoch [818/999] - Train Loss: 0.000066 - Val Loss: 0.000062
#
# Epoch [819/999] - Train Loss: 0.000065 - Val Loss: 0.000061
#
# Epoch [820/999] - Train Loss: 0.000067 - Val Loss: 0.000061
#
# Epoch [821/999] - Train Loss: 0.000067 - Val Loss: 0.000063
#
# Epoch [822/999] - Train Loss: 0.000064 - Val Loss: 0.000062
#
# Epoch [823/999] - Train Loss: 0.000066 - Val Loss: 0.000061
#
# Epoch [824/999] - Train Loss: 0.000065 - Val Loss: 0.000062
#
# Epoch [825/999] - Train Loss: 0.000064 - Val Loss: 0.000061
# Learning rate dropped to: 3.6607310695918744e-05
#
# Epoch [826/999] - Train Loss: 0.000066 - Val Loss: 0.000061
#
# Epoch [827/999] - Train Loss: 0.000065 - Val Loss: 0.000062
#
# Epoch [828/999] - Train Loss: 0.000065 - Val Loss: 0.000062
#
# Epoch [829/999] - Train Loss: 0.000065 - Val Loss: 0.000061
#
# Epoch [830/999] - Train Loss: 0.000064 - Val Loss: 0.000061
#
# Epoch [831/999] - Train Loss: 0.000066 - Val Loss: 0.000061
#
# Epoch [832/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [833/999] - Train Loss: 0.000065 - Val Loss: 0.000060
#
# Epoch [834/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [835/999] - Train Loss: 0.000064 - Val Loss: 0.000061
#
# Epoch [836/999] - Train Loss: 0.000065 - Val Loss: 0.000061
#
# Epoch [837/999] - Train Loss: 0.000065 - Val Loss: 0.000061
#
# Epoch [838/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [839/999] - Train Loss: 0.000064 - Val Loss: 0.000061
#
# Epoch [840/999] - Train Loss: 0.000064 - Val Loss: 0.000062
#
# Epoch [841/999] - Train Loss: 0.000064 - Val Loss: 0.000062
#
# Epoch [842/999] - Train Loss: 0.000064 - Val Loss: 0.000061
#
# Epoch [843/999] - Train Loss: 0.000063 - Val Loss: 0.000061
#
# Epoch [844/999] - Train Loss: 0.000064 - Val Loss: 0.000061
#
# Epoch [845/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [846/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [847/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [848/999] - Train Loss: 0.000063 - Val Loss: 0.000060
#
# Epoch [849/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [850/999] - Train Loss: 0.000063 - Val Loss: 0.000060
#
# Epoch [851/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [852/999] - Train Loss: 0.000063 - Val Loss: 0.000061
#
# Epoch [853/999] - Train Loss: 0.000064 - Val Loss: 0.000061
#
# Epoch [854/999] - Train Loss: 0.000064 - Val Loss: 0.000061
#
# Epoch [855/999] - Train Loss: 0.000062 - Val Loss: 0.000060
#
# Epoch [856/999] - Train Loss: 0.000062 - Val Loss: 0.000060
#
# Epoch [857/999] - Train Loss: 0.000063 - Val Loss: 0.000060
#
# Epoch [858/999] - Train Loss: 0.000062 - Val Loss: 0.000060
#
# Epoch [859/999] - Train Loss: 0.000064 - Val Loss: 0.000060
#
# Epoch [860/999] - Train Loss: 0.000062 - Val Loss: 0.000060
#
# Epoch [861/999] - Train Loss: 0.000063 - Val Loss: 0.000059
#
# Epoch [862/999] - Train Loss: 0.000064 - Val Loss: 0.000059
#
# Epoch [863/999] - Train Loss: 0.000061 - Val Loss: 0.000060
#
# Epoch [864/999] - Train Loss: 0.000063 - Val Loss: 0.000059
#
# Epoch [865/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [866/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [867/999] - Train Loss: 0.000062 - Val Loss: 0.000059
#
# Epoch [868/999] - Train Loss: 0.000063 - Val Loss: 0.000058
#
# Epoch [869/999] - Train Loss: 0.000062 - Val Loss: 0.000059
#
# Epoch [870/999] - Train Loss: 0.000063 - Val Loss: 0.000058
#
# Epoch [871/999] - Train Loss: 0.000063 - Val Loss: 0.000059
#
# Epoch [872/999] - Train Loss: 0.000063 - Val Loss: 0.000060
#
# Epoch [873/999] - Train Loss: 0.000064 - Val Loss: 0.000059
#
# Epoch [874/999] - Train Loss: 0.000061 - Val Loss: 0.000058
#
# Epoch [875/999] - Train Loss: 0.000063 - Val Loss: 0.000059
#
# Epoch [876/999] - Train Loss: 0.000063 - Val Loss: 0.000058
#
# Epoch [877/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [878/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [879/999] - Train Loss: 0.000062 - Val Loss: 0.000059
#
# Epoch [880/999] - Train Loss: 0.000061 - Val Loss: 0.000059
#
# Epoch [881/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [882/999] - Train Loss: 0.000061 - Val Loss: 0.000059
#
# Epoch [883/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [884/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [885/999] - Train Loss: 0.000061 - Val Loss: 0.000059
#
# Epoch [886/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [887/999] - Train Loss: 0.000061 - Val Loss: 0.000059
#
# Epoch [888/999] - Train Loss: 0.000060 - Val Loss: 0.000058
# Learning rate dropped to: 1.8303655347959372e-05
#
# Epoch [889/999] - Train Loss: 0.000061 - Val Loss: 0.000058
#
# Epoch [890/999] - Train Loss: 0.000062 - Val Loss: 0.000058
#
# Epoch [891/999] - Train Loss: 0.000060 - Val Loss: 0.000058
#
# Epoch [892/999] - Train Loss: 0.000062 - Val Loss: 0.000058
# Early stopping
# Saved best model at epoch 877
# Model trained successfully!
# Best model has been saved as: LC-SVD-DLinear.pth
# Step 4: Load the best epoch and plot the losses
# Model loaded
# C:\Users\ahetherington\AppData\Local\Temp\Mxt236\ahetherington_agastya\var\log\xwin\ipykernel_29812\2577301989.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))
# Step 5: Validate the model on test datared
# Input tensor (first sequence from the test data): (1, 30, 8)
#
#     Error summary
#     RRMSE [%]: 1.094
#     MAE: 0.529
#     MSE: 0.342
#
# Step 6: Forecast new snapshots
# Input tensor (last sequence from the test data): (1, 30, 8)
# Prediction shape [V.T]: (500, 8)
# Step 7: Reconstruct the new snapshots
#
#     Number of components: 2
#     Number of points in x: 449
#     Number of points in y: 199
#     Number of points in z: None
#
# Reconstructed test + forecast data: (2, 199, 449, 554)

# %%
test_forecast = forecast.copy()[..., :test_data.shape[-1]]

erroru = np.abs(test_data[0, ...] - test_forecast[0, ...])
errorv = np.abs(test_data[1, ...] - test_forecast[1, ...])

su = sv = test_data.shape[-1] - 1

fig, ax = plt.subplots(test_forecast.shape[0], 5, figsize=(15, 6), width_ratios=[25, 25, 1, 25, 1])
for axs in ax.flatten():
    axs.set(xticks=[], yticks=[])

ax[0, 0].set_ylabel('Y')
ax[0, 0].yaxis.set_label_coords(-0.025, .5)
ax[1, 0].set_ylabel('Y')
ax[1, 0].yaxis.set_label_coords(-0.025, .5)

ax[1, 0].set_xlabel('X')
ax[1, 1].set_xlabel('X')
ax[1, 3].set_xlabel('X')

ax[0, 0].contourf(test_data[0, ..., su], cmap='magma')
im1 = ax[0, 1].contourf(test_forecast[0, ..., su], cmap='magma')
im2 = ax[0, 3].contourf(erroru[..., su], cmap='magma')

ax[1, 0].contourf(test_data[1, ..., sv], cmap='magma')
im3 = ax[1, 1].contourf(test_forecast[1, ..., sv], cmap='magma')
im4 = ax[1, 3].contourf(errorv[..., sv], cmap='magma')

plt.colorbar(im1, cax=ax[0, 2])
plt.colorbar(im3, cax=ax[1, 2])
plt.colorbar(im2, cax=ax[0, 4])
plt.colorbar(im4, cax=ax[1, 4])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Use the pretrained model

# %%
def test_forecast(Ared, Tensor, esvd, seq_len, horizon, model_save_path, scaler_name, num_snaps):    
    time = list(np.linspace(0, Tensor.shape[-1] - 1, Tensor.shape[-1]).astype(int))

    U, S, V, n_modes, _, _ = LCSVD(Ared, Tensor, esvd, sensors, time)
    S = np.diag(S)
    V = V.T 

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = DLinear(sequence = seq_len, horizon = horizon, kernel_size = seq_len + 1 if 
                (seq_len + 1) % 2 != 0 else seq_len, individual = True, input_size = n_modes)
        
    model.to(device)
    print(model)
    total_params = sum(p.numel() for p in model.parameters())
    learn_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'Total parameters: {total_params}')
    print(f'Learnable parameters: {learn_params}')

    model.load_state_dict(torch.load(model_save_path))
    model.eval()

    with open(f"{scaler_name}.pkl", "rb") as f:
        data_scaler = pickle.load(f)

    test = V[:, -seq_len:]

    test_seq = data_scaler.transform(test.transpose(1, 0))

    X = test_seq[np.newaxis, :, :].astype(float) 

    seq = torch.tensor(X.copy()).float().to(device) 

    preds = [] 

    with torch.no_grad():
        for i in range(num_snaps):
            y = model(seq)
            pred = y.detach().cpu().numpy()
            preds.append(data_scaler.inverse_transform(pred) ) # de-scale data
            seq = torch.cat((seq, y[None, :, :]), axis = 1)
            seq = seq[:, -seq_len:, :]
    
    forecast_sV = np.array(preds)

    print(f'Prediction shape [V.T]: {forecast_sV.squeeze().shape}')

    indxs = np.arange(len(np.array(V.T)), len(np.array(preds)) + len(np.array(V.T)))

    labels = ['Test data', 'Forecast']

    fig, ax = plt.subplots(2, 2, figsize = (10, 10))
    for i, axs in zip(range(4), ax.flatten()):
        axs.plot(V.T[:, i].squeeze() , c = 'k')
        axs.plot(indxs, np.array(preds)[..., i].squeeze(), c = 'red', alpha = 0.7)
        axs.set(title = f'Mode: {i + 1}')
        if i <= 1:
            axs.set(xticks = [])
    
    fig.tight_layout()
    fig.subplots_adjust(bottom = 0.1075)
    fig.legend(labels=labels, loc="lower center", ncol=2)
    
    plt.show()

    forecast = U @ S @ np.concatenate([V, forecast_sV.squeeze().T], axis = 1) 

    nv, ny, nx, _ = Tensor.shape
    forecast = forecast.reshape((nv, ny, nx, -1))
    nz = None
        
    print(f'''
    Number of components: {nv}
    Number of points in x: {nx}
    Number of points in y: {ny}
    Number of points in z: {nz}
    ''')

    print(f'Reconstructed test + forecast data: {forecast.shape}')

    return forecast

# %% [markdown]
# #### Loading and generating the required data
# Run cells from `[10]` to `[12]` (both included) to generate the datasets

# %%
seq_len = 30
horizon = 1
esvd = 1e-2
model_save_path = 'LC-SVD-DLinear.pth'
scaler_name = 'LC-SVD-DLinear_scaler'
num_snaps = 500

new_tensor = test_forecast(syntheticExperimentalTensor, numericalTensor, esvd, seq_len, horizon, model_save_path, scaler_name, num_snaps)
# Out:
# DLinear(
#   (decomposition): series_descomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(31,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): ModuleList(
#     (0-7): 8 x Linear(in_features=30, out_features=1, bias=True)
#   )
#   (Linear_Trend): ModuleList(
#     (0-7): 8 x Linear(in_features=30, out_features=1, bias=True)
#   )
# )
# Total parameters: 496
# Learnable parameters: 496
# C:\Users\ahetherington\AppData\Local\Temp\Mxt236\ahetherington_agastya\var\log\xwin\ipykernel_29812\1863334796.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))
# Prediction shape [V.T]: (500, 8)
#     Number of components: 2
#     Number of points in x: 449
#     Number of points in y: 199
#     Number of points in z: None
#
# Reconstructed test + forecast data: (2, 199, 449, 651)

# %%
### Display the last forecast snapshot
fig, ax = plt.subplots(1, 3, width_ratios = [25, 25, 1], figsize = (12, 4))

ax[0].contourf(new_tensor[0, ..., -1])
ax[0].set(title = 'Num. - Streamwise velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
im1 = ax[1].contourf(new_tensor[1, ..., -1])
ax[1].set(title = 'Num. - Normal velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
plt.colorbar(im1, cax = ax[2]);
