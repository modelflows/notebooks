# %% [markdown]
# ## SVD-DLinear
# Official implementation of the hybrid SVD-DLinear model.
#
# [Hetherington, Ashton, Javier López Leonés, and Soledad Le Clainche. "LC-SVD-DLinear: A low-cost physics-based hybrid machine learning model for data forecasting using sparse measurements." arXiv preprint arXiv:2411.17433 (2024)](https://arxiv.org/abs/2411.17433)
#
# **Description**
#
# SVD-DLinear and HOSVD-DLinear are hybrid physics-informed neural networks designed for forecasting fluid dynamics datasets. Contrary to LC-SVD-DLinear and LC-HOSVD-DLinear, these models use high-resolution data directly.

# %%
# Install libraries
# !pip install -q optuna torch termcolor

# %%
### Imports
import numpy as np
from termcolor import colored
import pickle
from scipy.io import loadmat
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy.stats import pearsonr 
from scipy.fftpack import fft

import optuna
from optuna.trial import TrialState
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt

# %matplotlib inline

# Configure the plot appearance
plt.rc('axes', labelsize = 18)
plt.rc('axes', titlesize = 18)
plt.rc('legend', fontsize = 22)
plt.rc('figure', titlesize = 24)
plt.rc('xtick', labelsize = 16)
plt.rc('ytick', labelsize = 16)

# %% [markdown]
# ### Use cases
# You can run this notebook two different ways:
# 1. Train the model from scratch. In this case, run the entire notebook.
# 2. Use the pretrained model for the test case to generate predictions. Skip to the **Using a pretrained model** section, or cell `[58]`.

# %% [markdown]
# ### Callbacks

# %%
### Early stopping callback
class EarlyStopping():
  '''
  Callback used to avoid model overfitting during training. If the validation
  loss does not improve during a number of epochs, the model will stop training.
  Args:
      - patience: number of epochs evaluated after validation loss plateau, before stopping training
      - model_save_path: name of the file where the model parameters are saved
      - min_delta: minumum variation of validation loss between iterations
          val_loss[n] - val_loss[n - 1] <= min_delta
  '''
  def __init__(self, patience, model_save_path, min_delta = 0):
      self.patience = patience
      self.min_delta = min_delta
      self.model_save_path = model_save_path
      self.counter = 0
      self.min_validation_loss = np.inf
      self.best_epoch = 0
      self.early_stop = False

  def __call__(self, epoch, model, validation_loss):
      delta_loss = self.min_validation_loss - validation_loss
      if delta_loss > self.min_delta:
          self.min_validation_loss = validation_loss
          self.counter = 0
          self.best_epoch = epoch
          torch.save(model.state_dict(), self.model_save_path)
      else:
          self.counter += 1
          if self.counter >= self.patience:
              print('Early stopping')
              print(f'Saved best model at epoch {self.best_epoch}')
              self.early_stop = True

# Reduce LR on plateau
class LRScheduler():
  '''
  Reduce optimizer learning rate when the model validation loss does not improve
  Args:
      - optimizer: optimizer used during training (SGD, Adam, Adam, etc.)
      - patience: number of epochs evaluated after a possible learning rate plateau before applying a decrease
      - min_lr: minimum learning rate value. Default is 1e-06
      - factor: value by which the learning rate is reduced. Default is 0.5
  '''
  def __init__(self, lr, optimizer, patience, min_lr = 1e-6, factor = 0.5):
      self.optimizer = optimizer
      self.patience = patience
      self.min_lr = min_lr
      self.prev_lr = lr
      self.factor = factor
      self.lr_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer,
                                                                      mode = 'min',
                                                                      patience = self.patience,
                                                                      factor = self.factor,
                                                                      min_lr = self.min_lr)
  def __call__(self, val_loss):
      self.lr_scheduler.step(val_loss)
      curr_lr = self.optimizer.param_groups[0]['lr']
      if curr_lr < self.prev_lr:
          print(f'Learning rate dropped to: {curr_lr}')
      self.prev_lr = curr_lr

# %% [markdown]
# ### Hyperparameter tuner

# %%
def hyperFinder(train_dataset, val_dataset, model, device):
    '''
    Function used to find optimal hyperparameter values
    Args:
        - train_dataset: dataset containing training data
        - val_dataset: dataset containing validation data
        - model: forecast model class which requires tuning
        - device: device used for training: cuda:0 or cpu
    Returns:
        - train_loader: train dataloader with the optimal batch size
        - val_loader: validation dataloader with the optimal batch_size
        - learning_rate: optimal learning rate
        - weight_decay: optimal weight decay
    '''
    def objective(trial):
        epochs = 50

        weight_decay = trial.suggest_float('weight_decay', 1e-15, 1e-02, log = True)
        lr = trial.suggest_float("lr", 1e-04, 1e-02, log = True)

        optimizer = torch.optim.Adam(model.parameters(), lr = lr, weight_decay = weight_decay)

        batch_size = trial.suggest_categorical("batch_size", [4, 8, 16, 32])
        
        train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True, drop_last = True)
        val_loader = DataLoader(val_dataset, batch_size = batch_size, shuffle = False)

        loss_fn = nn.MSELoss()

        train_loss = 0.0
        num_train_batches = len(train_loader)
        num_val_batches = len(val_loader)
        val_loss = 0.0

        for epoch in range(epochs):
            model.train()

            for X, y in train_loader:
                X, y = X.to(device), y.to(device)
                optimizer.zero_grad()
                output = model(X)
                loss = loss_fn(output, y)
                loss.backward()
                optimizer.step()

                train_loss += loss.item()

            # train_avg_loss = train_loss / num_train_batches

            model.eval()
            with torch.no_grad():
                for X, y in val_loader:
                    X, y = X.to(device), y.to(device)
                    output = model(X)
                    val_loss += loss_fn(output, y)

            val_avg_loss = val_loss / num_val_batches

            trial.report(val_avg_loss, epoch)

            if trial.should_prune():
                raise optuna.exceptions.TrialPruned()

        return val_avg_loss

    study = optuna.create_study(direction = "minimize")
    study.optimize(objective, n_trials = 50)
    pruned_trials = study.get_trials(deepcopy = False, states = [TrialState.PRUNED])
    completed_trials = study.get_trials(deepcopy=False, states = [TrialState.COMPLETE])

    print('Study statistics: ')
    print('     Number of finished trials: ', len(study.trials))
    print('     Number of pruned trials: ', len(pruned_trials))
    print('     Number of completed trials: ', len(completed_trials))

    print('Best trial: ')
    trial = study.best_trial
    print('     Value: ', trial.value)

    print('     Params: ')
    for key, value in trial.params.items():
        print('    {}: {}'.format(key, value))

    optimal_params = trial.params

    train_loader = DataLoader(train_dataset, batch_size = optimal_params['batch_size'], shuffle = True, drop_last = True)
    val_loader = DataLoader(val_dataset, batch_size = optimal_params['batch_size'], shuffle = False)

    return train_loader, val_loader, optimal_params['lr'], optimal_params['weight_decay']

# %% [markdown]
# ### The DLinear architecture

# %%
class moving_avg(nn.Module):
    def __init__(self, kernel_size, stride):
        super(moving_avg, self).__init__()
        self.kernel_size = kernel_size
        self.avg = nn.AvgPool1d(kernel_size = kernel_size, stride = stride, padding = 0)

    def forward(self, x):
        front = x[:, 0:1, :].repeat(1, (self.kernel_size - 1) // 2, 1)
        end = x[:, -1:, :].repeat(1, (self.kernel_size -1) // 2, 1)
        x = torch.cat([front, x, end], dim = 1)
        x = self.avg(x.permute(0, 2, 1))
        x = x.permute(0, 2, 1)
        return x

class series_descomp(nn.Module):
    '''
    Applies a moving average to the input sequence, and decomposes the sequence into trend and seasonality
    '''
    def __init__(self, kernel_size):
        super(series_descomp, self).__init__()
        self.moving_avg = moving_avg(kernel_size, stride = 1)

    def forward(self, x):
        moving_mean = self.moving_avg(x)
        res = x - moving_mean
        return res, moving_mean

class DLinear(nn.Module):
    def __init__(self, input_size, kernel_size, sequence, horizon, individual):
        '''
        Decomposes an input sequence into trend and seasonality, and predicts the next value(s)
        Args:
            - input_size: number of modes
            - kernel_size: size of the kernel used to extract the trend
            - sequence: length of the input sequence
            - horizon: length of the forecast sequence
            - individual (bool): set to true if only a singular mode is being predicted 
        '''
        super(DLinear, self).__init__()
        self.Lag = sequence
        self.Horizon = horizon

        kernel_size = kernel_size
        self.decomposition = series_descomp(kernel_size)
        self.individual = individual
        self.channels = input_size

        self.Linear_Seasonal = nn.ModuleList()
        self.Linear_Trend = nn.ModuleList()

        for i in range(self.channels):
            self.Linear_Seasonal.append(nn.Linear(self.Lag, self.Horizon))
            self.Linear_Seasonal[i].weight = nn.Parameter((1 / self.Lag) * torch.zeros([self.Horizon, self.Lag])) # changed from ones to zeros
            self.Linear_Trend.append(nn.Linear(self.Lag, self.Horizon))
            self.Linear_Trend[i].weight = nn.Parameter((1 / self.Lag) * torch.zeros([self.Horizon, self.Lag])) # changed from ones to zeros

    def forward(self, x): # x: [Batch_size, Input_length, Channels]
        seasonal_init, trend_init = self.decomposition(x)
        seasonal_init, trend_init = seasonal_init.permute(0, 2, 1), trend_init.permute(0, 2, 1)

        seasonal_output = torch.zeros([seasonal_init.size(0), seasonal_init.size(1), self.Horizon], dtype = seasonal_init.dtype).to(seasonal_init.device)
        trend_output = torch.zeros([trend_init.size(0), trend_init.size(1), self.Horizon], dtype = trend_init.dtype).to(trend_init.device)
        
        for i in range(self.channels):
            seasonal_output[:, i, :] = self.Linear_Seasonal[i](seasonal_init[:, i, :])
            trend_output[:, i, :] = self.Linear_Trend[i](trend_init[:, i, :])

        x = seasonal_output + trend_output # x -> [batch, channels, horizon]
        return x.reshape(-1, self.channels) if self.Horizon == 1 else x.reshape(-1, self.Horizon, self.channels) # [Batch_size, Output_length, Channel]

# %% [markdown]
# ### Sequence generator and tensor dataset

# %%
def seqGenerator(Tensor, seq_len, horizon):
    '''
    Creates the sequences for the forecasting model
    Args:
      - Tensor: input tensor, which is the product of singular values and temporal coefficients
      - seq_len: length of the sequence of snapshots used to predict
      - horizon: number of snapshots predicted
    Returns:
      - an array containing the input sequences
      - an array containing the output horizons
    '''
    X = []
    y = []

    max_index = Tensor.shape[-1] - seq_len - horizon + 1

    for i in range(max_index):
        X.append(Tensor[:, i: i + seq_len]) # Take the last seq_len snapshots
        y.append(Tensor[:, i + seq_len: i + seq_len + horizon]) # Predict the horizon

    return np.array(X), np.array(y)

class TimeSeriesDataset(Dataset):
  '''
  Create a dataset by pairing sequences with their horizons
  Args:
      - X: sequence of the features
      - y: target value horizon
  '''
  def __init__(self, X, y):
      self.X = torch.tensor(X, dtype=torch.float32)
      self.y = torch.tensor(y, dtype=torch.float32)

  def __getitem__(self, idx):
      features = self.X[idx]
      targets = self.y[idx]
      return features, targets

  def __len__(self):
      return len(self.X)

# %% [markdown]
# ### Train and validation functions

# %%
def train_model(data_loader, model, loss_function, optimizer, device):
    '''
    Forecast model training function
    Args:
        - data_loader: torch dataloader object
        - model: forecasting model
        - loss_function: loss function used for training
        - optimizer: optimizer used for training
        - device: device used for training: cuda:0 or cpu
    Returns:
        - train_avg_loss: average train loss for one epoch
    '''
    num_batches = len(data_loader)
    total_loss = 0

    model.train()

    for X, y in data_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        output = model(X)
        loss = loss_function(output, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    train_avg_loss = total_loss / num_batches

    return train_avg_loss

def val_model(data_loader, model, loss_function, device):
    '''
    Forecast model validation function
    Args:
        - data_loader: torch dataloader object
        - model: forecasting model
        - loss_function: loss function used for validation (same as training)
        - device: device used for training: cuda:0 or cpu
    Returns:
        - val_avg_loss: average validation loss for one epoch
    '''
    num_batches = len(data_loader)
    total_loss = 0
    model.eval()
    with torch.no_grad():
        for X, y in data_loader:
            X, y = X.to(device), y.to(device)
            output = model(X)
            total_loss += loss_function(output, y)

    val_avg_loss = total_loss / num_batches

    return val_avg_loss

# %% [markdown]
# ### Data Scaling

# %%
def scaler(sV: np.ndarray, split: float = 0.7, type: str = 'minmax', scaler_name = 'SVD-DLinear_scaler'):
    '''
    Scales the input data using max-per-mode scaling and splits the data into train, validation and test
    Args:
        - sV: input matrix which is V.T
        - split: percentage of the input data that correspondes to training. Remaining part it split into two, for val. and test.
        - type: type of scaling to perform, which can be standard or minmax
        - scaler_name: name used to save the scaler
    Returns:
        - train: scaled train data
        - val: scaled validation data
        - test: scaled test data
        - train_idx: cut-off index corresponding to the training data set
        - val_idx: cut-off index corresponding to the validation data set
        - scaler: scaler object
    '''

    train_split = split
    val_split = (1 - train_split) / 2
    
    samples = sV.shape[-1]
    
    train_idx = int(samples * train_split)
    val_idx = int(samples * val_split)
    
    train = sV[:, :train_idx]
    val = sV[:, train_idx: train_idx + val_idx]
    test = sV[:, train_idx + val_idx:]

    if type.lower() == 'standard':
        scaler = StandardScaler()

    if type.lower() == 'minmax':
        scaler = MinMaxScaler(feature_range=(0, 1))

    train = scaler.fit_transform(train.transpose(1, 0)).transpose(1, 0)
    val = scaler.transform(val.transpose(1, 0)).transpose(1, 0)
    test = scaler.transform(test.transpose(1, 0)).transpose(1, 0)

    with open(f"{scaler_name}.pkl", "wb") as f:
        pickle.dump(scaler, f)

    return train, val, test, train_idx, val_idx, scaler

# %% [markdown]
# ### Error evaluation functions

# %%
def compute_MAE(y_true, y_pred): 
    '''
    Mean absolute error function
    Args:
        y_true: ground truth values
        y_pred: predicted values
    Return:
        Mean Absolute Error (MAE)
    '''  
    return np.mean(np.abs(y_true - y_pred))

def compute_MAPE(y_true, y_pred): 
    '''
    Mean absolute percentual error function
    Args:
        y_true: ground truth values
        y_pred: predicted values
    Return:
        Mean Absolute Percentual Error (MAPE)
    '''  
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def compute_MSE(y_true, y_pred):
    '''
    Relative mean squared error function
    Args:
        y_true: ground truth values
        y_pred: predicted values
    Return:
        Mean Squared Error (RMSE)
    '''  
    return np.mean((y_true - y_pred) ** 2)

def compute_PCC(y_true, y_pred):
    '''
    Compute the PCC score of the predictions
    Args:
        y_true: ground truth values
        y_pred: predicted values
    Return:
        PCC score
    '''  
    corrs = []
    for i in range(y_true.shape[-1]):
        PCC = pearsonr(y_true[..., i].flatten(), y_pred[..., i].flatten())[0]
        corrs.append(PCC)

    return np.mean(np.array(corrs))

# %% [markdown]
# ### Load the input data
# Here, we load the numerical dataset and create a synthetic experimental dataset

# %%
### Data is usually stored in .mat format
numericalTensor = list(loadmat('Tensor_cylinder_Re100.mat').values())[-1]

### Display both datasets
fig, ax = plt.subplots(1, 3, width_ratios = [25, 25, 1], figsize = (12, 4))

# Numerical dataset
ax[0].contourf(numericalTensor[0, ..., 0])
ax[0].set(title = 'Num. - Streamwise velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
im1 = ax[1].contourf(numericalTensor[1, ..., 0])
ax[1].set(title = 'Num. - Normal velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
plt.colorbar(im1, cax = ax[2])

# %% [markdown]
# ### Creating a pipeline to preprocess the data
# The goal is to forecast the next snapshots in high resolution.

# %%
def svdpreprocessing(Tensor, esvd, batch_size, seq_len, horizon, scaler_type, scaler_name):
    Tensor = np.reshape(Tensor, (-1, Tensor.shape[-1]))
    
    U, S, V = np.linalg.svd(Tensor, full_matrices = False)
    
    n_modes = 0
    norm = np.linalg.norm(S)
    
    for i in range(S.size):
        if np.linalg.norm(S[i:]) / norm <= esvd:
            pass
        else:
            n_modes += 1

    A_reconst = U[:, :n_modes] @ np.diag(S[:n_modes]) @ V[:n_modes, :]

    U = U[:, :n_modes]
    S = np.diag(S[:n_modes])
    V = V[:n_modes, :]

    print(f'''
Singular value decomposition summary
        - n_modes (retained modes): {n_modes}
        - U (POD modes): {U.shape}
        - S (singular values): {S.shape}
        - V (temporal coefficients): {V.shape}
        - TensorAprox (reconstructed tensor): {A_reconst.shape}
        ''')
    
    ### SVD modes evolution    
    fig, ax = plt.subplots(1, 1)
    for i in range(S.shape[0]):
        ax.plot(i + 1, S[i][i] / S[0][0], "ko") 
        
    ax.set_yscale('log')      # Logarithmic scale in y axis
    ax.set_xlabel('SVD modes')
    ax.set_ylabel('Singular values')
    ax.set_title('SVD modes vs. Singular values')
    plt.show()

    # Fourier 
    fig, ax = plt.subplots(2, 2, figsize = (10, 10))
    for i, axs in zip(range(4), ax.flatten()):
        axs.set(title = f'Mode: {i + 1}')
        temporal_coefficients = V[i, :].squeeze()
        fft_result = fft(temporal_coefficients)
        frequencies = np.fft.fftfreq(len(temporal_coefficients))
        axs.plot(frequencies[:len(frequencies)//2], np.abs(fft_result)[:len(frequencies)//2])
        if i > 1:
            axs.set_xlabel('Frequency')

        if i % 2 == 0:
            axs.set_ylabel('Amplitude')

    plt.show()

    if A_reconst.ndim == 5:
        nz = int(A_reconst.shape[-2] / 2)
        
        fig, ax = plt.subplots(1, 3, figsize = (10, 3))
        ax[0].contourf(A_reconst[0, ..., nz, 0], cmap = 'magma')
        ax[1].contourf(A_reconst[1, ..., nz,  0], cmap = 'magma')
        ax[2].contourf(A_reconst[2, ..., nz, 0], cmap = 'magma')
        ax[0].set(xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
        ax[1].set(xlabel = 'X', xticks = [], yticks = []) 
        ax[2].set(xlabel = 'X', xticks = [], yticks = []);

    elif A_reconst.ndim == 4:
        fig, ax = plt.subplots(1, 2, figsize = (10, 3))
        ax[0].contourf(A_reconst[0, ..., 0], cmap = 'magma')
        ax[1].contourf(A_reconst[1, ..., 0], cmap = 'magma')
        ax[0].set(xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
        ax[1].set(xlabel ='X', xticks = [], yticks = []);

    elif A_reconst.ndim == 3:
        fig, ax = plt.subplots(1, 1, figsize = (10, 3))
        ax.contourf(A_reconst[..., 0], cmap = 'magma')
        ax.set(xlabel = 'X', ylabel = 'Y');

    plt.suptitle('Tensor reconstructed using LC-HOSVD')
    plt.tight_layout()
    plt.show()
    
    split = 0.7

    print('Scaling the data...')        
    train, val, test, train_idx, val_idx, data_scaler = scaler(V, split, scaler_type, scaler_name)

    labels = ['Train', 'Validation', 'Test']
    fig, axs = plt.subplots(2, 2, figsize = (10, 4))
    for i, ax in zip(range(4), axs.flatten()):
        ax.set_title(f'Mode: {i + 1}')
        ax.plot(train[i, :], c = 'red')
        ax.plot(range(train_idx, train_idx + val_idx), val[i, :], c = 'blue')
        ax.plot(range(train_idx + val_idx, V.shape[-1]), test[i, :], c = 'green')
        if i <= 1:
            ax.set(xticks = [])

        if i % 2 != 0:
            ax.set(yticks = [])
        

    fig.tight_layout()
    fig.subplots_adjust(bottom = 0.3)
    fig.legend(labels = labels, loc="lower center", ncol=3)
    
    plt.show()

    original_test = Tensor[..., train_idx + val_idx:]

    val = np.concatenate([train[:, -seq_len:], val], axis = 1)
    test = np.concatenate([val[:, -seq_len:], test], axis = 1)

    print(f'''
Split summary
    - Train samples: {train.shape}
    - Validation samples: {val.shape}
    - Test samples: {test.shape}
        ''')
    
    print('Creating data sequences...\n')
    train_seq, train_horizon = seqGenerator(train, seq_len, horizon)
    val_seq, val_horizon = seqGenerator(val, seq_len, horizon)
    test_seq, test_horizon = seqGenerator(test, seq_len, horizon)

    train_seq, val_seq, test_seq = train_seq.transpose(0, 2, 1), val_seq.transpose(0, 2, 1), test_seq.transpose(0, 2, 1)
    train_horizon, val_horizon, test_horizon = train_horizon.squeeze(), val_horizon.squeeze(), test_horizon.squeeze()
    
    print('Creating PyTorch datasets...\n')
    train_ds = TimeSeriesDataset(train_seq, train_horizon)
    val_ds = TimeSeriesDataset(val_seq, val_horizon)
    test_ds = TimeSeriesDataset(test_seq, test_horizon)

    print('Generating data loaders...\n')
    train_loader = DataLoader(train_ds, batch_size = batch_size, shuffle = True, drop_last = True)
    val_loader = DataLoader(val_ds, batch_size = batch_size, shuffle = False)
    test_loader = DataLoader(test_ds, batch_size = 1, shuffle = False)

    sample = next(iter(train_loader))
    print(f'Singular batch of the features (sequence): {sample[0].shape}')
    print(f'Singular batch of the target (horizon): {sample[1].shape}')

    print('\nData preprocessing complete!')

    return original_test, test, train_loader, val_loader, test_loader, n_modes, \
    train_ds, val_ds, U, S, train_seq, val_seq, test_seq, data_scaler

# %% [markdown]
# ### Full data preprocessing and model training pipeline

# %%
def generator(Tensor, esvd, seq_len, horizon, batch_size, epochs, scaler_type, optimal, snapshots, model_save_path = 'SVD-DLinear.pth',
              scaler_name = 'SVD-DLinear_scaler'):

    print(colored('Step 1: Data preprocessing', 'red', attrs=["bold"]))
    test_data, test, train_loader, val_loader, test_loader, n_modes, train_ds, \
    val_ds, U, S, train_seq, val_seq, test_seq, data_scaler = svdpreprocessing(Tensor, esvd, batch_size, seq_len, horizon, scaler_type, scaler_name)

    print(colored('Step 2: Model definition', 'red', attrs=["bold"]))
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    
    model = DLinear(sequence = seq_len, horizon = horizon, kernel_size = seq_len + 1 if 
                    (seq_len + 1) % 2 != 0 else seq_len, individual = True, input_size = n_modes)

    model.to(device)
    print(model)
    total_params = sum(p.numel() for p in model.parameters())
    learn_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'Total parameters: {total_params}')
    print(f'Learnable parameters: {learn_params}')

    print(colored('Step 3: Model training with optimal hyperparams.', 'red', attrs=["bold"]))
    all_losses = []
    loss_fn = nn.MSELoss()

    if not optimal:
        learning_rate = 0.000174
        batch_size = 4
        
        optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)

    else:
        train_loader, val_loader, learning_rate, weight_decay = hyperFinder(train_ds, val_ds, model, device)
        # Reinstanciate the model to avoid data leaking
        del model
        model = DLinear(sequence = seq_len, horizon = horizon, kernel_size = seq_len + 1 if 
                    (seq_len + 1) % 2 != 0 else seq_len, individual = True, input_size = n_modes)

        optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate, weight_decay = weight_decay)

    lr_patience = 10   
    es_patience = 15
    factor = 0.5

    lr_scheduler = LRScheduler(lr = learning_rate, optimizer = optimizer, patience = lr_patience, factor = factor)
    early_stopper = EarlyStopping(patience = es_patience, model_save_path = model_save_path)

    for epoch in range(epochs):
        train_loss = train_model(train_loader, model, loss_fn, optimizer, device)
        val_loss = val_model(val_loader, model, loss_fn, device)
        all_losses.append([train_loss, val_loss])

        print(f'\nEpoch [{epoch}/{epochs - 1}] - Train Loss: {train_loss:.6f} - Val Loss: {val_loss:.6f}')

        early_stopper(epoch, model, val_loss)
        if early_stopper.early_stop:
            break

        lr_scheduler(val_loss)

    print('Model trained successfully!')
    print(f'Best model has been saved as: {model_save_path}')

    print(colored('Step 4: Load the best epoch and plot the losses', 'red', attrs=["bold"]))
    model.load_state_dict(torch.load(model_save_path))
    model.eval()
    print('Model loaded')

    fig, ax = plt.subplots(1, 1, figsize = (6, 6))
    ax.plot(np.array(all_losses)[:, 0].reshape(-1, 1), c = 'k', label = 'Train loss')
    ax.plot(np.array(all_losses)[:, 1].reshape(-1, 1), c = 'r', label = 'Validation loss')
    ax.set_xlabel('Epochs')
    ax.set_ylabel('MSE')
    ax.set_title('Training vs. Validation loss')
    ax.legend(loc = 'best')
    plt.show()

    print(colored('Step 5: Validate the model on test data' 'red', attrs=["bold"]))
    preds = []

    X = test_seq[0][np.newaxis, :, :].astype(float) 

    print(f'Input tensor (first sequence from the test data): {X.shape}')

    seq = torch.tensor(X.copy()).float().to(device) 

    num_snaps = test_data.shape[-1]

    with torch.no_grad():
        for i in range(num_snaps):
            y = model(seq)
            pred = y.detach().cpu().numpy()
            preds.append(data_scaler.inverse_transform(pred )) # de-scale data
            seq = torch.cat((seq, y[None, :, :]), axis = 1)
            seq = seq[:, -seq_len:, :]

    pred = U @ S @ np.array(preds).squeeze().T

    shape_ = test_data.shape

    pred = np.reshape(pred, shape_)

    RRMSE = np.linalg.norm(np.reshape(test_data - np.array(pred), newshape=(np.size(test_data), 1)), ord = 2) / np.linalg.norm(np.reshape(test_data, newshape = (np.size(test_data), 1))) * 100

    print(f'''
    Error summary
    RRMSE [%]: {RRMSE:.3f}
    MAE: {compute_MAE(test[:, seq_len:].T, np.array(preds).squeeze()):.3f}
    MSE: {compute_MSE(test[:, seq_len:].T, np.array(preds).squeeze()):.3f}
    ''')

    fig, ax = plt.subplots(2, 2, figsize = (10, 10))
    labels = ['Ground truth', 'Forecast']
    for i, axs in zip(range(4), ax.flatten()):
        test_modes = data_scaler.inverse_transform(test.T)[seq_len:, i].squeeze() 
        axs.plot(test_modes, c = 'k')
        axs.plot(np.array(preds)[..., i].squeeze(), alpha = 0.7, c = 'red')
        axs.set(title = f'Mode: {i + 1}')
        if i <= 1:
            axs.set(xticks = [])

    fig.tight_layout()
    fig.subplots_adjust(bottom = 0.1075)
    fig.legend(labels=labels, loc="lower center", ncol=2)

    print(colored('Step 6: Forecast new snapshots', 'red', attrs=["bold"]))

    X = test_seq[-1][np.newaxis, :, :].astype(float) 

    print(f'Input tensor (last sequence from the test data): {X.shape}')

    seq = torch.tensor(X.copy()).float().to(device) 

    preds = [] 

    num_snaps = snapshots

    with torch.no_grad():
        for i in range(num_snaps):
            y = model(seq)
            pred = y.detach().cpu().numpy()
            preds.append(data_scaler.inverse_transform(pred) ) # de-scale data
            seq = torch.cat((seq, y[None, :, :]), axis = 1)
            seq = seq[:, -seq_len:, :]
    
    forecast_sV = np.array(preds)

    print(f'Prediction shape [V.T]: {forecast_sV.squeeze().shape}')

    indxs = np.arange(len(np.array(test.T)), len(np.array(preds)) + len(np.array(test.T)))
    test_indxs = np.arange(len(np.array(test.T)))

    labels = ['Test data', 'Forecast']

    fig, ax = plt.subplots(2, 2, figsize = (10, 10))
    for i, axs in zip(range(4), ax.flatten()):
        axs.plot(data_scaler.inverse_transform(test.T)[:, i].squeeze() , c = 'k')
        axs.plot(indxs, np.array(preds)[..., i].squeeze(), c = 'red', alpha = 0.7)
        axs.set(title = f'Mode: {i + 1}')
        if i <= 1:
            axs.set(xticks = [])
    
    fig.tight_layout()
    fig.subplots_adjust(bottom = 0.1075)
    fig.legend(labels=labels, loc="lower center", ncol=2)
    
    plt.show()

    print(colored('Step 7: Reconstruct the new snapshots', 'red', attrs=["bold"]))
    forecast = U @ S @ (np.concatenate([data_scaler.inverse_transform(test.transpose(1, 0)), forecast_sV.squeeze()], axis = 0).T )

    nv, ny, nx, _ = Tensor.shape
    forecast = forecast.reshape((nv, ny, nx, -1))
    nz = None
        
    print(f'''
    Number of components: {nv}
    Number of points in x: {nx}
    Number of points in y: {ny}
    Number of points in z: {nz}
    ''')

    print(f'Reconstructed test + forecast data: {forecast.shape}')

    return test_data, forecast, test

# %% [markdown]
# ### Training and testing the model

# %%
# Select the parameters
esvd = 1e-2
seq_len = 30
horizon = 1
scaler_type = 'minmax'
batch_size = 4
snapshots = 500
optimal = True
epochs = 1000

# Preprocess the data and train the model
test_data, forecast, test = generator(numericalTensor, esvd, seq_len, horizon, batch_size, epochs, scaler_type, optimal, snapshots)
# Out:
# Step 1: Data preprocessing
#
# Singular value decomposition summary
#         - n_modes (retained modes): 8
#         - U (POD modes): (178702, 8)
#         - S (singular values): (8, 8)
#         - V (temporal coefficients): (8, 151)
#         - TensorAprox (reconstructed tensor): (178702, 151)
# Scaling the data...
# [I 2025-03-27 19:42:38,079] A new study created in memory with name: no-name-053d3d1b-00d4-4511-ae91-782375a3ee55
# Split summary
#     - Train samples: (8, 105)
#     - Validation samples: (8, 52)
#     - Test samples: (8, 54)
#
# Creating data sequences...
#
# Creating PyTorch datasets...
#
# Generating data loaders...
#
# Singular batch of the features (sequence): torch.Size([4, 30, 8])
# Singular batch of the target (horizon): torch.Size([4, 8])
#
# Data preprocessing complete!
# Step 2: Model definition
# DLinear(
#   (decomposition): series_descomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(31,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): ModuleList(
#     (0-7): 8 x Linear(in_features=30, out_features=1, bias=True)
#   )
#   (Linear_Trend): ModuleList(
#     (0-7): 8 x Linear(in_features=30, out_features=1, bias=True)
#   )
# )
# Total parameters: 496
# Learnable parameters: 496
# Step 3: Model training with optimal hyperparams.
# [I 2025-03-27 19:42:39,018] Trial 0 finished with value: 11.57772159576416 and parameters: {'weight_decay': 2.025470002201028e-07, 'lr': 0.00011215268061748795, 'batch_size': 32}. Best is trial 0 with value: 11.57772159576416.
# [I 2025-03-27 19:42:47,064] Trial 1 finished with value: 0.011859394609928131 and parameters: {'weight_decay': 2.976991844930164e-09, 'lr': 0.005470167331566269, 'batch_size': 4}. Best is trial 1 with value: 0.011859394609928131.
# [I 2025-03-27 19:42:56,302] Trial 2 finished with value: 0.0005252122646197677 and parameters: {'weight_decay': 1.8556582778620975e-14, 'lr': 0.0001579323157799663, 'batch_size': 4}. Best is trial 2 with value: 0.0005252122646197677.
# [I 2025-03-27 19:43:05,398] Trial 3 finished with value: 0.0009743369300849736 and parameters: {'weight_decay': 9.750574941132226e-05, 'lr': 0.0006639814440314765, 'batch_size': 4}. Best is trial 2 with value: 0.0005252122646197677.
# [I 2025-03-27 19:43:06,930] Trial 4 finished with value: 0.0003956661093980074 and parameters: {'weight_decay': 4.463261628811296e-07, 'lr': 0.00031721432335284354, 'batch_size': 32}. Best is trial 4 with value: 0.0003956661093980074.
# [I 2025-03-27 19:43:08,451] Trial 5 finished with value: 0.00047360564349219203 and parameters: {'weight_decay': 8.806540547043664e-15, 'lr': 0.0005207473758904128, 'batch_size': 32}. Best is trial 4 with value: 0.0003956661093980074.
# [I 2025-03-27 19:43:18,346] Trial 6 finished with value: 0.00039325261604972184 and parameters: {'weight_decay': 8.69343753780242e-05, 'lr': 0.0001244053051717936, 'batch_size': 4}. Best is trial 6 with value: 0.00039325261604972184.
# [I 2025-03-27 19:43:18,462] Trial 7 pruned.
# [I 2025-03-27 19:43:18,508] Trial 8 pruned.
# [I 2025-03-27 19:43:18,563] Trial 9 pruned.
# [I 2025-03-27 19:43:18,685] Trial 10 pruned.
# [I 2025-03-27 19:43:18,713] Trial 11 pruned.
# [I 2025-03-27 19:43:18,786] Trial 12 pruned.
# [I 2025-03-27 19:43:18,979] Trial 13 pruned.
# [I 2025-03-27 19:43:27,511] Trial 14 finished with value: 0.00045659253373742104 and parameters: {'weight_decay': 9.285398940813097e-08, 'lr': 0.00010498863805553571, 'batch_size': 4}. Best is trial 6 with value: 0.00039325261604972184.
# [I 2025-03-27 19:43:28,514] Trial 15 finished with value: 0.00035381055204197764 and parameters: {'weight_decay': 0.00011614172714504388, 'lr': 0.0001742050687432092, 'batch_size': 32}. Best is trial 15 with value: 0.00035381055204197764.
# [I 2025-03-27 19:43:32,745] Trial 16 finished with value: 0.0003634141758084297 and parameters: {'weight_decay': 5.37519145884981e-05, 'lr': 0.00018181836112937007, 'batch_size': 8}. Best is trial 15 with value: 0.00035381055204197764.
# [I 2025-03-27 19:43:32,862] Trial 17 pruned.
# [I 2025-03-27 19:43:36,867] Trial 18 finished with value: 0.00038144501741044223 and parameters: {'weight_decay': 0.00014284163871327866, 'lr': 0.00019665771776485914, 'batch_size': 8}. Best is trial 15 with value: 0.00035381055204197764.
# [I 2025-03-27 19:43:36,961] Trial 19 pruned.
# [I 2025-03-27 19:43:37,015] Trial 20 pruned.
# [I 2025-03-27 19:43:37,111] Trial 21 pruned.
# [I 2025-03-27 19:43:41,176] Trial 22 finished with value: 0.0003567940730135888 and parameters: {'weight_decay': 3.291279723866512e-05, 'lr': 0.0001852824934149004, 'batch_size': 8}. Best is trial 15 with value: 0.00035381055204197764.
# [I 2025-03-27 19:43:41,278] Trial 23 pruned.
# [I 2025-03-27 19:43:41,396] Trial 24 pruned.
# [I 2025-03-27 19:43:41,447] Trial 25 pruned.
# [I 2025-03-27 19:43:45,695] Trial 26 finished with value: 0.00033794340561144054 and parameters: {'weight_decay': 2.0572156644874667e-06, 'lr': 0.0002394366478842815, 'batch_size': 8}. Best is trial 26 with value: 0.00033794340561144054.
# [I 2025-03-27 19:43:49,715] Trial 27 finished with value: 0.0003190963761880994 and parameters: {'weight_decay': 1.3443021612870132e-06, 'lr': 0.0002418449091113453, 'batch_size': 8}. Best is trial 27 with value: 0.0003190963761880994.
# [I 2025-03-27 19:43:50,777] Trial 28 finished with value: 0.00026377433096058667 and parameters: {'weight_decay': 2.387231640809144e-08, 'lr': 0.0002779505762162036, 'batch_size': 32}. Best is trial 28 with value: 0.00026377433096058667.
# [I 2025-03-27 19:43:50,858] Trial 29 pruned.
# [I 2025-03-27 19:43:50,935] Trial 30 pruned.
# [I 2025-03-27 19:43:52,069] Trial 31 finished with value: 0.00025437609292566776 and parameters: {'weight_decay': 2.4383273718591835e-06, 'lr': 0.00012581954261387183, 'batch_size': 32}. Best is trial 31 with value: 0.00025437609292566776.
# [I 2025-03-27 19:43:53,093] Trial 32 finished with value: 0.00022919426555745304 and parameters: {'weight_decay': 1.0076803489607045e-06, 'lr': 0.00010650613852442591, 'batch_size': 32}. Best is trial 32 with value: 0.00022919426555745304.
# [I 2025-03-27 19:43:54,144] Trial 33 finished with value: 0.0002250443649245426 and parameters: {'weight_decay': 3.108239466044152e-07, 'lr': 0.0001230914263542225, 'batch_size': 32}. Best is trial 33 with value: 0.0002250443649245426.
# [I 2025-03-27 19:43:55,226] Trial 34 finished with value: 0.0002176671987399459 and parameters: {'weight_decay': 9.464191197218618e-09, 'lr': 0.0001338887431957198, 'batch_size': 32}. Best is trial 34 with value: 0.0002176671987399459.
# [I 2025-03-27 19:43:56,273] Trial 35 finished with value: 0.00021116317657288164 and parameters: {'weight_decay': 2.523240507417679e-07, 'lr': 0.00011930999978558008, 'batch_size': 32}. Best is trial 35 with value: 0.00021116317657288164.
# [I 2025-03-27 19:43:57,327] Trial 36 finished with value: 0.00020400418725330383 and parameters: {'weight_decay': 2.122786858521274e-07, 'lr': 0.00010496391736376356, 'batch_size': 32}. Best is trial 36 with value: 0.00020400418725330383.
# [I 2025-03-27 19:43:58,500] Trial 37 finished with value: 0.00020467334252316505 and parameters: {'weight_decay': 2.0825460917342687e-09, 'lr': 0.0001390814113353903, 'batch_size': 32}. Best is trial 36 with value: 0.00020400418725330383.
# [I 2025-03-27 19:43:59,744] Trial 38 finished with value: 0.00019837832951452583 and parameters: {'weight_decay': 2.861261895494762e-10, 'lr': 0.00014249293910609213, 'batch_size': 32}. Best is trial 38 with value: 0.00019837832951452583.
# [I 2025-03-27 19:44:01,083] Trial 39 finished with value: 0.0001912499574245885 and parameters: {'weight_decay': 1.4760320883164779e-12, 'lr': 0.00013462950873160447, 'batch_size': 32}. Best is trial 39 with value: 0.0001912499574245885.
# [I 2025-03-27 19:44:01,144] Trial 40 pruned.
# [I 2025-03-27 19:44:02,369] Trial 41 finished with value: 0.00018722434469964355 and parameters: {'weight_decay': 7.031649269078854e-14, 'lr': 0.00015084934101950522, 'batch_size': 32}. Best is trial 41 with value: 0.00018722434469964355.
# [I 2025-03-27 19:44:03,674] Trial 42 finished with value: 0.000182067888090387 and parameters: {'weight_decay': 6.47745246659596e-14, 'lr': 0.00014815806371058164, 'batch_size': 32}. Best is trial 42 with value: 0.000182067888090387.
# [I 2025-03-27 19:44:04,827] Trial 43 finished with value: 0.00017880863742902875 and parameters: {'weight_decay': 6.558285939942654e-14, 'lr': 0.00015137109810308346, 'batch_size': 32}. Best is trial 43 with value: 0.00017880863742902875.
# [I 2025-03-27 19:44:05,944] Trial 44 finished with value: 0.0001745388872222975 and parameters: {'weight_decay': 9.692916916841467e-14, 'lr': 0.00014930752535412118, 'batch_size': 32}. Best is trial 44 with value: 0.0001745388872222975.
# [I 2025-03-27 19:44:07,243] Trial 45 finished with value: 0.0001842527708504349 and parameters: {'weight_decay': 1.0148000286409444e-15, 'lr': 0.00022000057000016432, 'batch_size': 32}. Best is trial 44 with value: 0.0001745388872222975.
# [I 2025-03-27 19:44:08,411] Trial 46 finished with value: 0.00020748608221765608 and parameters: {'weight_decay': 2.11125141765159e-15, 'lr': 0.00031983664987745214, 'batch_size': 32}. Best is trial 44 with value: 0.0001745388872222975.
# [I 2025-03-27 19:44:08,576] Trial 47 pruned.
# [I 2025-03-27 19:44:09,643] Trial 48 finished with value: 0.00015800888650119305 and parameters: {'weight_decay': 5.004160567677578e-14, 'lr': 0.000157613640485989, 'batch_size': 32}. Best is trial 48 with value: 0.00015800888650119305.
# [I 2025-03-27 19:44:09,715] Trial 49 pruned.
# Study statistics:
#      Number of finished trials:  50
#      Number of pruned trials:  19
#      Number of completed trials:  31
# Best trial:
#      Value:  0.00015800888650119305
#      Params:
#     weight_decay: 5.004160567677578e-14
#     lr: 0.000157613640485989
#     batch_size: 32
#
# Epoch [0/999] - Train Loss: 0.372704 - Val Loss: 0.358913
#
# Epoch [1/999] - Train Loss: 0.370127 - Val Loss: 0.352094
#
# Epoch [2/999] - Train Loss: 0.370038 - Val Loss: 0.345299
#
# Epoch [3/999] - Train Loss: 0.353556 - Val Loss: 0.338589
#
# Epoch [4/999] - Train Loss: 0.338913 - Val Loss: 0.331944
#
# Epoch [5/999] - Train Loss: 0.340265 - Val Loss: 0.325386
#
# Epoch [6/999] - Train Loss: 0.332330 - Val Loss: 0.318910
#
# Epoch [7/999] - Train Loss: 0.337667 - Val Loss: 0.312513
#
# Epoch [8/999] - Train Loss: 0.326167 - Val Loss: 0.306212
#
# Epoch [9/999] - Train Loss: 0.307333 - Val Loss: 0.299998
#
# Epoch [10/999] - Train Loss: 0.294543 - Val Loss: 0.293930
#
# Epoch [11/999] - Train Loss: 0.295915 - Val Loss: 0.287960
#
# Epoch [12/999] - Train Loss: 0.296767 - Val Loss: 0.282054
#
# Epoch [13/999] - Train Loss: 0.286235 - Val Loss: 0.276254
#
# Epoch [14/999] - Train Loss: 0.286707 - Val Loss: 0.270547
#
# Epoch [15/999] - Train Loss: 0.275136 - Val Loss: 0.264918
#
# Epoch [16/999] - Train Loss: 0.274768 - Val Loss: 0.259373
#
# Epoch [17/999] - Train Loss: 0.264818 - Val Loss: 0.253918
#
# Epoch [18/999] - Train Loss: 0.260248 - Val Loss: 0.248564
#
# Epoch [19/999] - Train Loss: 0.255074 - Val Loss: 0.243292
#
# Epoch [20/999] - Train Loss: 0.265316 - Val Loss: 0.238089
#
# Epoch [21/999] - Train Loss: 0.243187 - Val Loss: 0.232964
#
# Epoch [22/999] - Train Loss: 0.243313 - Val Loss: 0.227927
#
# Epoch [23/999] - Train Loss: 0.238933 - Val Loss: 0.222975
#
# Epoch [24/999] - Train Loss: 0.234493 - Val Loss: 0.218079
#
# Epoch [25/999] - Train Loss: 0.229440 - Val Loss: 0.213281
#
# Epoch [26/999] - Train Loss: 0.218609 - Val Loss: 0.208577
#
# Epoch [27/999] - Train Loss: 0.222955 - Val Loss: 0.203941
#
# Epoch [28/999] - Train Loss: 0.209622 - Val Loss: 0.199409
#
# Epoch [29/999] - Train Loss: 0.203191 - Val Loss: 0.194980
#
# Epoch [30/999] - Train Loss: 0.206782 - Val Loss: 0.190630
#
# Epoch [31/999] - Train Loss: 0.197428 - Val Loss: 0.186361
#
# Epoch [32/999] - Train Loss: 0.196898 - Val Loss: 0.182158
#
# Epoch [33/999] - Train Loss: 0.192137 - Val Loss: 0.178059
#
# Epoch [34/999] - Train Loss: 0.182621 - Val Loss: 0.174030
#
# Epoch [35/999] - Train Loss: 0.182778 - Val Loss: 0.170087
#
# Epoch [36/999] - Train Loss: 0.177355 - Val Loss: 0.166246
#
# Epoch [37/999] - Train Loss: 0.177892 - Val Loss: 0.162454
#
# Epoch [38/999] - Train Loss: 0.171426 - Val Loss: 0.158750
#
# Epoch [39/999] - Train Loss: 0.172191 - Val Loss: 0.155089
#
# Epoch [40/999] - Train Loss: 0.160990 - Val Loss: 0.151509
#
# Epoch [41/999] - Train Loss: 0.157928 - Val Loss: 0.148010
#
# Epoch [42/999] - Train Loss: 0.152006 - Val Loss: 0.144596
#
# Epoch [43/999] - Train Loss: 0.156610 - Val Loss: 0.141223
#
# Epoch [44/999] - Train Loss: 0.150628 - Val Loss: 0.137904
#
# Epoch [45/999] - Train Loss: 0.141025 - Val Loss: 0.134659
#
# Epoch [46/999] - Train Loss: 0.141851 - Val Loss: 0.131488
#
# Epoch [47/999] - Train Loss: 0.138417 - Val Loss: 0.128403
#
# Epoch [48/999] - Train Loss: 0.136037 - Val Loss: 0.125377
#
# Epoch [49/999] - Train Loss: 0.131598 - Val Loss: 0.122418
#
# Epoch [50/999] - Train Loss: 0.131791 - Val Loss: 0.119501
#
# Epoch [51/999] - Train Loss: 0.127122 - Val Loss: 0.116649
#
# Epoch [52/999] - Train Loss: 0.120679 - Val Loss: 0.113861
#
# Epoch [53/999] - Train Loss: 0.120853 - Val Loss: 0.111130
#
# Epoch [54/999] - Train Loss: 0.118126 - Val Loss: 0.108443
#
# Epoch [55/999] - Train Loss: 0.113568 - Val Loss: 0.105833
#
# Epoch [56/999] - Train Loss: 0.110587 - Val Loss: 0.103274
#
# Epoch [57/999] - Train Loss: 0.109761 - Val Loss: 0.100773
#
# Epoch [58/999] - Train Loss: 0.108168 - Val Loss: 0.098318
#
# Epoch [59/999] - Train Loss: 0.104763 - Val Loss: 0.095913
#
# Epoch [60/999] - Train Loss: 0.101410 - Val Loss: 0.093568
#
# Epoch [61/999] - Train Loss: 0.102374 - Val Loss: 0.091252
#
# Epoch [62/999] - Train Loss: 0.096115 - Val Loss: 0.089001
#
# Epoch [63/999] - Train Loss: 0.095593 - Val Loss: 0.086812
#
# Epoch [64/999] - Train Loss: 0.095784 - Val Loss: 0.084651
#
# Epoch [65/999] - Train Loss: 0.090826 - Val Loss: 0.082550
#
# Epoch [66/999] - Train Loss: 0.088322 - Val Loss: 0.080495
#
# Epoch [67/999] - Train Loss: 0.086143 - Val Loss: 0.078499
#
# Epoch [68/999] - Train Loss: 0.083334 - Val Loss: 0.076544
#
# Epoch [69/999] - Train Loss: 0.081641 - Val Loss: 0.074640
#
# Epoch [70/999] - Train Loss: 0.079920 - Val Loss: 0.072781
#
# Epoch [71/999] - Train Loss: 0.079926 - Val Loss: 0.070964
#
# Epoch [72/999] - Train Loss: 0.076092 - Val Loss: 0.069193
#
# Epoch [73/999] - Train Loss: 0.074407 - Val Loss: 0.067454
#
# Epoch [74/999] - Train Loss: 0.071618 - Val Loss: 0.065759
#
# Epoch [75/999] - Train Loss: 0.071427 - Val Loss: 0.064106
#
# Epoch [76/999] - Train Loss: 0.070126 - Val Loss: 0.062482
#
# Epoch [77/999] - Train Loss: 0.067878 - Val Loss: 0.060895
#
# Epoch [78/999] - Train Loss: 0.064555 - Val Loss: 0.059347
#
# Epoch [79/999] - Train Loss: 0.061698 - Val Loss: 0.057839
#
# Epoch [80/999] - Train Loss: 0.060768 - Val Loss: 0.056372
#
# Epoch [81/999] - Train Loss: 0.062781 - Val Loss: 0.054938
#
# Epoch [82/999] - Train Loss: 0.059969 - Val Loss: 0.053534
#
# Epoch [83/999] - Train Loss: 0.060138 - Val Loss: 0.052158
#
# Epoch [84/999] - Train Loss: 0.056640 - Val Loss: 0.050821
#
# Epoch [85/999] - Train Loss: 0.056009 - Val Loss: 0.049503
#
# Epoch [86/999] - Train Loss: 0.052618 - Val Loss: 0.048227
#
# Epoch [87/999] - Train Loss: 0.052291 - Val Loss: 0.046982
#
# Epoch [88/999] - Train Loss: 0.050683 - Val Loss: 0.045773
#
# Epoch [89/999] - Train Loss: 0.050884 - Val Loss: 0.044590
#
# Epoch [90/999] - Train Loss: 0.046871 - Val Loss: 0.043445
#
# Epoch [91/999] - Train Loss: 0.047590 - Val Loss: 0.042324
#
# Epoch [92/999] - Train Loss: 0.046670 - Val Loss: 0.041227
#
# Epoch [93/999] - Train Loss: 0.045187 - Val Loss: 0.040160
#
# Epoch [94/999] - Train Loss: 0.044062 - Val Loss: 0.039115
#
# Epoch [95/999] - Train Loss: 0.042056 - Val Loss: 0.038095
#
# Epoch [96/999] - Train Loss: 0.042070 - Val Loss: 0.037100
#
# Epoch [97/999] - Train Loss: 0.040621 - Val Loss: 0.036125
#
# Epoch [98/999] - Train Loss: 0.038264 - Val Loss: 0.035181
#
# Epoch [99/999] - Train Loss: 0.038481 - Val Loss: 0.034265
#
# Epoch [100/999] - Train Loss: 0.037349 - Val Loss: 0.033372
#
# Epoch [101/999] - Train Loss: 0.037175 - Val Loss: 0.032500
#
# Epoch [102/999] - Train Loss: 0.035750 - Val Loss: 0.031653
#
# Epoch [103/999] - Train Loss: 0.034688 - Val Loss: 0.030823
#
# Epoch [104/999] - Train Loss: 0.033796 - Val Loss: 0.030014
#
# Epoch [105/999] - Train Loss: 0.032778 - Val Loss: 0.029232
#
# Epoch [106/999] - Train Loss: 0.031929 - Val Loss: 0.028466
#
# Epoch [107/999] - Train Loss: 0.030553 - Val Loss: 0.027722
#
# Epoch [108/999] - Train Loss: 0.030600 - Val Loss: 0.026998
#
# Epoch [109/999] - Train Loss: 0.029650 - Val Loss: 0.026292
#
# Epoch [110/999] - Train Loss: 0.027887 - Val Loss: 0.025607
#
# Epoch [111/999] - Train Loss: 0.028263 - Val Loss: 0.024938
#
# Epoch [112/999] - Train Loss: 0.028184 - Val Loss: 0.024281
#
# Epoch [113/999] - Train Loss: 0.026322 - Val Loss: 0.023643
#
# Epoch [114/999] - Train Loss: 0.025760 - Val Loss: 0.023021
#
# Epoch [115/999] - Train Loss: 0.025825 - Val Loss: 0.022413
#
# Epoch [116/999] - Train Loss: 0.024559 - Val Loss: 0.021825
#
# Epoch [117/999] - Train Loss: 0.024768 - Val Loss: 0.021250
#
# Epoch [118/999] - Train Loss: 0.024150 - Val Loss: 0.020686
#
# Epoch [119/999] - Train Loss: 0.022697 - Val Loss: 0.020141
#
# Epoch [120/999] - Train Loss: 0.022347 - Val Loss: 0.019609
#
# Epoch [121/999] - Train Loss: 0.021960 - Val Loss: 0.019090
#
# Epoch [122/999] - Train Loss: 0.021896 - Val Loss: 0.018580
#
# Epoch [123/999] - Train Loss: 0.020085 - Val Loss: 0.018085
#
# Epoch [124/999] - Train Loss: 0.020680 - Val Loss: 0.017601
#
# Epoch [125/999] - Train Loss: 0.020603 - Val Loss: 0.017126
#
# Epoch [126/999] - Train Loss: 0.018848 - Val Loss: 0.016663
#
# Epoch [127/999] - Train Loss: 0.018162 - Val Loss: 0.016217
#
# Epoch [128/999] - Train Loss: 0.018341 - Val Loss: 0.015785
#
# Epoch [129/999] - Train Loss: 0.017644 - Val Loss: 0.015365
#
# Epoch [130/999] - Train Loss: 0.017350 - Val Loss: 0.014956
#
# Epoch [131/999] - Train Loss: 0.017095 - Val Loss: 0.014558
#
# Epoch [132/999] - Train Loss: 0.016248 - Val Loss: 0.014169
#
# Epoch [133/999] - Train Loss: 0.015147 - Val Loss: 0.013792
#
# Epoch [134/999] - Train Loss: 0.015314 - Val Loss: 0.013429
#
# Epoch [135/999] - Train Loss: 0.014865 - Val Loss: 0.013075
#
# Epoch [136/999] - Train Loss: 0.015051 - Val Loss: 0.012729
#
# Epoch [137/999] - Train Loss: 0.014048 - Val Loss: 0.012393
#
# Epoch [138/999] - Train Loss: 0.014084 - Val Loss: 0.012065
#
# Epoch [139/999] - Train Loss: 0.013674 - Val Loss: 0.011747
#
# Epoch [140/999] - Train Loss: 0.013335 - Val Loss: 0.011437
#
# Epoch [141/999] - Train Loss: 0.013290 - Val Loss: 0.011134
#
# Epoch [142/999] - Train Loss: 0.012374 - Val Loss: 0.010840
#
# Epoch [143/999] - Train Loss: 0.012271 - Val Loss: 0.010554
#
# Epoch [144/999] - Train Loss: 0.011984 - Val Loss: 0.010276
#
# Epoch [145/999] - Train Loss: 0.011633 - Val Loss: 0.010005
#
# Epoch [146/999] - Train Loss: 0.011347 - Val Loss: 0.009740
#
# Epoch [147/999] - Train Loss: 0.011023 - Val Loss: 0.009483
#
# Epoch [148/999] - Train Loss: 0.010964 - Val Loss: 0.009233
#
# Epoch [149/999] - Train Loss: 0.010475 - Val Loss: 0.008990
#
# Epoch [150/999] - Train Loss: 0.010210 - Val Loss: 0.008753
#
# Epoch [151/999] - Train Loss: 0.009866 - Val Loss: 0.008523
#
# Epoch [152/999] - Train Loss: 0.009786 - Val Loss: 0.008299
#
# Epoch [153/999] - Train Loss: 0.009272 - Val Loss: 0.008082
#
# Epoch [154/999] - Train Loss: 0.009174 - Val Loss: 0.007873
#
# Epoch [155/999] - Train Loss: 0.008680 - Val Loss: 0.007669
#
# Epoch [156/999] - Train Loss: 0.008587 - Val Loss: 0.007470
#
# Epoch [157/999] - Train Loss: 0.008281 - Val Loss: 0.007276
#
# Epoch [158/999] - Train Loss: 0.008023 - Val Loss: 0.007089
#
# Epoch [159/999] - Train Loss: 0.008222 - Val Loss: 0.006907
#
# Epoch [160/999] - Train Loss: 0.008000 - Val Loss: 0.006730
#
# Epoch [161/999] - Train Loss: 0.007672 - Val Loss: 0.006556
#
# Epoch [162/999] - Train Loss: 0.007163 - Val Loss: 0.006388
#
# Epoch [163/999] - Train Loss: 0.006944 - Val Loss: 0.006226
#
# Epoch [164/999] - Train Loss: 0.007103 - Val Loss: 0.006068
#
# Epoch [165/999] - Train Loss: 0.006880 - Val Loss: 0.005914
#
# Epoch [166/999] - Train Loss: 0.006846 - Val Loss: 0.005765
#
# Epoch [167/999] - Train Loss: 0.006135 - Val Loss: 0.005621
#
# Epoch [168/999] - Train Loss: 0.006118 - Val Loss: 0.005481
#
# Epoch [169/999] - Train Loss: 0.006213 - Val Loss: 0.005345
#
# Epoch [170/999] - Train Loss: 0.006099 - Val Loss: 0.005213
#
# Epoch [171/999] - Train Loss: 0.005751 - Val Loss: 0.005085
#
# Epoch [172/999] - Train Loss: 0.005803 - Val Loss: 0.004961
#
# Epoch [173/999] - Train Loss: 0.005605 - Val Loss: 0.004839
#
# Epoch [174/999] - Train Loss: 0.005399 - Val Loss: 0.004719
#
# Epoch [175/999] - Train Loss: 0.005143 - Val Loss: 0.004603
#
# Epoch [176/999] - Train Loss: 0.005118 - Val Loss: 0.004492
#
# Epoch [177/999] - Train Loss: 0.005090 - Val Loss: 0.004382
#
# Epoch [178/999] - Train Loss: 0.004921 - Val Loss: 0.004275
#
# Epoch [179/999] - Train Loss: 0.004771 - Val Loss: 0.004171
#
# Epoch [180/999] - Train Loss: 0.004666 - Val Loss: 0.004071
#
# Epoch [181/999] - Train Loss: 0.004591 - Val Loss: 0.003973
#
# Epoch [182/999] - Train Loss: 0.004432 - Val Loss: 0.003878
#
# Epoch [183/999] - Train Loss: 0.004212 - Val Loss: 0.003786
#
# Epoch [184/999] - Train Loss: 0.004089 - Val Loss: 0.003696
#
# Epoch [185/999] - Train Loss: 0.004142 - Val Loss: 0.003609
#
# Epoch [186/999] - Train Loss: 0.004025 - Val Loss: 0.003524
#
# Epoch [187/999] - Train Loss: 0.003929 - Val Loss: 0.003441
#
# Epoch [188/999] - Train Loss: 0.003857 - Val Loss: 0.003360
#
# Epoch [189/999] - Train Loss: 0.003828 - Val Loss: 0.003281
#
# Epoch [190/999] - Train Loss: 0.003651 - Val Loss: 0.003204
#
# Epoch [191/999] - Train Loss: 0.003657 - Val Loss: 0.003129
#
# Epoch [192/999] - Train Loss: 0.003424 - Val Loss: 0.003056
#
# Epoch [193/999] - Train Loss: 0.003336 - Val Loss: 0.002986
#
# Epoch [194/999] - Train Loss: 0.003251 - Val Loss: 0.002917
#
# Epoch [195/999] - Train Loss: 0.003237 - Val Loss: 0.002851
#
# Epoch [196/999] - Train Loss: 0.003106 - Val Loss: 0.002787
#
# Epoch [197/999] - Train Loss: 0.003048 - Val Loss: 0.002725
#
# Epoch [198/999] - Train Loss: 0.002934 - Val Loss: 0.002664
#
# Epoch [199/999] - Train Loss: 0.002856 - Val Loss: 0.002605
#
# Epoch [200/999] - Train Loss: 0.002762 - Val Loss: 0.002548
#
# Epoch [201/999] - Train Loss: 0.002838 - Val Loss: 0.002493
#
# Epoch [202/999] - Train Loss: 0.002734 - Val Loss: 0.002438
#
# Epoch [203/999] - Train Loss: 0.002650 - Val Loss: 0.002385
#
# Epoch [204/999] - Train Loss: 0.002693 - Val Loss: 0.002333
#
# Epoch [205/999] - Train Loss: 0.002497 - Val Loss: 0.002283
#
# Epoch [206/999] - Train Loss: 0.002448 - Val Loss: 0.002235
#
# Epoch [207/999] - Train Loss: 0.002479 - Val Loss: 0.002187
#
# Epoch [208/999] - Train Loss: 0.002422 - Val Loss: 0.002141
#
# Epoch [209/999] - Train Loss: 0.002259 - Val Loss: 0.002096
#
# Epoch [210/999] - Train Loss: 0.002239 - Val Loss: 0.002052
#
# Epoch [211/999] - Train Loss: 0.002191 - Val Loss: 0.002010
#
# Epoch [212/999] - Train Loss: 0.002199 - Val Loss: 0.001969
#
# Epoch [213/999] - Train Loss: 0.002106 - Val Loss: 0.001928
#
# Epoch [214/999] - Train Loss: 0.002089 - Val Loss: 0.001889
#
# Epoch [215/999] - Train Loss: 0.001924 - Val Loss: 0.001851
#
# Epoch [216/999] - Train Loss: 0.002000 - Val Loss: 0.001815
#
# Epoch [217/999] - Train Loss: 0.001841 - Val Loss: 0.001779
#
# Epoch [218/999] - Train Loss: 0.001847 - Val Loss: 0.001745
#
# Epoch [219/999] - Train Loss: 0.001871 - Val Loss: 0.001711
#
# Epoch [220/999] - Train Loss: 0.001809 - Val Loss: 0.001678
#
# Epoch [221/999] - Train Loss: 0.001774 - Val Loss: 0.001646
#
# Epoch [222/999] - Train Loss: 0.001749 - Val Loss: 0.001615
#
# Epoch [223/999] - Train Loss: 0.001643 - Val Loss: 0.001584
#
# Epoch [224/999] - Train Loss: 0.001634 - Val Loss: 0.001555
#
# Epoch [225/999] - Train Loss: 0.001628 - Val Loss: 0.001526
#
# Epoch [226/999] - Train Loss: 0.001607 - Val Loss: 0.001498
#
# Epoch [227/999] - Train Loss: 0.001526 - Val Loss: 0.001471
#
# Epoch [228/999] - Train Loss: 0.001501 - Val Loss: 0.001444
#
# Epoch [229/999] - Train Loss: 0.001509 - Val Loss: 0.001417
#
# Epoch [230/999] - Train Loss: 0.001476 - Val Loss: 0.001392
#
# Epoch [231/999] - Train Loss: 0.001360 - Val Loss: 0.001367
#
# Epoch [232/999] - Train Loss: 0.001365 - Val Loss: 0.001343
#
# Epoch [233/999] - Train Loss: 0.001388 - Val Loss: 0.001319
#
# Epoch [234/999] - Train Loss: 0.001305 - Val Loss: 0.001296
#
# Epoch [235/999] - Train Loss: 0.001278 - Val Loss: 0.001274
#
# Epoch [236/999] - Train Loss: 0.001308 - Val Loss: 0.001252
#
# Epoch [237/999] - Train Loss: 0.001257 - Val Loss: 0.001231
#
# Epoch [238/999] - Train Loss: 0.001262 - Val Loss: 0.001210
#
# Epoch [239/999] - Train Loss: 0.001263 - Val Loss: 0.001190
#
# Epoch [240/999] - Train Loss: 0.001180 - Val Loss: 0.001171
#
# Epoch [241/999] - Train Loss: 0.001200 - Val Loss: 0.001152
#
# Epoch [242/999] - Train Loss: 0.001148 - Val Loss: 0.001134
#
# Epoch [243/999] - Train Loss: 0.001128 - Val Loss: 0.001116
#
# Epoch [244/999] - Train Loss: 0.001124 - Val Loss: 0.001099
#
# Epoch [245/999] - Train Loss: 0.001039 - Val Loss: 0.001082
#
# Epoch [246/999] - Train Loss: 0.001057 - Val Loss: 0.001066
#
# Epoch [247/999] - Train Loss: 0.001017 - Val Loss: 0.001050
#
# Epoch [248/999] - Train Loss: 0.001039 - Val Loss: 0.001034
#
# Epoch [249/999] - Train Loss: 0.001040 - Val Loss: 0.001019
#
# Epoch [250/999] - Train Loss: 0.001029 - Val Loss: 0.001004
#
# Epoch [251/999] - Train Loss: 0.000972 - Val Loss: 0.000989
#
# Epoch [252/999] - Train Loss: 0.000972 - Val Loss: 0.000975
#
# Epoch [253/999] - Train Loss: 0.000917 - Val Loss: 0.000961
#
# Epoch [254/999] - Train Loss: 0.000915 - Val Loss: 0.000947
#
# Epoch [255/999] - Train Loss: 0.000920 - Val Loss: 0.000933
#
# Epoch [256/999] - Train Loss: 0.000919 - Val Loss: 0.000920
#
# Epoch [257/999] - Train Loss: 0.000882 - Val Loss: 0.000907
#
# Epoch [258/999] - Train Loss: 0.000877 - Val Loss: 0.000894
#
# Epoch [259/999] - Train Loss: 0.000872 - Val Loss: 0.000881
#
# Epoch [260/999] - Train Loss: 0.000849 - Val Loss: 0.000869
#
# Epoch [261/999] - Train Loss: 0.000787 - Val Loss: 0.000858
#
# Epoch [262/999] - Train Loss: 0.000806 - Val Loss: 0.000846
#
# Epoch [263/999] - Train Loss: 0.000807 - Val Loss: 0.000835
#
# Epoch [264/999] - Train Loss: 0.000782 - Val Loss: 0.000824
#
# Epoch [265/999] - Train Loss: 0.000787 - Val Loss: 0.000813
#
# Epoch [266/999] - Train Loss: 0.000758 - Val Loss: 0.000803
#
# Epoch [267/999] - Train Loss: 0.000724 - Val Loss: 0.000793
#
# Epoch [268/999] - Train Loss: 0.000730 - Val Loss: 0.000783
#
# Epoch [269/999] - Train Loss: 0.000747 - Val Loss: 0.000773
#
# Epoch [270/999] - Train Loss: 0.000728 - Val Loss: 0.000763
#
# Epoch [271/999] - Train Loss: 0.000702 - Val Loss: 0.000754
#
# Epoch [272/999] - Train Loss: 0.000697 - Val Loss: 0.000745
#
# Epoch [273/999] - Train Loss: 0.000724 - Val Loss: 0.000737
#
# Epoch [274/999] - Train Loss: 0.000686 - Val Loss: 0.000728
#
# Epoch [275/999] - Train Loss: 0.000694 - Val Loss: 0.000720
#
# Epoch [276/999] - Train Loss: 0.000674 - Val Loss: 0.000712
#
# Epoch [277/999] - Train Loss: 0.000627 - Val Loss: 0.000705
#
# Epoch [278/999] - Train Loss: 0.000660 - Val Loss: 0.000698
#
# Epoch [279/999] - Train Loss: 0.000621 - Val Loss: 0.000691
#
# Epoch [280/999] - Train Loss: 0.000601 - Val Loss: 0.000684
#
# Epoch [281/999] - Train Loss: 0.000605 - Val Loss: 0.000678
#
# Epoch [282/999] - Train Loss: 0.000625 - Val Loss: 0.000671
#
# Epoch [283/999] - Train Loss: 0.000620 - Val Loss: 0.000664
#
# Epoch [284/999] - Train Loss: 0.000585 - Val Loss: 0.000658
#
# Epoch [285/999] - Train Loss: 0.000614 - Val Loss: 0.000652
#
# Epoch [286/999] - Train Loss: 0.000574 - Val Loss: 0.000645
#
# Epoch [287/999] - Train Loss: 0.000544 - Val Loss: 0.000639
#
# Epoch [288/999] - Train Loss: 0.000582 - Val Loss: 0.000633
#
# Epoch [289/999] - Train Loss: 0.000568 - Val Loss: 0.000627
#
# Epoch [290/999] - Train Loss: 0.000543 - Val Loss: 0.000621
#
# Epoch [291/999] - Train Loss: 0.000536 - Val Loss: 0.000615
#
# Epoch [292/999] - Train Loss: 0.000555 - Val Loss: 0.000610
#
# Epoch [293/999] - Train Loss: 0.000566 - Val Loss: 0.000605
#
# Epoch [294/999] - Train Loss: 0.000542 - Val Loss: 0.000600
#
# Epoch [295/999] - Train Loss: 0.000514 - Val Loss: 0.000594
#
# Epoch [296/999] - Train Loss: 0.000532 - Val Loss: 0.000590
#
# Epoch [297/999] - Train Loss: 0.000534 - Val Loss: 0.000585
#
# Epoch [298/999] - Train Loss: 0.000529 - Val Loss: 0.000580
#
# Epoch [299/999] - Train Loss: 0.000519 - Val Loss: 0.000575
#
# Epoch [300/999] - Train Loss: 0.000492 - Val Loss: 0.000571
#
# Epoch [301/999] - Train Loss: 0.000499 - Val Loss: 0.000567
#
# Epoch [302/999] - Train Loss: 0.000518 - Val Loss: 0.000562
#
# Epoch [303/999] - Train Loss: 0.000500 - Val Loss: 0.000558
#
# Epoch [304/999] - Train Loss: 0.000462 - Val Loss: 0.000554
#
# Epoch [305/999] - Train Loss: 0.000493 - Val Loss: 0.000550
#
# Epoch [306/999] - Train Loss: 0.000473 - Val Loss: 0.000546
#
# Epoch [307/999] - Train Loss: 0.000469 - Val Loss: 0.000542
#
# Epoch [308/999] - Train Loss: 0.000467 - Val Loss: 0.000538
#
# Epoch [309/999] - Train Loss: 0.000455 - Val Loss: 0.000534
#
# Epoch [310/999] - Train Loss: 0.000470 - Val Loss: 0.000530
#
# Epoch [311/999] - Train Loss: 0.000449 - Val Loss: 0.000526
#
# Epoch [312/999] - Train Loss: 0.000449 - Val Loss: 0.000522
#
# Epoch [313/999] - Train Loss: 0.000439 - Val Loss: 0.000518
#
# Epoch [314/999] - Train Loss: 0.000462 - Val Loss: 0.000515
#
# Epoch [315/999] - Train Loss: 0.000444 - Val Loss: 0.000511
#
# Epoch [316/999] - Train Loss: 0.000451 - Val Loss: 0.000508
#
# Epoch [317/999] - Train Loss: 0.000407 - Val Loss: 0.000505
#
# Epoch [318/999] - Train Loss: 0.000419 - Val Loss: 0.000501
#
# Epoch [319/999] - Train Loss: 0.000435 - Val Loss: 0.000498
#
# Epoch [320/999] - Train Loss: 0.000420 - Val Loss: 0.000495
#
# Epoch [321/999] - Train Loss: 0.000415 - Val Loss: 0.000492
#
# Epoch [322/999] - Train Loss: 0.000410 - Val Loss: 0.000489
#
# Epoch [323/999] - Train Loss: 0.000408 - Val Loss: 0.000486
#
# Epoch [324/999] - Train Loss: 0.000419 - Val Loss: 0.000483
#
# Epoch [325/999] - Train Loss: 0.000416 - Val Loss: 0.000480
#
# Epoch [326/999] - Train Loss: 0.000412 - Val Loss: 0.000476
#
# Epoch [327/999] - Train Loss: 0.000405 - Val Loss: 0.000473
#
# Epoch [328/999] - Train Loss: 0.000401 - Val Loss: 0.000470
#
# Epoch [329/999] - Train Loss: 0.000405 - Val Loss: 0.000467
#
# Epoch [330/999] - Train Loss: 0.000388 - Val Loss: 0.000465
#
# Epoch [331/999] - Train Loss: 0.000394 - Val Loss: 0.000462
#
# Epoch [332/999] - Train Loss: 0.000378 - Val Loss: 0.000460
#
# Epoch [333/999] - Train Loss: 0.000397 - Val Loss: 0.000457
#
# Epoch [334/999] - Train Loss: 0.000382 - Val Loss: 0.000455
#
# Epoch [335/999] - Train Loss: 0.000390 - Val Loss: 0.000452
#
# Epoch [336/999] - Train Loss: 0.000377 - Val Loss: 0.000450
#
# Epoch [337/999] - Train Loss: 0.000383 - Val Loss: 0.000448
#
# Epoch [338/999] - Train Loss: 0.000390 - Val Loss: 0.000446
#
# Epoch [339/999] - Train Loss: 0.000377 - Val Loss: 0.000443
#
# Epoch [340/999] - Train Loss: 0.000387 - Val Loss: 0.000441
#
# Epoch [341/999] - Train Loss: 0.000375 - Val Loss: 0.000439
#
# Epoch [342/999] - Train Loss: 0.000364 - Val Loss: 0.000437
#
# Epoch [343/999] - Train Loss: 0.000374 - Val Loss: 0.000435
#
# Epoch [344/999] - Train Loss: 0.000374 - Val Loss: 0.000433
#
# Epoch [345/999] - Train Loss: 0.000372 - Val Loss: 0.000431
#
# Epoch [346/999] - Train Loss: 0.000368 - Val Loss: 0.000429
#
# Epoch [347/999] - Train Loss: 0.000368 - Val Loss: 0.000427
#
# Epoch [348/999] - Train Loss: 0.000363 - Val Loss: 0.000425
#
# Epoch [349/999] - Train Loss: 0.000367 - Val Loss: 0.000423
#
# Epoch [350/999] - Train Loss: 0.000372 - Val Loss: 0.000421
#
# Epoch [351/999] - Train Loss: 0.000357 - Val Loss: 0.000419
#
# Epoch [352/999] - Train Loss: 0.000357 - Val Loss: 0.000417
#
# Epoch [353/999] - Train Loss: 0.000338 - Val Loss: 0.000415
#
# Epoch [354/999] - Train Loss: 0.000337 - Val Loss: 0.000414
#
# Epoch [355/999] - Train Loss: 0.000321 - Val Loss: 0.000412
#
# Epoch [356/999] - Train Loss: 0.000349 - Val Loss: 0.000410
#
# Epoch [357/999] - Train Loss: 0.000344 - Val Loss: 0.000409
#
# Epoch [358/999] - Train Loss: 0.000327 - Val Loss: 0.000408
#
# Epoch [359/999] - Train Loss: 0.000343 - Val Loss: 0.000407
#
# Epoch [360/999] - Train Loss: 0.000353 - Val Loss: 0.000405
#
# Epoch [361/999] - Train Loss: 0.000335 - Val Loss: 0.000404
#
# Epoch [362/999] - Train Loss: 0.000352 - Val Loss: 0.000403
#
# Epoch [363/999] - Train Loss: 0.000325 - Val Loss: 0.000402
#
# Epoch [364/999] - Train Loss: 0.000333 - Val Loss: 0.000401
#
# Epoch [365/999] - Train Loss: 0.000307 - Val Loss: 0.000400
#
# Epoch [366/999] - Train Loss: 0.000346 - Val Loss: 0.000399
#
# Epoch [367/999] - Train Loss: 0.000333 - Val Loss: 0.000398
#
# Epoch [368/999] - Train Loss: 0.000323 - Val Loss: 0.000396
#
# Epoch [369/999] - Train Loss: 0.000326 - Val Loss: 0.000395
#
# Epoch [370/999] - Train Loss: 0.000309 - Val Loss: 0.000394
#
# Epoch [371/999] - Train Loss: 0.000342 - Val Loss: 0.000393
#
# Epoch [372/999] - Train Loss: 0.000317 - Val Loss: 0.000392
#
# Epoch [373/999] - Train Loss: 0.000321 - Val Loss: 0.000391
#
# Epoch [374/999] - Train Loss: 0.000323 - Val Loss: 0.000390
#
# Epoch [375/999] - Train Loss: 0.000307 - Val Loss: 0.000389
#
# Epoch [376/999] - Train Loss: 0.000319 - Val Loss: 0.000388
#
# Epoch [377/999] - Train Loss: 0.000323 - Val Loss: 0.000386
#
# Epoch [378/999] - Train Loss: 0.000310 - Val Loss: 0.000385
#
# Epoch [379/999] - Train Loss: 0.000316 - Val Loss: 0.000384
#
# Epoch [380/999] - Train Loss: 0.000315 - Val Loss: 0.000383
#
# Epoch [381/999] - Train Loss: 0.000296 - Val Loss: 0.000383
#
# Epoch [382/999] - Train Loss: 0.000301 - Val Loss: 0.000382
#
# Epoch [383/999] - Train Loss: 0.000285 - Val Loss: 0.000381
#
# Epoch [384/999] - Train Loss: 0.000316 - Val Loss: 0.000380
#
# Epoch [385/999] - Train Loss: 0.000325 - Val Loss: 0.000380
#
# Epoch [386/999] - Train Loss: 0.000306 - Val Loss: 0.000379
#
# Epoch [387/999] - Train Loss: 0.000309 - Val Loss: 0.000378
#
# Epoch [388/999] - Train Loss: 0.000295 - Val Loss: 0.000377
#
# Epoch [389/999] - Train Loss: 0.000312 - Val Loss: 0.000376
#
# Epoch [390/999] - Train Loss: 0.000313 - Val Loss: 0.000375
#
# Epoch [391/999] - Train Loss: 0.000308 - Val Loss: 0.000374
#
# Epoch [392/999] - Train Loss: 0.000316 - Val Loss: 0.000373
#
# Epoch [393/999] - Train Loss: 0.000275 - Val Loss: 0.000372
#
# Epoch [394/999] - Train Loss: 0.000304 - Val Loss: 0.000372
#
# Epoch [395/999] - Train Loss: 0.000320 - Val Loss: 0.000371
#
# Epoch [396/999] - Train Loss: 0.000296 - Val Loss: 0.000370
#
# Epoch [397/999] - Train Loss: 0.000298 - Val Loss: 0.000369
#
# Epoch [398/999] - Train Loss: 0.000323 - Val Loss: 0.000367
#
# Epoch [399/999] - Train Loss: 0.000287 - Val Loss: 0.000366
#
# Epoch [400/999] - Train Loss: 0.000285 - Val Loss: 0.000366
#
# Epoch [401/999] - Train Loss: 0.000277 - Val Loss: 0.000365
#
# Epoch [402/999] - Train Loss: 0.000294 - Val Loss: 0.000365
#
# Epoch [403/999] - Train Loss: 0.000301 - Val Loss: 0.000364
#
# Epoch [404/999] - Train Loss: 0.000309 - Val Loss: 0.000363
#
# Epoch [405/999] - Train Loss: 0.000302 - Val Loss: 0.000363
#
# Epoch [406/999] - Train Loss: 0.000291 - Val Loss: 0.000362
#
# Epoch [407/999] - Train Loss: 0.000299 - Val Loss: 0.000362
#
# Epoch [408/999] - Train Loss: 0.000296 - Val Loss: 0.000361
#
# Epoch [409/999] - Train Loss: 0.000301 - Val Loss: 0.000360
#
# Epoch [410/999] - Train Loss: 0.000254 - Val Loss: 0.000360
#
# Epoch [411/999] - Train Loss: 0.000293 - Val Loss: 0.000359
#
# Epoch [412/999] - Train Loss: 0.000295 - Val Loss: 0.000358
#
# Epoch [413/999] - Train Loss: 0.000286 - Val Loss: 0.000357
#
# Epoch [414/999] - Train Loss: 0.000297 - Val Loss: 0.000356
#
# Epoch [415/999] - Train Loss: 0.000291 - Val Loss: 0.000355
#
# Epoch [416/999] - Train Loss: 0.000301 - Val Loss: 0.000354
#
# Epoch [417/999] - Train Loss: 0.000264 - Val Loss: 0.000354
#
# Epoch [418/999] - Train Loss: 0.000290 - Val Loss: 0.000353
#
# Epoch [419/999] - Train Loss: 0.000304 - Val Loss: 0.000352
#
# Epoch [420/999] - Train Loss: 0.000297 - Val Loss: 0.000351
#
# Epoch [421/999] - Train Loss: 0.000279 - Val Loss: 0.000350
#
# Epoch [422/999] - Train Loss: 0.000269 - Val Loss: 0.000349
#
# Epoch [423/999] - Train Loss: 0.000285 - Val Loss: 0.000348
#
# Epoch [424/999] - Train Loss: 0.000276 - Val Loss: 0.000348
#
# Epoch [425/999] - Train Loss: 0.000296 - Val Loss: 0.000347
#
# Epoch [426/999] - Train Loss: 0.000297 - Val Loss: 0.000346
#
# Epoch [427/999] - Train Loss: 0.000282 - Val Loss: 0.000345
#
# Epoch [428/999] - Train Loss: 0.000272 - Val Loss: 0.000344
#
# Epoch [429/999] - Train Loss: 0.000248 - Val Loss: 0.000343
#
# Epoch [430/999] - Train Loss: 0.000284 - Val Loss: 0.000343
#
# Epoch [431/999] - Train Loss: 0.000300 - Val Loss: 0.000342
#
# Epoch [432/999] - Train Loss: 0.000284 - Val Loss: 0.000342
#
# Epoch [433/999] - Train Loss: 0.000271 - Val Loss: 0.000341
#
# Epoch [434/999] - Train Loss: 0.000272 - Val Loss: 0.000340
#
# Epoch [435/999] - Train Loss: 0.000284 - Val Loss: 0.000340
#
# Epoch [436/999] - Train Loss: 0.000260 - Val Loss: 0.000339
#
# Epoch [437/999] - Train Loss: 0.000276 - Val Loss: 0.000339
#
# Epoch [438/999] - Train Loss: 0.000266 - Val Loss: 0.000339
#
# Epoch [439/999] - Train Loss: 0.000285 - Val Loss: 0.000338
#
# Epoch [440/999] - Train Loss: 0.000265 - Val Loss: 0.000338
#
# Epoch [441/999] - Train Loss: 0.000289 - Val Loss: 0.000337
#
# Epoch [442/999] - Train Loss: 0.000273 - Val Loss: 0.000336
#
# Epoch [443/999] - Train Loss: 0.000291 - Val Loss: 0.000336
#
# Epoch [444/999] - Train Loss: 0.000283 - Val Loss: 0.000335
#
# Epoch [445/999] - Train Loss: 0.000293 - Val Loss: 0.000334
#
# Epoch [446/999] - Train Loss: 0.000270 - Val Loss: 0.000333
#
# Epoch [447/999] - Train Loss: 0.000287 - Val Loss: 0.000332
#
# Epoch [448/999] - Train Loss: 0.000277 - Val Loss: 0.000332
#
# Epoch [449/999] - Train Loss: 0.000255 - Val Loss: 0.000332
#
# Epoch [450/999] - Train Loss: 0.000255 - Val Loss: 0.000332
#
# Epoch [451/999] - Train Loss: 0.000268 - Val Loss: 0.000331
#
# Epoch [452/999] - Train Loss: 0.000285 - Val Loss: 0.000331
#
# Epoch [453/999] - Train Loss: 0.000266 - Val Loss: 0.000331
#
# Epoch [454/999] - Train Loss: 0.000276 - Val Loss: 0.000330
#
# Epoch [455/999] - Train Loss: 0.000275 - Val Loss: 0.000330
#
# Epoch [456/999] - Train Loss: 0.000276 - Val Loss: 0.000329
#
# Epoch [457/999] - Train Loss: 0.000282 - Val Loss: 0.000329
#
# Epoch [458/999] - Train Loss: 0.000274 - Val Loss: 0.000328
#
# Epoch [459/999] - Train Loss: 0.000254 - Val Loss: 0.000328
#
# Epoch [460/999] - Train Loss: 0.000264 - Val Loss: 0.000327
#
# Epoch [461/999] - Train Loss: 0.000276 - Val Loss: 0.000326
#
# Epoch [462/999] - Train Loss: 0.000286 - Val Loss: 0.000325
#
# Epoch [463/999] - Train Loss: 0.000271 - Val Loss: 0.000323
#
# Epoch [464/999] - Train Loss: 0.000252 - Val Loss: 0.000322
#
# Epoch [465/999] - Train Loss: 0.000274 - Val Loss: 0.000321
#
# Epoch [466/999] - Train Loss: 0.000278 - Val Loss: 0.000320
#
# Epoch [467/999] - Train Loss: 0.000262 - Val Loss: 0.000319
#
# Epoch [468/999] - Train Loss: 0.000275 - Val Loss: 0.000317
#
# Epoch [469/999] - Train Loss: 0.000240 - Val Loss: 0.000317
#
# Epoch [470/999] - Train Loss: 0.000266 - Val Loss: 0.000316
#
# Epoch [471/999] - Train Loss: 0.000251 - Val Loss: 0.000316
#
# Epoch [472/999] - Train Loss: 0.000268 - Val Loss: 0.000316
#
# Epoch [473/999] - Train Loss: 0.000246 - Val Loss: 0.000316
#
# Epoch [474/999] - Train Loss: 0.000264 - Val Loss: 0.000316
#
# Epoch [475/999] - Train Loss: 0.000263 - Val Loss: 0.000315
#
# Epoch [476/999] - Train Loss: 0.000265 - Val Loss: 0.000315
#
# Epoch [477/999] - Train Loss: 0.000244 - Val Loss: 0.000315
#
# Epoch [478/999] - Train Loss: 0.000264 - Val Loss: 0.000314
#
# Epoch [479/999] - Train Loss: 0.000252 - Val Loss: 0.000314
#
# Epoch [480/999] - Train Loss: 0.000251 - Val Loss: 0.000314
#
# Epoch [481/999] - Train Loss: 0.000274 - Val Loss: 0.000313
#
# Epoch [482/999] - Train Loss: 0.000258 - Val Loss: 0.000312
#
# Epoch [483/999] - Train Loss: 0.000263 - Val Loss: 0.000311
#
# Epoch [484/999] - Train Loss: 0.000238 - Val Loss: 0.000311
#
# Epoch [485/999] - Train Loss: 0.000257 - Val Loss: 0.000310
#
# Epoch [486/999] - Train Loss: 0.000247 - Val Loss: 0.000309
#
# Epoch [487/999] - Train Loss: 0.000269 - Val Loss: 0.000309
#
# Epoch [488/999] - Train Loss: 0.000261 - Val Loss: 0.000309
#
# Epoch [489/999] - Train Loss: 0.000273 - Val Loss: 0.000308
#
# Epoch [490/999] - Train Loss: 0.000263 - Val Loss: 0.000308
#
# Epoch [491/999] - Train Loss: 0.000243 - Val Loss: 0.000307
#
# Epoch [492/999] - Train Loss: 0.000243 - Val Loss: 0.000306
#
# Epoch [493/999] - Train Loss: 0.000264 - Val Loss: 0.000306
#
# Epoch [494/999] - Train Loss: 0.000241 - Val Loss: 0.000305
#
# Epoch [495/999] - Train Loss: 0.000272 - Val Loss: 0.000304
#
# Epoch [496/999] - Train Loss: 0.000246 - Val Loss: 0.000304
#
# Epoch [497/999] - Train Loss: 0.000256 - Val Loss: 0.000303
#
# Epoch [498/999] - Train Loss: 0.000266 - Val Loss: 0.000302
#
# Epoch [499/999] - Train Loss: 0.000259 - Val Loss: 0.000302
#
# Epoch [500/999] - Train Loss: 0.000259 - Val Loss: 0.000301
#
# Epoch [501/999] - Train Loss: 0.000255 - Val Loss: 0.000300
#
# Epoch [502/999] - Train Loss: 0.000248 - Val Loss: 0.000300
#
# Epoch [503/999] - Train Loss: 0.000258 - Val Loss: 0.000299
#
# Epoch [504/999] - Train Loss: 0.000253 - Val Loss: 0.000299
#
# Epoch [505/999] - Train Loss: 0.000250 - Val Loss: 0.000298
#
# Epoch [506/999] - Train Loss: 0.000246 - Val Loss: 0.000297
#
# Epoch [507/999] - Train Loss: 0.000246 - Val Loss: 0.000297
#
# Epoch [508/999] - Train Loss: 0.000258 - Val Loss: 0.000297
#
# Epoch [509/999] - Train Loss: 0.000264 - Val Loss: 0.000297
#
# Epoch [510/999] - Train Loss: 0.000253 - Val Loss: 0.000296
#
# Epoch [511/999] - Train Loss: 0.000241 - Val Loss: 0.000296
#
# Epoch [512/999] - Train Loss: 0.000245 - Val Loss: 0.000295
#
# Epoch [513/999] - Train Loss: 0.000261 - Val Loss: 0.000295
#
# Epoch [514/999] - Train Loss: 0.000230 - Val Loss: 0.000295
#
# Epoch [515/999] - Train Loss: 0.000255 - Val Loss: 0.000294
#
# Epoch [516/999] - Train Loss: 0.000253 - Val Loss: 0.000294
#
# Epoch [517/999] - Train Loss: 0.000248 - Val Loss: 0.000293
#
# Epoch [518/999] - Train Loss: 0.000247 - Val Loss: 0.000293
#
# Epoch [519/999] - Train Loss: 0.000245 - Val Loss: 0.000293
#
# Epoch [520/999] - Train Loss: 0.000241 - Val Loss: 0.000292
#
# Epoch [521/999] - Train Loss: 0.000238 - Val Loss: 0.000292
#
# Epoch [522/999] - Train Loss: 0.000260 - Val Loss: 0.000292
#
# Epoch [523/999] - Train Loss: 0.000262 - Val Loss: 0.000291
#
# Epoch [524/999] - Train Loss: 0.000239 - Val Loss: 0.000291
#
# Epoch [525/999] - Train Loss: 0.000245 - Val Loss: 0.000291
#
# Epoch [526/999] - Train Loss: 0.000262 - Val Loss: 0.000291
#
# Epoch [527/999] - Train Loss: 0.000240 - Val Loss: 0.000290
#
# Epoch [528/999] - Train Loss: 0.000236 - Val Loss: 0.000290
#
# Epoch [529/999] - Train Loss: 0.000233 - Val Loss: 0.000290
#
# Epoch [530/999] - Train Loss: 0.000239 - Val Loss: 0.000289
#
# Epoch [531/999] - Train Loss: 0.000240 - Val Loss: 0.000288
#
# Epoch [532/999] - Train Loss: 0.000251 - Val Loss: 0.000288
#
# Epoch [533/999] - Train Loss: 0.000248 - Val Loss: 0.000288
#
# Epoch [534/999] - Train Loss: 0.000246 - Val Loss: 0.000287
#
# Epoch [535/999] - Train Loss: 0.000243 - Val Loss: 0.000287
#
# Epoch [536/999] - Train Loss: 0.000227 - Val Loss: 0.000286
#
# Epoch [537/999] - Train Loss: 0.000246 - Val Loss: 0.000286
#
# Epoch [538/999] - Train Loss: 0.000233 - Val Loss: 0.000286
#
# Epoch [539/999] - Train Loss: 0.000246 - Val Loss: 0.000285
#
# Epoch [540/999] - Train Loss: 0.000249 - Val Loss: 0.000285
#
# Epoch [541/999] - Train Loss: 0.000240 - Val Loss: 0.000285
#
# Epoch [542/999] - Train Loss: 0.000254 - Val Loss: 0.000284
#
# Epoch [543/999] - Train Loss: 0.000260 - Val Loss: 0.000284
#
# Epoch [544/999] - Train Loss: 0.000235 - Val Loss: 0.000283
#
# Epoch [545/999] - Train Loss: 0.000260 - Val Loss: 0.000283
#
# Epoch [546/999] - Train Loss: 0.000243 - Val Loss: 0.000283
#
# Epoch [547/999] - Train Loss: 0.000241 - Val Loss: 0.000282
#
# Epoch [548/999] - Train Loss: 0.000229 - Val Loss: 0.000282
#
# Epoch [549/999] - Train Loss: 0.000243 - Val Loss: 0.000281
#
# Epoch [550/999] - Train Loss: 0.000234 - Val Loss: 0.000280
#
# Epoch [551/999] - Train Loss: 0.000230 - Val Loss: 0.000280
#
# Epoch [552/999] - Train Loss: 0.000217 - Val Loss: 0.000279
#
# Epoch [553/999] - Train Loss: 0.000229 - Val Loss: 0.000279
#
# Epoch [554/999] - Train Loss: 0.000242 - Val Loss: 0.000278
#
# Epoch [555/999] - Train Loss: 0.000234 - Val Loss: 0.000278
#
# Epoch [556/999] - Train Loss: 0.000240 - Val Loss: 0.000277
#
# Epoch [557/999] - Train Loss: 0.000244 - Val Loss: 0.000277
#
# Epoch [558/999] - Train Loss: 0.000226 - Val Loss: 0.000277
#
# Epoch [559/999] - Train Loss: 0.000232 - Val Loss: 0.000277
#
# Epoch [560/999] - Train Loss: 0.000240 - Val Loss: 0.000277
#
# Epoch [561/999] - Train Loss: 0.000240 - Val Loss: 0.000277
#
# Epoch [562/999] - Train Loss: 0.000227 - Val Loss: 0.000276
#
# Epoch [563/999] - Train Loss: 0.000232 - Val Loss: 0.000276
#
# Epoch [564/999] - Train Loss: 0.000208 - Val Loss: 0.000276
#
# Epoch [565/999] - Train Loss: 0.000238 - Val Loss: 0.000276
#
# Epoch [566/999] - Train Loss: 0.000244 - Val Loss: 0.000275
#
# Epoch [567/999] - Train Loss: 0.000226 - Val Loss: 0.000275
#
# Epoch [568/999] - Train Loss: 0.000235 - Val Loss: 0.000275
#
# Epoch [569/999] - Train Loss: 0.000218 - Val Loss: 0.000274
#
# Epoch [570/999] - Train Loss: 0.000232 - Val Loss: 0.000274
#
# Epoch [571/999] - Train Loss: 0.000230 - Val Loss: 0.000274
#
# Epoch [572/999] - Train Loss: 0.000238 - Val Loss: 0.000273
#
# Epoch [573/999] - Train Loss: 0.000213 - Val Loss: 0.000272
#
# Epoch [574/999] - Train Loss: 0.000221 - Val Loss: 0.000272
#
# Epoch [575/999] - Train Loss: 0.000210 - Val Loss: 0.000272
#
# Epoch [576/999] - Train Loss: 0.000234 - Val Loss: 0.000271
#
# Epoch [577/999] - Train Loss: 0.000217 - Val Loss: 0.000270
#
# Epoch [578/999] - Train Loss: 0.000225 - Val Loss: 0.000270
#
# Epoch [579/999] - Train Loss: 0.000217 - Val Loss: 0.000270
#
# Epoch [580/999] - Train Loss: 0.000222 - Val Loss: 0.000270
#
# Epoch [581/999] - Train Loss: 0.000226 - Val Loss: 0.000270
#
# Epoch [582/999] - Train Loss: 0.000217 - Val Loss: 0.000270
#
# Epoch [583/999] - Train Loss: 0.000212 - Val Loss: 0.000270
#
# Epoch [584/999] - Train Loss: 0.000230 - Val Loss: 0.000270
#
# Epoch [585/999] - Train Loss: 0.000223 - Val Loss: 0.000270
#
# Epoch [586/999] - Train Loss: 0.000218 - Val Loss: 0.000269
#
# Epoch [587/999] - Train Loss: 0.000222 - Val Loss: 0.000269
#
# Epoch [588/999] - Train Loss: 0.000214 - Val Loss: 0.000269
#
# Epoch [589/999] - Train Loss: 0.000208 - Val Loss: 0.000268
#
# Epoch [590/999] - Train Loss: 0.000227 - Val Loss: 0.000268
#
# Epoch [591/999] - Train Loss: 0.000221 - Val Loss: 0.000267
#
# Epoch [592/999] - Train Loss: 0.000211 - Val Loss: 0.000266
#
# Epoch [593/999] - Train Loss: 0.000231 - Val Loss: 0.000266
#
# Epoch [594/999] - Train Loss: 0.000229 - Val Loss: 0.000265
#
# Epoch [595/999] - Train Loss: 0.000223 - Val Loss: 0.000264
#
# Epoch [596/999] - Train Loss: 0.000222 - Val Loss: 0.000264
#
# Epoch [597/999] - Train Loss: 0.000219 - Val Loss: 0.000263
#
# Epoch [598/999] - Train Loss: 0.000208 - Val Loss: 0.000263
#
# Epoch [599/999] - Train Loss: 0.000229 - Val Loss: 0.000262
#
# Epoch [600/999] - Train Loss: 0.000212 - Val Loss: 0.000262
#
# Epoch [601/999] - Train Loss: 0.000212 - Val Loss: 0.000262
#
# Epoch [602/999] - Train Loss: 0.000230 - Val Loss: 0.000261
#
# Epoch [603/999] - Train Loss: 0.000214 - Val Loss: 0.000261
#
# Epoch [604/999] - Train Loss: 0.000225 - Val Loss: 0.000261
#
# Epoch [605/999] - Train Loss: 0.000225 - Val Loss: 0.000261
#
# Epoch [606/999] - Train Loss: 0.000202 - Val Loss: 0.000260
#
# Epoch [607/999] - Train Loss: 0.000224 - Val Loss: 0.000260
#
# Epoch [608/999] - Train Loss: 0.000224 - Val Loss: 0.000260
#
# Epoch [609/999] - Train Loss: 0.000219 - Val Loss: 0.000259
#
# Epoch [610/999] - Train Loss: 0.000222 - Val Loss: 0.000259
#
# Epoch [611/999] - Train Loss: 0.000212 - Val Loss: 0.000259
#
# Epoch [612/999] - Train Loss: 0.000214 - Val Loss: 0.000258
#
# Epoch [613/999] - Train Loss: 0.000214 - Val Loss: 0.000258
#
# Epoch [614/999] - Train Loss: 0.000221 - Val Loss: 0.000257
#
# Epoch [615/999] - Train Loss: 0.000222 - Val Loss: 0.000256
#
# Epoch [616/999] - Train Loss: 0.000212 - Val Loss: 0.000256
#
# Epoch [617/999] - Train Loss: 0.000213 - Val Loss: 0.000255
#
# Epoch [618/999] - Train Loss: 0.000214 - Val Loss: 0.000255
#
# Epoch [619/999] - Train Loss: 0.000215 - Val Loss: 0.000255
#
# Epoch [620/999] - Train Loss: 0.000210 - Val Loss: 0.000255
#
# Epoch [621/999] - Train Loss: 0.000203 - Val Loss: 0.000254
#
# Epoch [622/999] - Train Loss: 0.000205 - Val Loss: 0.000254
#
# Epoch [623/999] - Train Loss: 0.000212 - Val Loss: 0.000254
#
# Epoch [624/999] - Train Loss: 0.000205 - Val Loss: 0.000254
#
# Epoch [625/999] - Train Loss: 0.000216 - Val Loss: 0.000253
#
# Epoch [626/999] - Train Loss: 0.000212 - Val Loss: 0.000253
#
# Epoch [627/999] - Train Loss: 0.000205 - Val Loss: 0.000252
#
# Epoch [628/999] - Train Loss: 0.000205 - Val Loss: 0.000252
#
# ...
#
# Epoch [766/999] - Train Loss: 0.000168 - Val Loss: 0.000197
#
# Epoch [767/999] - Train Loss: 0.000180 - Val Loss: 0.000197
#
# Epoch [768/999] - Train Loss: 0.000171 - Val Loss: 0.000196
#
# Epoch [769/999] - Train Loss: 0.000158 - Val Loss: 0.000196
#
# Epoch [770/999] - Train Loss: 0.000159 - Val Loss: 0.000195
#
# Epoch [771/999] - Train Loss: 0.000164 - Val Loss: 0.000195
#
# Epoch [772/999] - Train Loss: 0.000152 - Val Loss: 0.000194
#
# Epoch [773/999] - Train Loss: 0.000163 - Val Loss: 0.000194
#
# Epoch [774/999] - Train Loss: 0.000166 - Val Loss: 0.000194
#
# Epoch [775/999] - Train Loss: 0.000154 - Val Loss: 0.000194
#
# Epoch [776/999] - Train Loss: 0.000161 - Val Loss: 0.000193
#
# Epoch [777/999] - Train Loss: 0.000157 - Val Loss: 0.000193
#
# Epoch [778/999] - Train Loss: 0.000165 - Val Loss: 0.000193
#
# Epoch [779/999] - Train Loss: 0.000171 - Val Loss: 0.000193
#
# Epoch [780/999] - Train Loss: 0.000169 - Val Loss: 0.000192
#
# Epoch [781/999] - Train Loss: 0.000157 - Val Loss: 0.000192
#
# Epoch [782/999] - Train Loss: 0.000159 - Val Loss: 0.000192
#
# Epoch [783/999] - Train Loss: 0.000159 - Val Loss: 0.000192
#
# Epoch [784/999] - Train Loss: 0.000162 - Val Loss: 0.000192
#
# Epoch [785/999] - Train Loss: 0.000160 - Val Loss: 0.000192
#
# Epoch [786/999] - Train Loss: 0.000154 - Val Loss: 0.000192
#
# Epoch [787/999] - Train Loss: 0.000173 - Val Loss: 0.000192
#
# Epoch [788/999] - Train Loss: 0.000153 - Val Loss: 0.000192
#
# Epoch [789/999] - Train Loss: 0.000160 - Val Loss: 0.000192
#
# Epoch [790/999] - Train Loss: 0.000167 - Val Loss: 0.000192
#
# Epoch [791/999] - Train Loss: 0.000154 - Val Loss: 0.000191
#
# Epoch [792/999] - Train Loss: 0.000155 - Val Loss: 0.000191
#
# Epoch [793/999] - Train Loss: 0.000168 - Val Loss: 0.000191
#
# Epoch [794/999] - Train Loss: 0.000144 - Val Loss: 0.000190
#
# Epoch [795/999] - Train Loss: 0.000156 - Val Loss: 0.000190
#
# Epoch [796/999] - Train Loss: 0.000160 - Val Loss: 0.000190
#
# Epoch [797/999] - Train Loss: 0.000156 - Val Loss: 0.000190
#
# Epoch [798/999] - Train Loss: 0.000145 - Val Loss: 0.000190
#
# Epoch [799/999] - Train Loss: 0.000161 - Val Loss: 0.000190
#
# Epoch [800/999] - Train Loss: 0.000151 - Val Loss: 0.000190
#
# Epoch [801/999] - Train Loss: 0.000170 - Val Loss: 0.000189
#
# Epoch [802/999] - Train Loss: 0.000159 - Val Loss: 0.000189
#
# Epoch [803/999] - Train Loss: 0.000146 - Val Loss: 0.000188
#
# Epoch [804/999] - Train Loss: 0.000140 - Val Loss: 0.000188
#
# Epoch [805/999] - Train Loss: 0.000164 - Val Loss: 0.000188
#
# Epoch [806/999] - Train Loss: 0.000147 - Val Loss: 0.000187
#
# Epoch [807/999] - Train Loss: 0.000160 - Val Loss: 0.000187
#
# Epoch [808/999] - Train Loss: 0.000160 - Val Loss: 0.000186
#
# Epoch [809/999] - Train Loss: 0.000157 - Val Loss: 0.000186
#
# Epoch [810/999] - Train Loss: 0.000147 - Val Loss: 0.000185
#
# Epoch [811/999] - Train Loss: 0.000156 - Val Loss: 0.000185
#
# Epoch [812/999] - Train Loss: 0.000149 - Val Loss: 0.000184
#
# Epoch [813/999] - Train Loss: 0.000156 - Val Loss: 0.000184
#
# Epoch [814/999] - Train Loss: 0.000141 - Val Loss: 0.000183
#
# Epoch [815/999] - Train Loss: 0.000139 - Val Loss: 0.000183
#
# Epoch [816/999] - Train Loss: 0.000152 - Val Loss: 0.000183
#
# Epoch [817/999] - Train Loss: 0.000153 - Val Loss: 0.000182
#
# Epoch [818/999] - Train Loss: 0.000152 - Val Loss: 0.000182
#
# Epoch [819/999] - Train Loss: 0.000144 - Val Loss: 0.000181
#
# Epoch [820/999] - Train Loss: 0.000160 - Val Loss: 0.000180
#
# Epoch [821/999] - Train Loss: 0.000141 - Val Loss: 0.000180
#
# Epoch [822/999] - Train Loss: 0.000153 - Val Loss: 0.000179
#
# Epoch [823/999] - Train Loss: 0.000148 - Val Loss: 0.000178
#
# Epoch [824/999] - Train Loss: 0.000161 - Val Loss: 0.000178
#
# Epoch [825/999] - Train Loss: 0.000155 - Val Loss: 0.000177
#
# Epoch [826/999] - Train Loss: 0.000150 - Val Loss: 0.000177
#
# Epoch [827/999] - Train Loss: 0.000150 - Val Loss: 0.000177
#
# Epoch [828/999] - Train Loss: 0.000149 - Val Loss: 0.000177
#
# Epoch [829/999] - Train Loss: 0.000153 - Val Loss: 0.000177
#
# Epoch [830/999] - Train Loss: 0.000157 - Val Loss: 0.000176
#
# Epoch [831/999] - Train Loss: 0.000148 - Val Loss: 0.000176
#
# Epoch [832/999] - Train Loss: 0.000141 - Val Loss: 0.000176
#
# Epoch [833/999] - Train Loss: 0.000154 - Val Loss: 0.000176
#
# Epoch [834/999] - Train Loss: 0.000154 - Val Loss: 0.000175
#
# Epoch [835/999] - Train Loss: 0.000136 - Val Loss: 0.000175
#
# Epoch [836/999] - Train Loss: 0.000134 - Val Loss: 0.000175
#
# Epoch [837/999] - Train Loss: 0.000145 - Val Loss: 0.000175
#
# Epoch [838/999] - Train Loss: 0.000142 - Val Loss: 0.000175
#
# Epoch [839/999] - Train Loss: 0.000146 - Val Loss: 0.000175
#
# Epoch [840/999] - Train Loss: 0.000143 - Val Loss: 0.000175
#
# Epoch [841/999] - Train Loss: 0.000144 - Val Loss: 0.000175
#
# Epoch [842/999] - Train Loss: 0.000150 - Val Loss: 0.000175
#
# Epoch [843/999] - Train Loss: 0.000148 - Val Loss: 0.000174
#
# Epoch [844/999] - Train Loss: 0.000149 - Val Loss: 0.000174
#
# Epoch [845/999] - Train Loss: 0.000141 - Val Loss: 0.000173
#
# Epoch [846/999] - Train Loss: 0.000148 - Val Loss: 0.000172
#
# Epoch [847/999] - Train Loss: 0.000136 - Val Loss: 0.000172
#
# Epoch [848/999] - Train Loss: 0.000142 - Val Loss: 0.000171
#
# Epoch [849/999] - Train Loss: 0.000135 - Val Loss: 0.000170
#
# Epoch [850/999] - Train Loss: 0.000133 - Val Loss: 0.000170
#
# Epoch [851/999] - Train Loss: 0.000142 - Val Loss: 0.000169
#
# Epoch [852/999] - Train Loss: 0.000152 - Val Loss: 0.000169
#
# Epoch [853/999] - Train Loss: 0.000141 - Val Loss: 0.000168
#
# Epoch [854/999] - Train Loss: 0.000140 - Val Loss: 0.000167
#
# Epoch [855/999] - Train Loss: 0.000146 - Val Loss: 0.000166
#
# Epoch [856/999] - Train Loss: 0.000134 - Val Loss: 0.000166
#
# Epoch [857/999] - Train Loss: 0.000148 - Val Loss: 0.000165
#
# Epoch [858/999] - Train Loss: 0.000136 - Val Loss: 0.000165
#
# Epoch [859/999] - Train Loss: 0.000147 - Val Loss: 0.000165
#
# Epoch [860/999] - Train Loss: 0.000136 - Val Loss: 0.000164
#
# Epoch [861/999] - Train Loss: 0.000141 - Val Loss: 0.000164
#
# Epoch [862/999] - Train Loss: 0.000151 - Val Loss: 0.000164
#
# Epoch [863/999] - Train Loss: 0.000144 - Val Loss: 0.000163
#
# Epoch [864/999] - Train Loss: 0.000133 - Val Loss: 0.000163
#
# Epoch [865/999] - Train Loss: 0.000137 - Val Loss: 0.000162
#
# Epoch [866/999] - Train Loss: 0.000134 - Val Loss: 0.000162
#
# Epoch [867/999] - Train Loss: 0.000135 - Val Loss: 0.000162
#
# Epoch [868/999] - Train Loss: 0.000136 - Val Loss: 0.000162
#
# Epoch [869/999] - Train Loss: 0.000135 - Val Loss: 0.000162
#
# Epoch [870/999] - Train Loss: 0.000137 - Val Loss: 0.000162
#
# Epoch [871/999] - Train Loss: 0.000130 - Val Loss: 0.000161
#
# Epoch [872/999] - Train Loss: 0.000142 - Val Loss: 0.000161
#
# Epoch [873/999] - Train Loss: 0.000132 - Val Loss: 0.000161
#
# Epoch [874/999] - Train Loss: 0.000133 - Val Loss: 0.000161
#
# Epoch [875/999] - Train Loss: 0.000128 - Val Loss: 0.000161
#
# Epoch [876/999] - Train Loss: 0.000133 - Val Loss: 0.000160
#
# Epoch [877/999] - Train Loss: 0.000128 - Val Loss: 0.000160
#
# Epoch [878/999] - Train Loss: 0.000133 - Val Loss: 0.000160
#
# Epoch [879/999] - Train Loss: 0.000131 - Val Loss: 0.000159
#
# Epoch [880/999] - Train Loss: 0.000140 - Val Loss: 0.000159
#
# Epoch [881/999] - Train Loss: 0.000130 - Val Loss: 0.000159
#
# Epoch [882/999] - Train Loss: 0.000129 - Val Loss: 0.000158
#
# Epoch [883/999] - Train Loss: 0.000131 - Val Loss: 0.000158
#
# Epoch [884/999] - Train Loss: 0.000133 - Val Loss: 0.000157
#
# Epoch [885/999] - Train Loss: 0.000129 - Val Loss: 0.000157
#
# Epoch [886/999] - Train Loss: 0.000132 - Val Loss: 0.000157
#
# Epoch [887/999] - Train Loss: 0.000131 - Val Loss: 0.000156
#
# Epoch [888/999] - Train Loss: 0.000132 - Val Loss: 0.000156
#
# Epoch [889/999] - Train Loss: 0.000134 - Val Loss: 0.000156
#
# Epoch [890/999] - Train Loss: 0.000128 - Val Loss: 0.000155
#
# Epoch [891/999] - Train Loss: 0.000135 - Val Loss: 0.000155
#
# Epoch [892/999] - Train Loss: 0.000131 - Val Loss: 0.000155
#
# Epoch [893/999] - Train Loss: 0.000133 - Val Loss: 0.000154
#
# Epoch [894/999] - Train Loss: 0.000122 - Val Loss: 0.000154
#
# Epoch [895/999] - Train Loss: 0.000123 - Val Loss: 0.000154
#
# Epoch [896/999] - Train Loss: 0.000135 - Val Loss: 0.000154
#
# Epoch [897/999] - Train Loss: 0.000123 - Val Loss: 0.000153
#
# Epoch [898/999] - Train Loss: 0.000133 - Val Loss: 0.000153
#
# Epoch [899/999] - Train Loss: 0.000134 - Val Loss: 0.000152
#
# Epoch [900/999] - Train Loss: 0.000124 - Val Loss: 0.000152
#
# Epoch [901/999] - Train Loss: 0.000122 - Val Loss: 0.000152
#
# Epoch [902/999] - Train Loss: 0.000135 - Val Loss: 0.000151
#
# Epoch [903/999] - Train Loss: 0.000124 - Val Loss: 0.000150
#
# Epoch [904/999] - Train Loss: 0.000126 - Val Loss: 0.000149
#
# Epoch [905/999] - Train Loss: 0.000120 - Val Loss: 0.000149
#
# Epoch [906/999] - Train Loss: 0.000119 - Val Loss: 0.000149
#
# Epoch [907/999] - Train Loss: 0.000126 - Val Loss: 0.000148
#
# Epoch [908/999] - Train Loss: 0.000127 - Val Loss: 0.000148
#
# Epoch [909/999] - Train Loss: 0.000124 - Val Loss: 0.000148
#
# Epoch [910/999] - Train Loss: 0.000127 - Val Loss: 0.000147
#
# Epoch [911/999] - Train Loss: 0.000125 - Val Loss: 0.000147
#
# Epoch [912/999] - Train Loss: 0.000125 - Val Loss: 0.000147
#
# Epoch [913/999] - Train Loss: 0.000123 - Val Loss: 0.000146
#
# Epoch [914/999] - Train Loss: 0.000125 - Val Loss: 0.000146
#
# Epoch [915/999] - Train Loss: 0.000127 - Val Loss: 0.000146
#
# Epoch [916/999] - Train Loss: 0.000122 - Val Loss: 0.000145
#
# Epoch [917/999] - Train Loss: 0.000134 - Val Loss: 0.000145
#
# Epoch [918/999] - Train Loss: 0.000128 - Val Loss: 0.000146
#
# Epoch [919/999] - Train Loss: 0.000126 - Val Loss: 0.000146
#
# Epoch [920/999] - Train Loss: 0.000126 - Val Loss: 0.000145
#
# Epoch [921/999] - Train Loss: 0.000132 - Val Loss: 0.000145
#
# Epoch [922/999] - Train Loss: 0.000121 - Val Loss: 0.000145
#
# Epoch [923/999] - Train Loss: 0.000115 - Val Loss: 0.000145
#
# Epoch [924/999] - Train Loss: 0.000120 - Val Loss: 0.000144
#
# Epoch [925/999] - Train Loss: 0.000125 - Val Loss: 0.000144
#
# Epoch [926/999] - Train Loss: 0.000109 - Val Loss: 0.000144
#
# Epoch [927/999] - Train Loss: 0.000118 - Val Loss: 0.000143
#
# Epoch [928/999] - Train Loss: 0.000119 - Val Loss: 0.000143
#
# Epoch [929/999] - Train Loss: 0.000119 - Val Loss: 0.000143
#
# Epoch [930/999] - Train Loss: 0.000121 - Val Loss: 0.000143
#
# Epoch [931/999] - Train Loss: 0.000107 - Val Loss: 0.000142
#
# Epoch [932/999] - Train Loss: 0.000121 - Val Loss: 0.000142
#
# Epoch [933/999] - Train Loss: 0.000124 - Val Loss: 0.000142
#
# Epoch [934/999] - Train Loss: 0.000117 - Val Loss: 0.000142
#
# Epoch [935/999] - Train Loss: 0.000125 - Val Loss: 0.000142
#
# Epoch [936/999] - Train Loss: 0.000117 - Val Loss: 0.000142
#
# Epoch [937/999] - Train Loss: 0.000121 - Val Loss: 0.000142
#
# Epoch [938/999] - Train Loss: 0.000123 - Val Loss: 0.000142
#
# Epoch [939/999] - Train Loss: 0.000118 - Val Loss: 0.000142
#
# Epoch [940/999] - Train Loss: 0.000123 - Val Loss: 0.000142
#
# Epoch [941/999] - Train Loss: 0.000116 - Val Loss: 0.000141
#
# Epoch [942/999] - Train Loss: 0.000121 - Val Loss: 0.000141
#
# Epoch [943/999] - Train Loss: 0.000125 - Val Loss: 0.000141
#
# Epoch [944/999] - Train Loss: 0.000113 - Val Loss: 0.000140
#
# Epoch [945/999] - Train Loss: 0.000121 - Val Loss: 0.000140
#
# Epoch [946/999] - Train Loss: 0.000107 - Val Loss: 0.000140
#
# Epoch [947/999] - Train Loss: 0.000123 - Val Loss: 0.000139
#
# Epoch [948/999] - Train Loss: 0.000114 - Val Loss: 0.000139
#
# Epoch [949/999] - Train Loss: 0.000117 - Val Loss: 0.000139
#
# Epoch [950/999] - Train Loss: 0.000113 - Val Loss: 0.000139
#
# Epoch [951/999] - Train Loss: 0.000111 - Val Loss: 0.000139
#
# Epoch [952/999] - Train Loss: 0.000122 - Val Loss: 0.000138
#
# Epoch [953/999] - Train Loss: 0.000112 - Val Loss: 0.000138
#
# Epoch [954/999] - Train Loss: 0.000118 - Val Loss: 0.000138
#
# Epoch [955/999] - Train Loss: 0.000116 - Val Loss: 0.000138
#
# Epoch [956/999] - Train Loss: 0.000109 - Val Loss: 0.000138
#
# Epoch [957/999] - Train Loss: 0.000116 - Val Loss: 0.000138
#
# Epoch [958/999] - Train Loss: 0.000111 - Val Loss: 0.000137
#
# Epoch [959/999] - Train Loss: 0.000117 - Val Loss: 0.000137
#
# Epoch [960/999] - Train Loss: 0.000116 - Val Loss: 0.000137
#
# Epoch [961/999] - Train Loss: 0.000122 - Val Loss: 0.000136
#
# Epoch [962/999] - Train Loss: 0.000117 - Val Loss: 0.000136
#
# Epoch [963/999] - Train Loss: 0.000110 - Val Loss: 0.000136
#
# Epoch [964/999] - Train Loss: 0.000112 - Val Loss: 0.000135
#
# Epoch [965/999] - Train Loss: 0.000115 - Val Loss: 0.000135
#
# Epoch [966/999] - Train Loss: 0.000116 - Val Loss: 0.000134
#
# Epoch [967/999] - Train Loss: 0.000115 - Val Loss: 0.000133
#
# Epoch [968/999] - Train Loss: 0.000114 - Val Loss: 0.000132
#
# Epoch [969/999] - Train Loss: 0.000113 - Val Loss: 0.000131
#
# Epoch [970/999] - Train Loss: 0.000104 - Val Loss: 0.000131
#
# Epoch [971/999] - Train Loss: 0.000107 - Val Loss: 0.000130
#
# Epoch [972/999] - Train Loss: 0.000102 - Val Loss: 0.000130
#
# Epoch [973/999] - Train Loss: 0.000111 - Val Loss: 0.000130
#
# Epoch [974/999] - Train Loss: 0.000111 - Val Loss: 0.000129
#
# Epoch [975/999] - Train Loss: 0.000116 - Val Loss: 0.000129
#
# Epoch [976/999] - Train Loss: 0.000109 - Val Loss: 0.000128
#
# Epoch [977/999] - Train Loss: 0.000112 - Val Loss: 0.000128
#
# Epoch [978/999] - Train Loss: 0.000113 - Val Loss: 0.000127
#
# Epoch [979/999] - Train Loss: 0.000105 - Val Loss: 0.000127
#
# Epoch [980/999] - Train Loss: 0.000107 - Val Loss: 0.000126
#
# Epoch [981/999] - Train Loss: 0.000108 - Val Loss: 0.000126
#
# Epoch [982/999] - Train Loss: 0.000107 - Val Loss: 0.000125
#
# Epoch [983/999] - Train Loss: 0.000102 - Val Loss: 0.000125
#
# Epoch [984/999] - Train Loss: 0.000111 - Val Loss: 0.000125
#
# Epoch [985/999] - Train Loss: 0.000110 - Val Loss: 0.000125
#
# Epoch [986/999] - Train Loss: 0.000107 - Val Loss: 0.000125
#
# Epoch [987/999] - Train Loss: 0.000113 - Val Loss: 0.000125
#
# Epoch [988/999] - Train Loss: 0.000102 - Val Loss: 0.000125
#
# Epoch [989/999] - Train Loss: 0.000108 - Val Loss: 0.000125
#
# Epoch [990/999] - Train Loss: 0.000107 - Val Loss: 0.000125
#
# Epoch [991/999] - Train Loss: 0.000106 - Val Loss: 0.000125
#
# Epoch [992/999] - Train Loss: 0.000109 - Val Loss: 0.000125
#
# Epoch [993/999] - Train Loss: 0.000114 - Val Loss: 0.000125
#
# Epoch [994/999] - Train Loss: 0.000104 - Val Loss: 0.000125
#
# Epoch [995/999] - Train Loss: 0.000106 - Val Loss: 0.000124
#
# Epoch [996/999] - Train Loss: 0.000107 - Val Loss: 0.000124
#
# Epoch [997/999] - Train Loss: 0.000106 - Val Loss: 0.000124
#
# Epoch [998/999] - Train Loss: 0.000103 - Val Loss: 0.000123
#
# Epoch [999/999] - Train Loss: 0.000109 - Val Loss: 0.000122
# Model trained successfully!
# Best model has been saved as: SVD-DLinear.pth
# Step 4: Load the best epoch and plot the losses
# Model loaded
# C:\Users\ahetherington\AppData\Local\Temp\Mxt236\ahetherington_agastya\var\log\xwin\ipykernel_24572\2616788460.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))
# Step 5: Validate the model on test datared
# Input tensor (first sequence from the test data): (1, 30, 8)
#
#     Error summary
#     RRMSE [%]: 0.979
#     MAE: 0.511
#     MSE: 0.342
#
# Step 6: Forecast new snapshots
# Input tensor (last sequence from the test data): (1, 30, 8)
# Prediction shape [V.T]: (500, 8)
# Step 7: Reconstruct the new snapshots
#
#     Number of components: 2
#     Number of points in x: 449
#     Number of points in y: 199
#     Number of points in z: None
#
# Reconstructed test + forecast data: (2, 199, 449, 554)

# %%
test_forecast = forecast.copy()[..., :test_data.shape[-1]]
test_data = test_data.reshape(test_forecast.shape)

erroru = np.abs(test_data[0, ...] - test_forecast[0, ...])
errorv = np.abs(test_data[1, ...] - test_forecast[1, ...])

su = sv = test_data.shape[-1] - 1

fig, ax = plt.subplots(test_forecast.shape[0], 5, figsize=(15, 6), width_ratios=[25, 25, 1, 25, 1])
for axs in ax.flatten():
    axs.set(xticks=[], yticks=[])

ax[0, 0].set_ylabel('Y')
ax[0, 0].yaxis.set_label_coords(-0.025, .5)
ax[1, 0].set_ylabel('Y')
ax[1, 0].yaxis.set_label_coords(-0.025, .5)

ax[1, 0].set_xlabel('X')
ax[1, 1].set_xlabel('X')
ax[1, 3].set_xlabel('X')

ax[0, 0].contourf(test_data[0, ..., su], cmap='magma')
im1 = ax[0, 1].contourf(test_forecast[0, ..., su], cmap='magma')
im2 = ax[0, 3].contourf(erroru[..., su], cmap='magma')

ax[1, 0].contourf(test_data[1, ..., sv], cmap='magma')
im3 = ax[1, 1].contourf(test_forecast[1, ..., sv], cmap='magma')
im4 = ax[1, 3].contourf(errorv[..., sv], cmap='magma')

plt.colorbar(im1, cax=ax[0, 2])
plt.colorbar(im3, cax=ax[1, 2])
plt.colorbar(im2, cax=ax[0, 4])
plt.colorbar(im4, cax=ax[1, 4])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Use a pretrained model

# %%
def test_forecast(Tensor, esvd, seq_len, horizon, model_save_path, scaler_name, num_snaps):    
    Tensor_ = np.reshape(Tensor, (-1, Tensor.shape[-1]))
    
    U, S, V = np.linalg.svd(Tensor_, full_matrices = False)
    
    n_modes = 0
    norm = np.linalg.norm(S)
    
    for i in range(S.size):
        if np.linalg.norm(S[i:]) / norm <= esvd:
            pass
        else:
            n_modes += 1

    U = U[:, :n_modes]
    S = np.diag(S[:n_modes])
    V = V[:n_modes, :]

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    model = DLinear(sequence = seq_len, horizon = horizon, kernel_size = seq_len + 1 if 
                (seq_len + 1) % 2 != 0 else seq_len, individual = True, input_size = n_modes)
        
    model.to(device)
    print(model)
    total_params = sum(p.numel() for p in model.parameters())
    learn_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f'Total parameters: {total_params}')
    print(f'Learnable parameters: {learn_params}')

    model.load_state_dict(torch.load(model_save_path))
    model.eval()

    with open(f"{scaler_name}.pkl", "rb") as f:
        data_scaler = pickle.load(f)

    test = V[:, -seq_len:]

    test_seq = data_scaler.transform(test.transpose(1, 0))

    X = test_seq[np.newaxis, :, :].astype(float) 

    seq = torch.tensor(X.copy()).float().to(device) 

    preds = [] 

    with torch.no_grad():
        for i in range(num_snaps):
            y = model(seq)
            pred = y.detach().cpu().numpy()
            preds.append(data_scaler.inverse_transform(pred) ) # de-scale data
            seq = torch.cat((seq, y[None, :, :]), axis = 1)
            seq = seq[:, -seq_len:, :]
    
    forecast_sV = np.array(preds)

    print(f'Prediction shape [V.T]: {forecast_sV.squeeze().shape}')

    indxs = np.arange(len(np.array(V.T)), len(np.array(preds)) + len(np.array(V.T)))

    labels = ['Test data', 'Forecast']

    fig, ax = plt.subplots(2, 2, figsize = (10, 10))
    for i, axs in zip(range(4), ax.flatten()):
        axs.plot(V.T[:, i].squeeze() , c = 'k')
        axs.plot(indxs, np.array(preds)[..., i].squeeze(), c = 'red', alpha = 0.7)
        axs.set(title = f'Mode: {i + 1}')
        if i <= 1:
            axs.set(xticks = [])
    
    fig.tight_layout()
    fig.subplots_adjust(bottom = 0.1075)
    fig.legend(labels=labels, loc="lower center", ncol=2)
    
    plt.show()

    forecast = U @ S @ np.concatenate([V, forecast_sV.squeeze().T], axis = 1) 

    nv, ny, nx, _ = Tensor.shape
    forecast = forecast.reshape((nv, ny, nx, -1))
    nz = None
        
    print(f'''
    Number of components: {nv}
    Number of points in x: {nx}
    Number of points in y: {ny}
    Number of points in z: {nz}
    ''')

    print(f'Reconstructed test + forecast data: {forecast.shape}')

    return forecast

# %%
Tensor = list(loadmat('Tensor_cylinder_Re100.mat').values())[-1]
esvd = 1e-2
seq_len = 30
horizon = 1
num_snaps = 250
model_save_path = 'SVD-DLinear.pth'
scaler_name = 'SVD-DLinear_scaler'

new_tensor = test_forecast(Tensor, esvd, seq_len, horizon, model_save_path, scaler_name, num_snaps)
# Out:
# DLinear(
#   (decomposition): series_descomp(
#     (moving_avg): moving_avg(
#       (avg): AvgPool1d(kernel_size=(31,), stride=(1,), padding=(0,))
#     )
#   )
#   (Linear_Seasonal): ModuleList(
#     (0-7): 8 x Linear(in_features=30, out_features=1, bias=True)
#   )
#   (Linear_Trend): ModuleList(
#     (0-7): 8 x Linear(in_features=30, out_features=1, bias=True)
#   )
# )
# Total parameters: 496
# Learnable parameters: 496
# C:\Users\ahetherington\AppData\Local\Temp\Mxt236\ahetherington_agastya\var\log\xwin\ipykernel_24572\2818814744.py:30: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_save_path))
# Prediction shape [V.T]: (250, 8)
#     Number of components: 2
#     Number of points in x: 449
#     Number of points in y: 199
#     Number of points in z: None
#
# Reconstructed test + forecast data: (2, 199, 449, 401)

# %%
### Display the last forecast snapshot
fig, ax = plt.subplots(1, 3, width_ratios = [25, 25, 1], figsize = (12, 4))

ax[0].contourf(new_tensor[0, ..., -1])
ax[0].set(title = 'Num. - Streamwise velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
im1 = ax[1].contourf(new_tensor[1, ..., -1])
ax[1].set(title = 'Num. - Normal velocity', xlabel = 'X', ylabel = 'Y', xticks = [], yticks = [])
plt.colorbar(im1, cax = ax[2]);
